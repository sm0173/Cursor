# %% [markdown]
# # Программирование на Python, БИ
#
# ## НИУ ВШЭ, 2025-26 учебный год

# %% [markdown]
# # Семинар 15. API

# %% [markdown]
# Раннее мы с вами уже собирали данные вручную, обращаясь к html-страницам, размеченным для отображения в браузере. Однако это не единственный способ получения данных с внешних ресурсов — другим важным подходом является использование API — Application Program Interface.
#
# Обычный интерфейс — это способ взаимодействия человека с программой, а API — одной программы с другой, например, вашего скрипта на Python — с удалённым веб-сервером.
#
# Именно обсуждению такого прекрасного инструмента как API — а также всего, что с ним связано, — будет посвящен сегодняшний семинар.

# %% [markdown]
# ## Язык XML
#
# Для хранения веб-страниц, которые читают люди, используется язык HTML. Для хранения произвольных структурированных данных, которыми обмениваются между собой программы, используются другие языки — в частности, язык XML, похожий на HTML. Точнее, XML — это, на самом деле, даже не язык, а скорее метаязык — то есть способ описания языков. В отличие от HTML, набор тегов в XML-документе может быть произвольным (и определяется разработчиком конкретного диалекта XML). Например, если бы мы хотели описать в виде XML некоторую студенческую группу, это могло бы выглядеть так:
#
# ```xml
# <group>
#     <number>134</number>
#     <student>
#         <firstname>Виталий</firstname>
#         <lastname>Иванов</lastname>
#     </student>
#     <student>
#         <firstname>Мария</firstname>
#         <lastname>Петрова</lastname>
#     </student>
# </group>
# ```

# %% [markdown]
# Для обработки XML-файлов можно использовать тот же пакет *Beautiful Soup*, который мы уже использовали для работы с HTML. Единственное различие — нужно указать дополнительный параметр `features="xml"` при вызове функции `BeautifulSoup` — чтобы он не искал в документе HTML-теги.

# %%
group = """<group>
<number>134</number>
<student>
<firstname>Виталий</firstname>
<lastname>Иванов</lastname>
</student>
<student>
<firstname>Мария</firstname>
<lastname>Петрова</lastname>
</student>
</group>"""

# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from bs4) (4.13.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->bs4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->bs4) (4.12.2)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (5.3.0)

# %%
from bs4 import BeautifulSoup

# %%
obj = BeautifulSoup(group, features="lxml")
print(obj.prettify())
# Out:
# <html>
#  <body>
#   <group>
#    <number>
#     134
#    </number>
#    <student>
#     <firstname>
#      Виталий
#     </firstname>
#     <lastname>
#      Иванов
#     </lastname>
#    </student>
#    <student>
#     <firstname>
#      Мария
#     </firstname>
#     <lastname>
#      Петрова
#     </lastname>
#    </student>
#   </group>
#  </body>
# </html>

# %% [markdown]
# Номер группы можно найти, например, вот так — для каждого объекта через точку указываем его атрибут, в который надо спуститься.

# %%
obj.group.number.text # последний атрибут текст, точно также как делали в html
# Out:
# '134'

# %% [markdown]
# Но это работает только тогда, когда тэг уникальный. В других случаях, парсер всегда будет попадать в первый child-тэг, который он встретил по пути вниз.

# %%
obj.group.student.lastname.text # до Петровой так не добраться
# Out:
# 'Иванов'

# %% [markdown]
# Перечислить всех студентов можно с помощью цикла (похожая структура у нас была и в обработке html).

# %%
for student in obj.group.find_all('student'):
    print(student.lastname.text, student.firstname.text)
# Out:
# Иванов Виталий
# Петрова Мария

# %% [markdown]
# По сути, главное отличие xml от html состоит в том, что работать вы будете не со стандартизированными структурами. Поэтому перед работой придется поиграть в детективов — запросить данные и внимательно изучить расположение узлов, чтобы понять, какие тэги вас интересуют.

# %% [markdown]
# ## Язык JSON
#
# Другой популярный формат, в котором клиент может отдать вам данные — это язык json. JSON расшифровывается как JavaScript Object Notation и изначально возник как подмножество языка JavaScript, используемое для описания объектов. Впрочем, впоследствии он начал использоваться и в других языках программирования, включая, конечно, Python.
#
# Различные API могут поддерживать либо XML, либо JSON, либо и то, и другое одновременно, так что нам полезно будет научиться работать с обоими типами данных.

# %% [markdown]
# В целом, JSON очень похож на описание объекта в Python, и смысл квадратных и фигурных скобок здесь абсолютно такой же. Правда, есть и отличия: например, в Python одинарные и двойные кавычки ничем не отличаются, а в JSON можно использовать только двойные.
#
# Полученный нами JSON-файл, как правило, представляет собой словарь, значения которого — строки или числа, а также списки или словари, значения которых в свою очередь также могут быть строками, числами, списками, словарями и т.д. Таким образом получается довольно сложная, ветвистая структура данных.
#
# Впрочем, здесь очень важно сделать  ремарку, что тот факт, что перед нами сложная структура данных, видим только мы, но не программа — с точки зрения Python, j.text это просто какая-то строка. Однако в модуле requests присутствует специальный метод, позволяющий сразу выдать питоновский объект (словарь или список), если результат запроса возвращён в формате JSON. Так что нам в любом случае не придётся использовать какие-либо дополнительные библиотеки и сильно усложнять себе жизнь.

# %% [markdown]
# Подводя итог, хочется еще раз резюмировать, что основные преимущества JSON заключаются в том, что мы получаем готовый объект Python и нет необходимости использовать какие-то сторонние библиотеки для того, чтобы с ним работать. Недостатком является то же самое: зачастую поиск информации в XML-файле может проводиться более эффективно, чем в JSON.

# %% [markdown]
# ## API для веб-сайтов
#
# Прежде чем переходить к практике с API, необходимо обсудить несколько важных теоретических топиков касательно этого инструмента.

# %% [markdown]
# - В чем заключается принципиальная разница между подходами API и Web Scraping'a?
#
# - Какой смысл для компаний создавать в рамках своих порталов и сайтов протоколы доступа по API? Для чего?
#
# - Что такое API-ключ (API-токен) и зачем он нужен? Что будет, если передавать запрос по API без API-ключа?
#
# - Существует ли какой-то универсальный интерфейс для функций API у разных ресурсов и, если да, то в чём он заключается?
#
# - Где почитать описание доступа по API для конкретного веб-сайта, к данным которого мы хотим обратиться, используя этот протокол?

# %% [markdown]
# ## Практика. API для КиноПоиска
#
# Сегодня мы поработаем с неофициальным API КиноПоиска и попробуем извлечь интересные инсайты, на основе данных, к которым получим доступ.
#
# Документация для ресурса доступна [по ссылке](https://api.kinopoisk.dev/documentation). Давайте откроем и ознакомимся с ней.

# %%
import requests
import json

# %% [markdown]
# ### Подготовка
#
# Для начала в рамках подготовки получите свой персональный API-ключ. Инструкция о том, как это сделать, представлена на сайте.

# %%
API_key = "### enter your key here"

# %% [markdown]
# Сделаем самый базовый запрос:

# %%
page = requests.get(f'https://api.kinopoisk.dev/v1.4/movie/666', headers ={'accept': 'application/json', 'X-API-KEY': API_key})
page
# Out:
# <Response [200]>

# %% [markdown]
# Посмотрим на то, что пришло на выходе от сайта:

# %%
page.json()
# Out:
# {'id': 666,
#  'externalId': {'kpHD': '48e8d0acb0f62d8585101798eaeceec5',
#   'imdb': 'tt0232500',
#   'tmdb': 9799},
#  'name': 'Форсаж',
#  'alternativeName': 'The Fast and the Furious',
#  'enName': 'The Fast and the Furious: The Original',
#  'names': [{'name': 'Wild Speed', 'language': 'JP', 'type': 'English title'},
#   {'name': 'The Fast and the Furious (A todo gas)',
#    'language': 'ES',
#    'type': None},
#   {'name': 'Bŭrzi i yarostni', 'language': 'BG', 'type': None},
#   {'name': 'Oi Machités ton Drómon', 'language': 'GR', 'type': None},
#   {'name': 'Форсаж', 'language': 'RU', 'type': None},
#   {'name': 'Paklene ulice', 'language': 'RS', 'type': None},
#   {'name': 'Forsazh', 'language': 'UA', 'type': None},
#   {'name': '玩命關頭', 'language': 'TW', 'type': None},
#   {'name': '速度与激情', 'language': 'CN', 'type': None},
#   {'name': 'Fast & furious', 'language': 'FR', 'type': None},
#   {'name': 'Fast & Furious', 'language': 'US', 'type': None},
#   {'name': 'Quá Nhanh Quá Nguy Hiểm', 'language': 'VN', 'type': None},
#   {'name': 'ワイルド・スピード：2001', 'language': 'JP', 'type': None},
#   {'name': 'F&F1 - The Fast and the Furious',
#    'language': 'GB',
#    'type': 'sortable'},
#   {'name': '狂野時速1', 'language': 'TW', 'type': None},
#   {'name': '狂野時速1', 'language': 'HK', 'type': None},
#   {'name': 'The Fast and the Furious I',
#    'language': 'US',
#    'type': 'My personal playlist'},
#   {'name': 'Fast and Furious', 'language': 'DE', 'type': None},
#   {'name': 'Forsaj', 'language': 'AZ', 'type': None},
#   {'name': 'A todo gas: 1', 'language': 'ES', 'type': 'Castellano'},
#   {'name': 'Fast and Furious', 'language': 'US', 'type': None},
#   {'name': 'The Fast and the Furious: The Original',
#    'language': 'US',
#    'type': None},
#   {'name': 'F&F1 - The Fast And The Furious',
#    'language': 'GB',
#    'type': 'sortable'}],
#  'type': 'movie',
#  'typeNumber': 1,
#  'year': 2001,
#  'description': 'Его зовут Брайан, и он — фанатик турбин и нитроускорителей. Его цель — быть принятым в автобанду легендарного Доминика Торетто, чемпиона опасных и незаконных уличных гонок. Но это лишь часть правды… Брайан также полицейский, имеющий задание войти в доверие к Торетто, подозреваемому в причастности к дерзким грабежам трейлеров, совершенным прямо «с колес».Но чем больше доверяет нахальному новичку харизматичный Доминик, тем больше проникается герой идеалами «ангелов дорог». И тем меньше ему хочется выполнять свою миссию. И вот, наступает момент, когда Брайану придется выбирать между дружбой и долгом. И выбирать на скорости в 200 километров в час…',
#  'shortDescription': 'Коп под прикрытием внедряется в банду стритрейсеров и становится одним из них. Первая часть гоночной франшизы',
#  'slogan': '',
#  'status': None,
#  'rating': {'kp': 7.823,
#   'imdb': 6.8,
#   'filmCritics': 5.4,
#   'russianFilmCritics': 0,
#   'await': None},
#  'votes': {'kp': 417884,
#   'imdb': 429615,
#   'filmCritics': 158,
#   'russianFilmCritics': 0,
#   'await': 0},
#  'movieLength': 106,
#  'totalSeriesLength': None,
#  'seriesLength': None,
#  'ratingMpaa': 'pg13',
#  'ageRating': 18,
#  'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/6201401/8277905e-aa09-465d-b0de-7c389a42f215/orig',
#   'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/6201401/8277905e-aa09-465d-b0de-7c389a42f215/x1000'},
#  'backdrop': {'url': 'https://image.openmoviedb.com/tmdb-images/original/jY9ef5nqY4xIIMu3yzW3qamUCoi.jpg',
#   'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/jY9ef5nqY4xIIMu3yzW3qamUCoi.jpg'},
#  'genres': [{'name': 'боевик'}, {'name': 'триллер'}, {'name': 'криминал'}],
#  'countries': [{'name': 'США'}, {'name': 'Германия'}],
#  'persons': [{'id': 6317,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_6317.jpg',
#    'name': 'Пол Уокер',
#    'enName': 'Paul Walker',
#    'description': "Brian O'Conner",
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 11437,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_11437.jpg',
#    'name': 'Вин Дизель',
#    'enName': 'Vin Diesel',
#    'description': 'Dominic Toretto',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 2318,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_2318.jpg',
#    'name': 'Мишель Родригес',
#    'enName': 'Michelle Rodriguez',
#    'description': 'Letty',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 47679,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_47679.jpg',
#    'name': 'Джордана Брюстер',
#    'enName': 'Jordana Brewster',
#    'description': 'Mia Toretto',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 16059,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_16059.jpg',
#    'name': 'Мэтт Шульце',
#    'enName': 'Matt Schulze',
#    'description': 'Vince',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 29366,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_29366.jpg',
#    'name': 'Рик Юн',
#    'enName': 'Rick Yune',
#    'description': 'Johnny Tran',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 22695,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_22695.jpg',
#    'name': 'Чэд Линдберг',
#    'enName': 'Chad Lindberg',
#    'description': 'Jesse',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 47429,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_47429.jpg',
#    'name': 'Джонни Стронг',
#    'enName': 'Johnny Strong',
#    'description': 'Leon',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 532,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_532.jpg',
#    'name': 'Тед Левайн',
#    'enName': 'Ted Levine',
#    'description': 'Sgt. Tanner',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 7189,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_7189.jpg',
#    'name': 'Том Бэрри',
#    'enName': 'Thom Barry',
#    'description': 'Agent Bilkins',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 12801,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_12801.jpg',
#    'name': 'Джа Рул',
#    'enName': 'Ja Rule',
#    'description': 'Edwin',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 28017,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_28017.jpg',
#    'name': 'Вито Руджинис',
#    'enName': 'Vyto Ruginis',
#    'description': 'Harry',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 47680,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_47680.jpg',
#    'name': 'Стэнтон Рутледж',
#    'enName': 'Stanton Rutledge',
#    'description': 'Muse',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 9690,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_9690.jpg',
#    'name': 'Ноэль Гульеми',
#    'enName': 'Noel Gugliemi',
#    'description': 'Hector (в титрах: Noel Guglielmi)',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 47681,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_47681.jpg',
#    'name': 'Р.Дж. Де Вера',
#    'enName': 'RJ de Vera',
#    'description': 'Danny Yamato (в титрах: RJ De Vera)',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 15039,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_15039.jpg',
#    'name': 'Бо Холден',
#    'enName': 'Beau Holden',
#    'description': 'Ted Gassner',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 34292,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_34292.jpg',
#    'name': 'Регги Ли',
#    'enName': 'Reggie Lee',
#    'description': 'Lance Nguyen',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 22860,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_22860.jpg',
#    'name': 'Дэвид Дуглас',
#    'enName': 'David Douglas',
#    'description': 'Rasta Racer',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 39565,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_39565.jpg',
#    'name': 'Питер Нэви Туясосопо',
#    'enName': 'Peter Navy Tuiasosopo',
#    'description': 'Samoan Guard',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 52,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_52.jpg',
#    'name': 'Нил Х. Мориц',
#    'enName': 'Neal H. Moritz',
#    'description': 'Ferrari Driver',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 47682,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_47682.jpg',
#    'name': 'Дория Ансельмо',
#    'enName': 'Doria Anselmo',
#    'description': 'Ferrari Passenger (в титрах: Doria Clare Anselmo)',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 47683,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_47683.jpg',
#    'name': 'Гленн К. Ота',
#    'enName': 'Glenn K. Ota',
#    'description': "Johnny's Father",
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 31005,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_31005.jpg',
#    'name': 'Ф. Валентино Моралес',
#    'enName': 'F. Valentino Morales',
#    'description': 'Dispatcher',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 12383,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_12383.jpg',
#    'name': 'Майк Уайт',
#    'enName': 'Mike White',
#    'description': 'Night Truck Driver',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 47684,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_47684.jpg',
#    'name': 'Дэлфин Пасифик',
#    'enName': 'Delphine Pacific',
#    'description': "Racer's Edge Clerk",
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 47685,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_47685.jpg',
#    'name': 'Моника Тамайо',
#    'enName': 'Monica Tamayo',
#    'description': 'Monica',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 39626,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_39626.jpg',
#    'name': 'Меган Бэйкер',
#    'enName': 'Megan Baker',
#    'description': 'Gimel',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 47686,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_47686.jpg',
#    'name': 'Тэмми Моника Гегамиан',
#    'enName': 'Tammy Monica Gegamian',
#    'description': "Edwin's Babe",
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 33197,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_33197.jpg',
#    'name': 'Джон Доле',
#    'enName': 'John Dohle',
#    'description': 'SWAT Officer',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 1211599,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_1211599.jpg',
#    'name': 'Лу Рейс',
#    'enName': 'Lou Reyes',
#    'description': 'SWAT Officer',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 33198,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_33198.jpg',
#    'name': 'Джеймс Харт',
#    'enName': 'James Hart',
#    'description': 'SWAT Officer',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 10175109,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_10175109.jpg',
#    'name': None,
#    'enName': 'Dave Christian',
#    'description': 'SWAT Officer',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 10175110,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_10175110.jpg',
#    'name': None,
#    'enName': 'Doug Dingman',
#    'description': 'SWAT Officer',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 10175111,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_10175111.jpg',
#    'name': None,
#    'enName': 'Steve Scallon',
#    'description': 'SWAT Officer',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 10175112,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_10175112.jpg',
#    'name': None,
#    'enName': 'Mark Jackson',
#    'description': 'SWAT Officer',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 10175113,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_10175113.jpg',
#    'name': None,
#    'enName': 'Troy Thomas',
#    'description': 'SWAT Officer',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 10175114,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_10175114.jpg',
#    'name': None,
#    'enName': 'Ralph Smith',
#    'description': 'SWAT Officer',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 10175115,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_10175115.jpg',
#    'name': None,
#    'enName': 'Joe Witty',
#    'description': 'SWAT Officer',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 10175116,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_10175116.jpg',
#    'name': None,
#    'enName': 'Jaime Rubaclava',
#    'description': 'SWAT Officer',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 10175117,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_10175117.jpg',
#    'name': None,
#    'enName': 'Rick Massa',
#    'description': 'SWAT Officer',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 10175118,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_10175118.jpg',
#    'name': None,
#    'enName': 'Rick Anzaldo',
#    'description': 'SWAT Officer',
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 4052533,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_4052533.jpg',
#    'name': None,
#    'enName': 'Dan Andreiu',
#    'description': None,
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 1977,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_1977.jpg',
#    'name': 'Адам Каррера',
#    'enName': 'Adam Carrera',
#    'description': None,
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 2409,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_2409.jpg',
#    'name': 'Роб Коэн',
#    'enName': 'Rob Cohen',
#    'description': None,
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 569853,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_569853.jpg',
#    'name': 'Гари Круз',
#    'enName': 'Gary Cruz',
#    'description': None,
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 123654,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_123654.jpg',
#    'name': 'Чик Дэниел',
#    'enName': 'Chic Daniel',
#    'description': None,
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 1053331,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_1053331.jpg',
#    'name': 'Рени Гарсиа',
#    'enName': 'Renee Garcia',
#    'description': None,
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 3441044,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_3441044.jpg',
#    'name': 'Да Хань',
#    'enName': 'Da Han',
#    'description': None,
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 2644965,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_2644965.jpg',
#    'name': 'Флора Хуанг',
#    'enName': 'Flora Huang',
#    'description': None,
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 51800,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_51800.jpg',
#    'name': 'Майкл Кехо',
#    'enName': 'Michael Kehoe',
#    'description': None,
#    'profession': 'актеры',
#    'enProfession': 'actor'},
#   {'id': 449730,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_449730.jpg',
#    'name': 'Брайан Трансо',
#    'enName': 'Brian Transeau',
#    'description': None,
#    'profession': 'композиторы',
#    'enProfession': 'composer'},
#   {'id': 97862,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_97862.jpg',
#    'name': 'Вальдемар Калиновски',
#    'enName': 'Waldemar Kalinowski',
#    'description': None,
#    'profession': 'художники',
#    'enProfession': 'designer'},
#   {'id': 1996705,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_1996705.jpg',
#    'name': 'Кевин Кэвэно',
#    'enName': 'Kevin Kavanaugh',
#    'description': None,
#    'profession': 'художники',
#    'enProfession': 'designer'},
#   {'id': 1115548,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_1115548.jpg',
#    'name': 'Санья Милкович Хэйс',
#    'enName': 'Sanja Milkovic Hays',
#    'description': None,
#    'profession': 'художники',
#    'enProfession': 'designer'},
#   {'id': 1995740,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_1995740.jpg',
#    'name': 'Флоренс Фелмэн',
#    'enName': 'Florence Fellman',
#    'description': None,
#    'profession': 'художники',
#    'enProfession': 'designer'},
#   {'id': 2409,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_2409.jpg',
#    'name': 'Роб Коэн',
#    'enName': 'Rob Cohen',
#    'description': None,
#    'profession': 'режиссеры',
#    'enProfession': 'director'},
#   {'id': 1085433,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_1085433.jpg',
#    'name': 'Питер Хонесс',
#    'enName': 'Peter Honess',
#    'description': None,
#    'profession': 'монтажеры',
#    'enProfession': 'editor'},
#   {'id': 1996898,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_1996898.jpg',
#    'name': 'Даллас Пуэтт',
#    'enName': 'Dallas Puett',
#    'description': None,
#    'profession': 'монтажеры',
#    'enProfession': 'editor'},
#   {'id': 610522,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_610522.jpg',
#    'name': 'Эриксон Кор',
#    'enName': 'Ericson Core',
#    'description': None,
#    'profession': 'операторы',
#    'enProfession': 'operator'},
#   {'id': 6361,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_6361.jpg',
#    'name': 'Крейтон Беллингер',
#    'enName': 'Creighton Bellinger',
#    'description': None,
#    'profession': 'продюсеры',
#    'enProfession': 'producer'},
#   {'id': 47687,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_47687.jpg',
#    'name': 'Даг Клейборн',
#    'enName': 'Doug Claybourne',
#    'description': None,
#    'profession': 'продюсеры',
#    'enProfession': 'producer'},
#   {'id': 52,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_52.jpg',
#    'name': 'Нил Х. Мориц',
#    'enName': 'Neal H. Moritz',
#    'description': None,
#    'profession': 'продюсеры',
#    'enProfession': 'producer'},
#   {'id': 6316,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_6316.jpg',
#    'name': 'Джон Пог',
#    'enName': 'John Pogue',
#    'description': None,
#    'profession': 'продюсеры',
#    'enProfession': 'producer'},
#   {'id': 1806292,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_1806292.jpg',
#    'name': 'Дмитрий Кошмин',
#    'enName': None,
#    'description': None,
#    'profession': 'актеры дубляжа',
#    'enProfession': 'voice_actor'},
#   {'id': 1053232,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_1053232.jpg',
#    'name': 'Алексей Мясников',
#    'enName': None,
#    'description': None,
#    'profession': 'актеры дубляжа',
#    'enProfession': 'voice_actor'},
#   {'id': 1672422,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_1672422.jpg',
#    'name': 'Татьяна Весёлкина',
#    'enName': None,
#    'description': None,
#    'profession': 'актеры дубляжа',
#    'enProfession': 'voice_actor'},
#   {'id': 4118844,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_4118844.jpg',
#    'name': 'Ирина Аникина',
#    'enName': None,
#    'description': None,
#    'profession': 'актеры дубляжа',
#    'enProfession': 'voice_actor'},
#   {'id': 1040432,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_1040432.jpg',
#    'name': 'Денис Беспалый',
#    'enName': None,
#    'description': None,
#    'profession': 'актеры дубляжа',
#    'enProfession': 'voice_actor'},
#   {'id': 224608,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_224608.jpg',
#    'name': 'Борис Шувалов',
#    'enName': None,
#    'description': None,
#    'profession': 'актеры дубляжа',
#    'enProfession': 'voice_actor'},
#   {'id': 1079073,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_1079073.jpg',
#    'name': 'Андрей Бархударов',
#    'enName': None,
#    'description': None,
#    'profession': 'актеры дубляжа',
#    'enProfession': 'voice_actor'},
#   {'id': 476576,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_476576.jpg',
#    'name': 'Андрей Мерзликин',
#    'enName': None,
#    'description': None,
#    'profession': 'актеры дубляжа',
#    'enProfession': 'voice_actor'},
#   {'id': 1159780,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_1159780.jpg',
#    'name': 'Александр Груздев',
#    'enName': None,
#    'description': None,
#    'profession': 'актеры дубляжа',
#    'enProfession': 'voice_actor'},
#   {'id': 1664122,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_1664122.jpg',
#    'name': 'Виктор Бохон',
#    'enName': None,
#    'description': None,
#    'profession': 'актеры дубляжа',
#    'enProfession': 'voice_actor'},
#   {'id': 277027,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_277027.jpg',
#    'name': 'Андрей Градов',
#    'enName': None,
#    'description': None,
#    'profession': 'актеры дубляжа',
#    'enProfession': 'voice_actor'},
#   {'id': 310535,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_310535.jpg',
#    'name': 'Олег Куценко',
#    'enName': None,
#    'description': None,
#    'profession': 'актеры дубляжа',
#    'enProfession': 'voice_actor'},
#   {'id': 1616407,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_1616407.jpg',
#    'name': 'Всеволод Кузнецов',
#    'enName': None,
#    'description': None,
#    'profession': 'актеры дубляжа',
#    'enProfession': 'voice_actor'},
#   {'id': 1655599,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_1655599.jpg',
#    'name': 'Юрий Брежнев',
#    'enName': None,
#    'description': None,
#    'profession': 'актеры дубляжа',
#    'enProfession': 'voice_actor'},
#   {'id': 273498,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_273498.jpg',
#    'name': 'Михаил Тихонов',
#    'enName': None,
#    'description': None,
#    'profession': 'актеры дубляжа',
#    'enProfession': 'voice_actor'},
#   {'id': 1646298,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_1646298.jpg',
#    'name': 'Олег Вирозуб',
#    'enName': None,
#    'description': None,
#    'profession': 'актеры дубляжа',
#    'enProfession': 'voice_actor'},
#   {'id': 280829,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_280829.jpg',
#    'name': 'Юрий Маляров',
#    'enName': None,
#    'description': None,
#    'profession': 'актеры дубляжа',
#    'enProfession': 'voice_actor'},
#   {'id': 1662055,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_1662055.jpg',
#    'name': 'Елена Греб',
#    'enName': None,
#    'description': None,
#    'profession': 'актеры дубляжа',
#    'enProfession': 'voice_actor'},
#   {'id': 1650216,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_1650216.jpg',
#    'name': 'Елена Ивасишина',
#    'enName': None,
#    'description': None,
#    'profession': 'актеры дубляжа',
#    'enProfession': 'voice_actor'},
#   {'id': 231213,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_231213.jpg',
#    'name': 'Александр Новиков',
#    'enName': None,
#    'description': None,
#    'profession': 'актеры дубляжа',
#    'enProfession': 'voice_actor'},
#   {'id': 1419143,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_1419143.jpg',
#    'name': 'Дмитрий Филимонов',
#    'enName': None,
#    'description': None,
#    'profession': 'актеры дубляжа',
#    'enProfession': 'voice_actor'},
#   {'id': 47678,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_47678.jpg',
#    'name': 'Эрик Бергквист',
#    'enName': 'Erik Bergquist',
#    'description': None,
#    'profession': 'сценаристы',
#    'enProfession': 'writer'},
#   {'id': 30322,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_30322.jpg',
#    'name': 'Дэвид Эйр',
#    'enName': 'David Ayer',
#    'description': None,
#    'profession': 'сценаристы',
#    'enProfession': 'writer'},
#   {'id': 47677,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_47677.jpg',
#    'name': 'Кен Лай',
#    'enName': 'Ken Li',
#    'description': None,
#    'profession': 'сценаристы',
#    'enProfession': 'writer'},
#   {'id': 30024,
#    'photo': 'https://image.openmoviedb.com/kinopoisk-st-images//actor_iphone/iphone360_30024.jpg',
#    'name': 'Гэри Скотт Томпсон',
#    'enName': 'Gary Scott Thompson',
#    'description': None,
#    'profession': 'сценаристы',
#    'enProfession': 'writer'}],
#  'budget': {'currency': '$', 'value': 38000000},
#  'premiere': {'country': None,
#   'digital': None,
#   'cinema': None,
#   'bluray': '2009-08-04T00:00:00.000Z',
#   'dvd': '2009-03-10T00:00:00.000Z',
#   'russia': '2001-10-18T00:00:00.000Z',
#   'world': '2001-06-18T00:00:00.000Z'},
#  'sequelsAndPrequels': [{'id': 623352,
#    'name': 'Включай турбонаддув',
#    'alternativeName': 'The Turbo Charged Prelude for 2 Fast 2 Furious',
#    'enName': None,
#    'type': 'movie',
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4774061/64df0c4d-6c95-4a23-8e30-cb0a6f195e11/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4774061/64df0c4d-6c95-4a23-8e30-cb0a6f195e11/x1000'}},
#   {'id': 323,
#    'name': 'Двойной форсаж',
#    'alternativeName': '2 Fast 2 Furious',
#    'enName': None,
#    'type': 'movie',
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/6201401/a7de8b77-34a0-4b22-9574-acec6c689958/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/6201401/a7de8b77-34a0-4b22-9574-acec6c689958/x1000'}},
#   {'id': 106079,
#    'name': 'Тройной форсаж: Токийский дрифт',
#    'alternativeName': 'The Fast and the Furious: Tokyo Drift',
#    'enName': None,
#    'type': 'movie',
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4774061/93898f89-91a1-4084-a2c7-5e5deac4933a/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4774061/93898f89-91a1-4084-a2c7-5e5deac4933a/x1000'}},
#   {'id': 395978,
#    'name': 'Форсаж 4',
#    'alternativeName': 'Fast & Furious',
#    'enName': None,
#    'type': 'movie',
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4774061/a65f24e3-10db-4325-87b6-49037781ada0/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4774061/a65f24e3-10db-4325-87b6-49037781ada0/x1000'}},
#   {'id': 484718,
#    'name': 'Бандиты',
#    'alternativeName': 'Los Bandoleros',
#    'enName': None,
#    'type': 'movie',
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1629390/b22c914d-5b47-40f0-87a3-356f75cc4fb0/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1629390/b22c914d-5b47-40f0-87a3-356f75cc4fb0/x1000'}},
#   {'id': 496943,
#    'name': 'Форсаж 5',
#    'alternativeName': 'Fast Five',
#    'enName': None,
#    'type': 'movie',
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1599028/90ecc695-b927-45b4-a012-d9da7e674f52/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1599028/90ecc695-b927-45b4-a012-d9da7e674f52/x1000'}},
#   {'id': 594736,
#    'name': 'Форсаж 6',
#    'alternativeName': 'Furious 6',
#    'enName': None,
#    'type': 'movie',
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1946459/1441cd7d-a538-4724-b7f0-e131b2fdab21/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1946459/1441cd7d-a538-4724-b7f0-e131b2fdab21/x1000'}},
#   {'id': 754481,
#    'name': 'Форсаж 7',
#    'alternativeName': 'Fast & Furious 7',
#    'enName': None,
#    'type': 'movie',
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1777765/a594e007-e67b-4eab-ae03-b86192804531/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1777765/a594e007-e67b-4eab-ae03-b86192804531/x1000'}},
#   {'id': 894027,
#    'name': 'Форсаж 8',
#    'alternativeName': 'The Fate of the Furious',
#    'enName': None,
#    'type': 'movie',
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/6201401/8dd570e1-eaac-4c2b-945d-1209bc64a187/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/6201401/8dd570e1-eaac-4c2b-945d-1209bc64a187/x1000'}},
#   {'id': 964318,
#    'name': 'Форсаж 9',
#    'alternativeName': 'F9',
#    'enName': None,
#    'type': 'movie',
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4303601/8adda490-54b6-4780-86ad-d42f0aa020da/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4303601/8adda490-54b6-4780-86ad-d42f0aa020da/x1000'}},
#   {'id': 959062,
#    'name': 'Форсаж 10',
#    'alternativeName': 'Fast X',
#    'enName': None,
#    'type': 'movie',
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4774061/cb22693a-d025-4d74-81c5-11976cbf4858/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4774061/cb22693a-d025-4d74-81c5-11976cbf4858/x1000'}}],
#  'watchability': {'items': [{'name': 'Иви',
#     'logo': {'url': 'https://avatars.mds.yandex.net/get-ott/2419418/0dfd1724-848f-4725-9160-abc571f41c11/orig'},
#     'url': 'https://www.ivi.ru/watch/90291?utm_source=yandex&utm_medium=wizard'}]},
#  'top10': None,
#  'top250': 162,
#  'isSeries': False,
#  'audience': [{'count': 25500000, 'country': 'США'},
#   {'count': 1545240, 'country': 'Великобритания'},
#   {'count': 1338595, 'country': 'Германия'}],
#  'ticketsOnSale': False,
#  'lists': ['top250',
#   'top500',
#   'popular-films',
#   'hd-blockbusters',
#   'hd-revise',
#   'box-usa-all-time',
#   'box-total'],
#  'networks': None,
#  'createdAt': '2024-04-13T01:38:31.812Z',
#  'updatedAt': '2025-02-09T00:02:00.232Z',
#  'videos': {'trailers': [{'url': 'https://www.youtube.com/embed/_Oi9Ma7nxK8',
#     'name': 'Форсаж (2001) - Дублир трейлер2 Open Matte HD',
#     'site': 'youtube',
#     'type': 'TRAILER'},
#    {'url': 'https://www.youtube.com/embed/m_jWcyfjFGw',
#     'name': 'Legacy Trailer',
#     'site': 'youtube',
#     'type': 'TRAILER'},
#    {'url': 'https://www.youtube.com/embed/HRe0LVDO9zE',
#     'name': 'Trailer 2',
#     'site': 'youtube',
#     'type': 'TRAILER'},
#    {'url': 'https://www.youtube.com/embed/ZsJz2TJAPjw',
#     'name': 'Official Trailer',
#     'site': 'youtube',
#     'type': 'TRAILER'}]},
#  'fees': {'usa': {'value': 144533925, 'currency': '$'},
#   'world': {'value': 207283925, 'currency': '$'}},
#  'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/uPzO7DHR1Z3zZQExKp5X4ABUu79.png',
#   'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/uPzO7DHR1Z3zZQExKp5X4ABUu79.png'}}

# %% [markdown]
# ### Задача 1. Драмы XXI века
#
# Для начала поставим перед собой масштабную задачу получить информацию обо всех драмах XXI века.
#
# Какие поля нам для этого нужно прописать?

# %%
request =     'https://api.kinopoisk.dev/v1.4/movie?page=1&limit=100&selectFields=id&selectFields=name&selectFields=alternativeName&selectFields=enName&selectFields=type&selectFields=year&selectFields=description&selectFields=shortDescription&selectFields=movieLength&selectFields=isSeries&selectFields=ticketsOnSale&selectFields=totalSeriesLength&selectFields=seriesLength&selectFields=ratingMpaa&selectFields=ageRating&selectFields=top10&selectFields=top250&selectFields=typeNumber&selectFields=status&selectFields=names&selectFields=logo&selectFields=poster&selectFields=backdrop&selectFields=rating&selectFields=votes&selectFields=genres&selectFields=countries&selectFields=releaseYears&type=movie&year=2000-2025&genres.name=драма'

# %%
page = requests.get(request, headers ={'accept': 'application/json', 'X-API-KEY': API_key})
page
# Out:
# <Response [200]>

# %% [markdown]
# Что же мы получили?

# %%
res = page.json()
res
# Out:
# {'docs': [{'id': 7178658,
#    'name': None,
#    'alternativeName': 'One Lyfe to Life',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 7.6,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 61,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 120,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7179833,
#    'name': 'Халиса',
#    'alternativeName': 'Halisa',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 94,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'Израиль'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7178672,
#    'name': 'Социализация',
#    'alternativeName': None,
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2025,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'Россия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7158604,
#    'name': 'Камбэк',
#    'alternativeName': 'Comeback',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 4.9,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 238,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 98,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}, {'name': 'комедия'}, {'name': 'музыка'}],
#    'countries': [{'name': 'Финляндия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7158957,
#    'name': None,
#    'alternativeName': 'Quik Money',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2022,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 8.1,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 73,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 92,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}, {'name': 'комедия'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7158580,
#    'name': None,
#    'alternativeName': 'My Friends',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 92,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}, {'name': 'комедия'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7156710,
#    'name': None,
#    'alternativeName': 'Faire un enfant',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 7.2,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 59,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 19,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'короткометражка'},
#     {'name': 'драма'},
#     {'name': 'мелодрама'},
#     {'name': 'комедия'}],
#    'countries': [{'name': 'Канада'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 779578,
#    'name': None,
#    'alternativeName': 'All of Me',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2013,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 7,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 1,
#     'imdb': 32,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 54,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'документальный'}, {'name': 'драма'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7158954,
#    'name': None,
#    'alternativeName': 'Bug Man',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 7.5,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 25,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 88,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}, {'name': 'мелодрама'}, {'name': 'комедия'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 766052,
#    'name': None,
#    'alternativeName': 'Mr Invisible',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2013,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 7.8,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 88,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 14,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'короткометражка'},
#     {'name': 'триллер'},
#     {'name': 'драма'}],
#    'countries': [{'name': 'Ирландия'}, {'name': 'Великобритания'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7158958,
#    'name': None,
#    'alternativeName': 'Territory',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 93,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'ужасы'}, {'name': 'драма'}],
#    'countries': [{'name': 'США'}, {'name': 'Индия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7156704,
#    'name': None,
#    'alternativeName': 'Hatiran Yeter',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 5.4,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 201,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 138,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'Турция'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7149816,
#    'name': 'Новая песня',
#    'alternativeName': 'Chohon, dasi bureuneun norae',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2025,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 129,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10671298/c0cd9b73-fbc2-4fac-820d-b67f776e8fd7/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10671298/c0cd9b73-fbc2-4fac-820d-b67f776e8fd7/x1000'},
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7149817,
#    'name': 'Общий план',
#    'alternativeName': None,
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': 'Шесть историй о\xa0любви, карьере, опасностях и\xa0отношениях между людьми.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 5,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 99,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4716873/0160a0a4-9df6-4226-9994-3f421b2ba08c/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4716873/0160a0a4-9df6-4226-9994-3f421b2ba08c/x1000'},
#    'genres': [{'name': 'мелодрама'},
#     {'name': 'комедия'},
#     {'name': 'драма'},
#     {'name': 'триллер'}],
#    'countries': [{'name': 'Россия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7147535,
#    'name': None,
#    'alternativeName': 'DJ Ahmet',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2025,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 99,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7149897,
#    'name': None,
#    'alternativeName': 'Ghadeghan',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2022,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 4.8,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 74,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 87,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'Иран'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7149870,
#    'name': None,
#    'alternativeName': 'Car Sick',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'короткометражка'}, {'name': 'драма'}],
#    'countries': [{'name': 'Великобритания'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7145015,
#    'name': 'Раскрылась',
#    'alternativeName': None,
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2022,
#    'description': 'В ночь Хэллоуина уставшая девушка-курьер сталкивается с\xa0загадочной версией самой себя. Следуя за\xa0этим видением, она\xa0погружается в\xa0странный и\xa0пугающий мир, где\xa0реальность начинает рассыпаться.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 1,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 5,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10768063/eceaa20f-2920-4970-a094-4a806ccc3a48/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10768063/eceaa20f-2920-4970-a094-4a806ccc3a48/x1000'},
#    'genres': [{'name': 'короткометражка'}, {'name': 'драма'}],
#    'countries': [{'name': 'Россия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7145553,
#    'name': 'Пранкер',
#    'alternativeName': None,
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': '23-летний Саша мечтает прославиться на\xa0весь интернет своими пранками. Но\xa0очередной розыгрыш над\xa0близкими заканчивается трагедией, которая заставляет Сашу идти на\xa0серьезные жертвы.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 1,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 15,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'короткометражка'}, {'name': 'драма'}],
#    'countries': [{'name': 'Россия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7144330,
#    'name': None,
#    'alternativeName': 'Kronprinsen och tyrannens återkomst',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2025,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 1,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'фэнтези'},
#     {'name': 'драма'},
#     {'name': 'приключения'},
#     {'name': 'семейный'}],
#    'countries': [{'name': 'Швеция'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7145014,
#    'name': 'Все грани тебя',
#    'alternativeName': None,
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': 'Молодой человек, вынужденный остаться один в\xa0кафе и\xa0ждать возвращения своей девушки, которая пошла решать срочное дело, узнаёт много нового о\xa0себе в\xa0результате необычного происшествия и\xa0его последствий.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 2,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1898899/37d62afe-d3d0-4867-8f6e-1ea5b7ee5490/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1898899/37d62afe-d3d0-4867-8f6e-1ea5b7ee5490/x1000'},
#    'genres': [{'name': 'короткометражка'}, {'name': 'драма'}],
#    'countries': [{'name': 'Россия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7145554,
#    'name': 'Меня зовут Любовь',
#    'alternativeName': None,
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': 'Любовь\xa0—\xa0женщина среднего возраста, которая живёт в\xa0деревне вместе с\xa0родителями и\xa0семьёй брата. Последние 5\xa0лет она\xa0мечтает изменить свою жизнь, но\xa0не знает, с\xa0чего начать. В\xa0свой день рождения она\xa0загадывает желание выйти замуж. В\xa0этот же\xa0вечер она\xa0слышит в\xa0гороскопе, что\xa0нужно действовать именно сейчас, и\xa0тут же\xa0ей на\xa0глаза попадается реклама реалити-шоу «Холостях» на\xa0НВК «Саха». Любовь решается отправиться в\xa0Якутск, чтобы принять участие в\xa0шоу и\xa0найти свою вторую половинку.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 95,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 16,
#    'genres': [{'name': 'драма'}, {'name': 'комедия'}],
#    'countries': [{'name': 'Россия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7144323,
#    'name': None,
#    'alternativeName': 'Bob Trevino Likes It',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 8.1,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 1,
#     'imdb': 265,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 102,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': 'pg13',
#    'ageRating': None,
#    'genres': [{'name': 'драма'}, {'name': 'комедия'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7144720,
#    'name': 'Как бы беременна',
#    'alternativeName': 'Kinda Pregnant',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2025,
#    'description': 'Лэйни и\xa0Кейт дружат с\xa0детства. Лэйни всю\xa0жизнь мечтала о\xa0детях, но\xa0долгожданное предложение руки и\xa0сердца от\xa0возлюбленного Дэйва так\xa0и не\xa0поступает, а\xa0лучшая подруга Кейт рассказывает о\xa0своей беременности. В\xa0магазине для\xa0будущих мам\xa0продавец ошибочно принимает Лэйни за\xa0беременную, что\xa0вдохновляет её надеть фальшивый живот и\xa0притвориться, что\xa0она ждет ребенка.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 5.753,
#     'imdb': 5,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 399,
#     'imdb': 5599,
#     'filmCritics': 0,
#     'russianFilmCritics': 1,
#     'await': 0},
#    'movieLength': 97,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': 'r',
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10592371/b940323e-3c17-4a36-abc4-3a911d64ad8d/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10592371/b940323e-3c17-4a36-abc4-3a911d64ad8d/x1000'},
#    'genres': [{'name': 'драма'}, {'name': 'комедия'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7144749,
#    'name': None,
#    'alternativeName': 'Monolith',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 4,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 17,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 72,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}, {'name': 'криминал'}],
#    'countries': [{'name': 'Германия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7137793,
#    'name': 'Синица в небе',
#    'alternativeName': None,
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2020,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 29,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'короткометражка'}, {'name': 'драма'}],
#    'countries': [{'name': 'Россия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7138056,
#    'name': None,
#    'alternativeName': 'Where Was God?',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2014,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 5.8,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 144,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 89,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'документальный'}, {'name': 'драма'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7138078,
#    'name': 'Мизанабим',
#    'alternativeName': None,
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': 'Киномеханику приходится иметь дело с\xa0новыми фильмами и\xa0технологиями. Его\xa0«устаревшее» кино больше никому не\xa0нужно.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 4,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 14,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'короткометражка'}, {'name': 'драма'}],
#    'countries': [{'name': 'Россия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7137794,
#    'name': 'Обретая себя',
#    'alternativeName': None,
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Перед важными соревнованиями подающий надежды боксёр узнаёт о\xa0патологии левого глаза, грозящей слепотой.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 19,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 16,
#    'genres': [{'name': 'короткометражка'},
#     {'name': 'драма'},
#     {'name': 'спорт'}],
#    'countries': [{'name': 'Россия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7138653,
#    'name': 'Циники',
#    'alternativeName': None,
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 3,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 8,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 16,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1898899/bf136f39-f952-44b6-b58f-b74024f31c7f/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1898899/bf136f39-f952-44b6-b58f-b74024f31c7f/x1000'},
#    'genres': [{'name': 'короткометражка'},
#     {'name': 'драма'},
#     {'name': 'комедия'}],
#    'countries': [{'name': 'Россия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7128110,
#    'name': None,
#    'alternativeName': "Le syndrome de l'été sans fin",
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 8,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 1,
#     'imdb': 80,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 98,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'триллер'}, {'name': 'драма'}, {'name': 'комедия'}],
#    'countries': [{'name': 'Чехия'}, {'name': 'Франция'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7130744,
#    'name': 'Маленький роман',
#    'alternativeName': None,
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 2,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 14,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10812607/e2db6b83-9861-4c6d-a626-0c731bbb3603/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10812607/e2db6b83-9861-4c6d-a626-0c731bbb3603/x1000'},
#    'genres': [{'name': 'короткометражка'},
#     {'name': 'драма'},
#     {'name': 'мелодрама'}],
#    'countries': [{'name': 'Россия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7128207,
#    'name': None,
#    'alternativeName': 'Dirty Boy',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 8.2,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 15,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 98,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'триллер'}, {'name': 'драма'}, {'name': 'детектив'}],
#    'countries': [{'name': 'Великобритания'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7128206,
#    'name': None,
#    'alternativeName': 'Min fantastiske fremmede',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 6.2,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 89,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 101,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'Норвегия'},
#     {'name': 'Франция'},
#     {'name': 'Швеция'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7128111,
#    'name': None,
#    'alternativeName': 'Los dos hemisferios de Lucca',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2025,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 6.8,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 1,
#     'imdb': 720,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 96,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'Мексика'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7128230,
#    'name': None,
#    'alternativeName': 'Min evige sommer',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 105,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'Дания'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7129356,
#    'name': 'Перестройка',
#    'alternativeName': 'Rebuilding',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2025,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 95,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7127854,
#    'name': 'Откуда дует ветер',
#    'alternativeName': 'Where the Wind Comes From',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2025,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 100,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}, {'name': 'комедия'}],
#    'countries': [{'name': 'Тунис'}, {'name': 'Катар'}, {'name': 'Франция'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7130749,
#    'name': 'День Питера Худжара',
#    'alternativeName': "Peter Hujar's Day",
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2025,
#    'description': 'Один день из\xa0жизни известного нью-йоркского фотографа 1970-х и\xa080-х годов, о\xa0котором он\xa0рассказывает своей подруге.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 76,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}, {'name': 'биография'}, {'name': 'история'}],
#    'countries': [{'name': 'США'}, {'name': 'Германия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7127852,
#    'name': 'Рики',
#    'alternativeName': 'Ricky',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2025,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 109,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7129355,
#    'name': 'Если бы у меня были ноги, я бы тебя пнул',
#    'alternativeName': "If I Had Legs I'd Kick You",
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2025,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 113,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': 'r',
#    'ageRating': None,
#    'genres': [{'name': 'драма'}, {'name': 'комедия'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7127851,
#    'name': 'Рыба-луна и другие истории о Грин-Лейк',
#    'alternativeName': 'Sunfish and Other Stories on Green Lake',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2025,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 87,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7104936,
#    'name': None,
#    'alternativeName': 'Kangaroo Island',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 113,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}, {'name': 'комедия'}],
#    'countries': [{'name': 'Австралия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7106480,
#    'name': 'Проклятый',
#    'alternativeName': None,
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2022,
#    'description': 'Воин, возвращающийся домой после долгих странствий, пытается спасти красивую девушку, попавшую в\xa0беду в\xa0чаще леса. Это\xa0становится роковой ошибкой.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 21,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10671298/30aca0c1-38c9-4852-8833-a4f0d8e6d2de/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10671298/30aca0c1-38c9-4852-8833-a4f0d8e6d2de/x1000'},
#    'genres': [{'name': 'короткометражка'},
#     {'name': 'драма'},
#     {'name': 'фэнтези'}],
#    'countries': [{'name': 'Россия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7106979,
#    'name': 'Конвейер',
#    'alternativeName': None,
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': 'Рыбак встречает на\xa0озере свою точную копию. Попытка доказать свою уникальность грозит смертельной опасностью.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10893610/7b57a175-b887-4bc2-82d5-c0bff1bbc743/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10893610/7b57a175-b887-4bc2-82d5-c0bff1bbc743/x1000'},
#    'genres': [{'name': 'короткометражка'},
#     {'name': 'драма'},
#     {'name': 'ужасы'}],
#    'countries': [{'name': 'Россия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7106478,
#    'name': 'Маркмарта',
#    'alternativeName': None,
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': 'Молодой курьер, влюбленный в\xa0женщину старше себя, соглашается помочь ей\xa0забрать ключи от\xa0машины. Однако, получив любовь, он\xa0сразу ее\xa0теряет, ставя себя перед выбором: отпустить или\xa0бороться.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 17,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'короткометражка'},
#     {'name': 'драма'},
#     {'name': 'комедия'}],
#    'countries': [{'name': 'Россия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7104926,
#    'name': None,
#    'alternativeName': 'Gold',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 7.9,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 2,
#     'imdb': 59,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 126,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}, {'name': 'биография'}, {'name': 'спорт'}],
#    'countries': [{'name': 'Малайзия'}, {'name': 'Сингапур'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7098498,
#    'name': None,
#    'alternativeName': 'Болмаған балалық шақ',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2025,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 105,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'Казахстан'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7098675,
#    'name': 'Я с тобой задыхаюсь',
#    'alternativeName': None,
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2025,
#    'description': 'Молодая медсестра Даша готовится выйти замуж за\xa0идеального парня. Но\xa0ее девичник идет не\xa0по плану. На\xa0праздник заявляется неожиданный гость, из\xa0Москвы приходит предложение мечты, а\xa0вскоре под\xa0угрозой оказывается ее\xa0жизнь. Температура растет: окруженная страстями и\xa0экстремальными обстоятельствами Даша встает перед сложным выбором.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 74,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10812607/479e3de5-83d9-496f-9468-c20b8a7fe09a/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10812607/479e3de5-83d9-496f-9468-c20b8a7fe09a/x1000'},
#    'genres': [{'name': 'мелодрама'}, {'name': 'драма'}],
#    'countries': [{'name': 'Россия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7098593,
#    'name': None,
#    'alternativeName': 'Fierce Hunt',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 92,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'боевик'}, {'name': 'драма'}, {'name': 'криминал'}],
#    'countries': [{'name': 'Китай'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7098331,
#    'name': None,
#    'alternativeName': 'Neighbour',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2021,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 7.4,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 13,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 30,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'короткометражка'}, {'name': 'драма'}],
#    'countries': [{'name': 'Грузия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7098674,
#    'name': None,
#    'alternativeName': 'Love, Brooklyn',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2025,
#    'description': 'Не в\xa0силах выбрать между переживанием прошлого или\xa0созданием нового будущего, Роджер колеблется между отношениями с\xa0двумя разными женщинами.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 97,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7092649,
#    'name': 'Прости, детка',
#    'alternativeName': 'Sorry, Baby',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2025,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 103,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7094233,
#    'name': None,
#    'alternativeName': 'Sukkwan Island',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2025,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 114,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'Франция'},
#     {'name': 'Норвегия'},
#     {'name': 'Великобритания'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7091804,
#    'name': None,
#    'alternativeName': 'Kaçkin',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 3,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 104,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}, {'name': 'криминал'}],
#    'countries': [{'name': 'Кыргызстан'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7094847,
#    'name': 'Тезек',
#    'alternativeName': None,
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Ночью при\xa0загадочных обстоятельствах исчезает жеребец пастуха Кокпая. Вместе с\xa0отцом он\xa0отправляется на\xa0поиски коня, а\xa0чуть позже за\xa0ними уходит младшая дочь Улбала. Вскоре с\xa0членами семьи начинают происходить разные происшествия.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 7,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10703859/de70124a-1a4e-4892-820f-1e8f0ede4b39/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10703859/de70124a-1a4e-4892-820f-1e8f0ede4b39/x1000'},
#    'genres': [{'name': 'триллер'}, {'name': 'драма'}],
#    'countries': [{'name': 'Казахстан'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7094231,
#    'name': 'Омаха',
#    'alternativeName': 'Omaha',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2025,
# ...
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 25,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 12,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10592371/4a361d0d-791a-4d2a-9f5e-ce9c6b69e415/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10592371/4a361d0d-791a-4d2a-9f5e-ce9c6b69e415/x1000'},
#    'genres': [{'name': 'короткометражка'}, {'name': 'драма'}],
#    'countries': [{'name': 'Россия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 1085141,
#    'name': 'Рабея',
#    'alternativeName': 'Rabeya',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2008,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 8.1,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 29,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 105,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4483445/cf182048-468a-4b6f-8701-d2c1d4cf96f1/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4483445/cf182048-468a-4b6f-8701-d2c1d4cf96f1/x1000'},
#    'genres': [{'name': 'драма'}, {'name': 'военный'}, {'name': 'история'}],
#    'countries': [{'name': 'Бангладеш'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 1126761,
#    'name': None,
#    'alternativeName': 'Rangeen Gudhooli',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2008,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 145,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10853012/173007dd-6c29-4010-a5bd-d256491db89c/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10853012/173007dd-6c29-4010-a5bd-d256491db89c/x1000'},
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'Индия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7056650,
#    'name': None,
#    'alternativeName': 'Paula',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 4.8,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 2,
#     'imdb': 44,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 98,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'Франция'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7056587,
#    'name': 'Фейковый Арман',
#    'alternativeName': None,
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 3,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10893610/f304051e-10ed-44fb-b33b-41f23f938039/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10893610/f304051e-10ed-44fb-b33b-41f23f938039/x1000'},
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'countries': [{'name': 'Казахстан'}],
#    'genres': [{'name': 'драма'}]},
#   {'id': 7056678,
#    'name': None,
#    'alternativeName': 'A Heart for Christmas',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 7.5,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 96,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 91,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}, {'name': 'мелодрама'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7055487,
#    'name': 'Классная',
#    'alternativeName': None,
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2025,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 12,
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'Беларусь'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7056649,
#    'name': None,
#    'alternativeName': 'Detroit Burning',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2022,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 7,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 34,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 93,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'документальный'},
#     {'name': 'боевик'},
#     {'name': 'драма'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7055760,
#    'name': None,
#    'alternativeName': 'A Lien',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 7,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 25,
#     'imdb': 287,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 15,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'короткометражка'}, {'name': 'драма'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7059784,
#    'name': 'Обоюдное молчание',
#    'alternativeName': None,
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2025,
#    'description': 'Две сестры, Надя и\xa0Лия, встретившись спустя годы разлуки в\xa0старом загородном доме, пытаются восстановить связь, разрываемую обидами и\xa0невысказанными тайнами.',
#    'shortDescription': None,
#    'status': 'post-production',
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 15,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'genres': [{'name': 'короткометражка'}, {'name': 'драма'}],
#    'countries': [{'name': 'Россия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7056651,
#    'name': None,
#    'alternativeName': 'Verona',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 6,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 11,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 79,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'Канада'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7054420,
#    'name': None,
#    'alternativeName': 'Kaagaz 2',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 5.9,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 2672,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 125,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'Индия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7055759,
#    'name': None,
#    'alternativeName': 'Anuja',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 6.5,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 16,
#     'imdb': 767,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 22,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'короткометражка'}, {'name': 'драма'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7061270,
#    'name': None,
#    'alternativeName': 'Bubble & Squeak',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2025,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 95,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}, {'name': 'комедия'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7054208,
#    'name': None,
#    'alternativeName': 'Apnées',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 7.9,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 1,
#     'imdb': 68,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 17,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'короткометражка'},
#     {'name': 'триллер'},
#     {'name': 'драма'}],
#    'countries': [{'name': 'Франция'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 727471,
#    'name': None,
#    'alternativeName': 'One Night',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2012,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 5.6,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 100,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 73,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}, {'name': 'мелодрама'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7048109,
#    'name': None,
#    'alternativeName': 'Once Upon a Honeymoon',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 6.4,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 2,
#     'imdb': 19,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 109,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'}, {'name': 'мелодрама'}],
#    'countries': [{'name': 'Нигерия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'poster': {'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10671298/916b0785-ca69-4e5d-8d5b-891393598cc8/x1000',
#     'url': 'https://image.openmoviedb.com/kinopoisk-images/10671298/916b0785-ca69-4e5d-8d5b-891393598cc8/orig'}},
#   {'id': 7048153,
#    'name': 'Племя чужих',
#    'alternativeName': 'Fremmed: Det første opgør',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2025,
#    'description': 'Когда Аати и\xa0ее семья как\xa0первые фермеры прибывают в\xa0страну, которая сейчас известна как\xa0Дания, ее\xa0семью убивает местное племя охотников-собирателей. В\xa0одиночестве в\xa0огромном и\xa0жутком лесу Аати и\xa0ее брат вынуждены жить с\xa0племенем, убившим их\xa0семью, и\xa0изучать их\xa0традиции, чтобы выжить.',
#    'shortDescription': None,
#    'status': 'post-production',
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 116,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10900341/8a47471e-9a5d-4ead-862b-b022772f46cf/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10900341/8a47471e-9a5d-4ead-862b-b022772f46cf/x1000'},
#    'genres': [{'name': 'триллер'}, {'name': 'драма'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 7048182,
#    'name': 'Уроки фортепиано',
#    'alternativeName': None,
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': 'Мать Алисы договаривается об\xa0уроках музыки для\xa0дочери со\xa0своей одинокой пожилой соседкой Лидией. Она\xa0с радостью соглашается бесплатно поработать с\xa0девочкой, но\xa0Алиса оказывается подростком с\xa0непростым характером. Лидия ищет подход к\xa0девочке, а\xa0Алиса, в\xa0свою очередь, учится не\xa0отворачиваться от\xa0своих близких, открываться миру и\xa0окружающим людям.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 3,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 22,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 12,
#    'genres': [{'name': 'короткометражка'}, {'name': 'драма'}],
#    'countries': [{'name': 'Россия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False}],
#  'total': 203672,
#  'limit': 100,
#  'page': 1,
#  'pages': 2037}

# %% [markdown]
# Посмотрим, какие ключи есть в нашем словаре, и попробуем разобраться, что каждый из них означает:

# %%
res.keys()
# Out:
# dict_keys(['docs', 'total', 'limit', 'page', 'pages'])

# %%
len(res['docs'])
# Out:
# 100

# %%
res['total'], res['limit'], res['page'], res['pages']
# Out:
# (203672, 100, 1, 2037)

# %% [markdown]
# Итого получаем следующее:
#
# - `pages` — суммарное количество страниц,
# генерирующихся по нашему запросу
# - `page` — номер текущей страницы
# - `limit` — максимальное количество документов (фильмов) на одной странице (задаётся нами)
# - `total` — суммарное количество документов (фильмов)
# - `docs` — непосредственно информация о документах (фильмах) на текущей странице

# %%
import pandas as pd

# %%
pd.DataFrame(res['docs'])['name'].head(10)
# Out:
# 0            None
# 1          Халиса
# 2    Социализация
# 3          Камбэк
# 4            None
# 5            None
# 6            None
# 7            None
# 8            None
# 9            None
# Name: name, dtype: object

# %% [markdown]
# Видим, что имеется много какого-то мусора, но очистить его в масштабах всех 2000 страниц мы пока что не в состоянии. Давайте попробуем снизить наши запросы

# %% [markdown]
# ### Задача 2. Фантастика 2023-го
#
# Окей, предположим мы хотим вывести все фантастические фильмы за 2023 год, снятые в США и/или Великобритании. Пусть будет такой, более скромный запрос.

# %% [markdown]
# Подготовку будем вести уже более автоматизированным образом и пропишем отдельными переменными ключевые для нас вещи:

# %%
genres = ['фантастика','фэнтези']
countries = ['США', "Великобритания"]
page_id = 1

request = f'https://api.kinopoisk.dev/v1.4/movie?page={page_id}&limit=100&selectFields=id&selectFields=name&selectFields=alternativeName&selectFields=enName&selectFields=type&selectFields=year&selectFields=description&selectFields=shortDescription&selectFields=movieLength&selectFields=isSeries&selectFields=ticketsOnSale&selectFields=totalSeriesLength&selectFields=seriesLength&selectFields=ratingMpaa&selectFields=ageRating&selectFields=top10&selectFields=top250&selectFields=typeNumber&selectFields=status&selectFields=names&selectFields=logo&selectFields=poster&selectFields=backdrop&selectFields=rating&selectFields=votes&selectFields=genres&selectFields=countries&selectFields=releaseYears&type=movie&year=2023&genres.name={genres[0]}&genres.name={genres[1]}&countries.name={countries[0]}&countries.name={countries[1]}'

page = requests.get(request, headers ={'accept': 'application/json', 'X-API-KEY': API_key})
page
# Out:
# <Response [200]>

# %%
res = page.json()
res
# Out:
# {'docs': [{'id': 7048397,
#    'name': None,
#    'alternativeName': 'The Hunting of the Snark',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 5.3,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 59,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 90,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'фэнтези'}, {'name': 'приключения'}],
#    'countries': [{'name': 'Великобритания'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 6641159,
#    'name': 'Война пришельцев',
#    'alternativeName': 'Alien Nemesis',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 2.1,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 3,
#     'imdb': 30,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 80,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'ужасы'}, {'name': 'фантастика'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'poster': {'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10592371/85353141-7f78-4608-a968-e5505ebeb642/x1000',
#     'url': 'https://image.openmoviedb.com/kinopoisk-images/10592371/85353141-7f78-4608-a968-e5505ebeb642/orig'}},
#   {'id': 5458632,
#    'name': None,
#    'alternativeName': 'Aliens, Atlantis and the Illuminati: The New America',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 70,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'фантастика'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 5501675,
#    'name': None,
#    'alternativeName': 'Norse Fuckers',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 3,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 143,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'genres': [{'name': 'для взрослых'}, {'name': 'фэнтези'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 5437566,
#    'name': None,
#    'alternativeName': 'Videoverse: Mixtape',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 6.3,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 8,
#     'imdb': 65,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 98,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10835644/92af00d6-e85d-435d-87fc-e15e7059b080/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10835644/92af00d6-e85d-435d-87fc-e15e7059b080/x1000'},
#    'genres': [{'name': 'фэнтези'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 6376100,
#    'name': None,
#    'alternativeName': 'Scary Tales: Dead Zone',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 2.9,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 1,
#     'imdb': 129,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 83,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'ужасы'},
#     {'name': 'фантастика'},
#     {'name': 'фэнтези'},
#     {'name': 'триллер'},
#     {'name': 'драма'},
#     {'name': 'детектив'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 6302631,
#    'name': None,
#    'alternativeName': 'Little Deaths',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 7.8,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 33,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 80,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'фантастика'},
#     {'name': 'драма'},
#     {'name': 'мелодрама'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 6056627,
#    'name': None,
#    'alternativeName': 'Outer Darkness',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 5,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 3,
#     'imdb': 33,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 93,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'фантастика'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 6090448,
#    'name': None,
#    'alternativeName': 'America Is Sinking',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 2.7,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 13,
#     'imdb': 267,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 83,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'фантастика'},
#     {'name': 'боевик'},
#     {'name': 'приключения'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 5629574,
#    'name': None,
#    'alternativeName': 'Woke',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 2.9,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 52,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'ужасы'}, {'name': 'фантастика'}, {'name': 'триллер'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 5939196,
#    'name': 'Симбиоз',
#    'alternativeName': 'Symbiosis',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 7,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 45,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'фантастика'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 5926389,
#    'name': 'Доктор Кто: Пункт назначения – Скаро',
#    'alternativeName': 'Doctor Who: Destination - Skaro',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'На планете Скаро Даврос представляет своему помощнику мистеру Каставиллиану новое смертоносное изобретение. Даврос покидает помещение, куда сразу после прилетает ТАРДИС, отрывая от прототипа клешню.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 6.7,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 26,
#     'imdb': 59,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 5,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'короткометражка'}, {'name': 'фантастика'}],
#    'countries': [{'name': 'Великобритания'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 5984212,
#    'name': 'В поисках падшего ангела',
#    'alternativeName': 'Fallen: The Search of A Broken Angel',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 7.8,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 1,
#     'imdb': 21,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'фантастика'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 5595574,
#    'name': 'Инопланетный апокалипсис',
#    'alternativeName': 'Alien Apocalypse',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 3.2,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 18,
#     'imdb': 187,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 87,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'фантастика'}, {'name': 'боевик'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 5143633,
#    'name': 'Метаморф',
#    'alternativeName': 'Shifter',
#    'enName': None,
#    'names': [{'name': 'Перевтілення', 'language': 'UA', 'type': None},
#     {'name': 'Метаморф', 'language': 'RU', 'type': None},
#     {'name': 'Shifter', 'language': 'US', 'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'После личной трагедии агент ЦРУ\xa0Тара Кройдон решается на\xa0операцию, которая должна превратить ее\xa0в суперагента. Теперь с\xa0помощью инъекций ДНК\xa0она может принимать облик любого человека. Она\xa0вездесуща и\xa0практически неуязвима. Но\xa0постепенно она\xa0осознает, что, превращаясь в\xa0других, она\xa0все больше утрачивает саму себя. Девушка начинает сомневаться в\xa0том, кто\xa0она на\xa0самом деле, каков истинный смысл ее\xa0миссий и\xa0каковы мотивы ее\xa0босса. Тара решает докопаться до\xa0правды.',
#    'shortDescription': 'Сотрудница ЦРУ обретает способность менять личности, но теряет свою. Фантастический боевик о поиске правды',
#    'status': None,
#    'rating': {'kp': 4.809,
#     'imdb': 3.6,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 1961,
#     'imdb': 123,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 105,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10893610/17e4b31b-27ed-49a1-81c0-870ddb9d60e2/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10893610/17e4b31b-27ed-49a1-81c0-870ddb9d60e2/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1652588/2a00000189f889eba2e14d7d9450f3e3f7cd/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1652588/2a00000189f889eba2e14d7d9450f3e3f7cd/x1000'},
#    'genres': [{'name': 'фантастика'}, {'name': 'боевик'}, {'name': 'триллер'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': None, 'previewUrl': None}},
#   {'id': 1424998,
#    'name': 'Пилигрим',
#    'alternativeName': 'The Nomad',
#    'enName': None,
#    'names': [{'name': 'Kill for Me', 'language': 'GB', 'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Молодая журналистка освещает шокирующую историю об\xa0убийствах священников. По\xa0мере продвижения расследования она\xa0сталкивается лицом к\xa0лицу с\xa0убийцей и\xa0начинает испытывать к\xa0нему симпатию.',
#    'shortDescription': 'Репортерша обращается за помощью к серийному убийце священников. Триллер о попытке исцелить детские травмы',
#    'status': None,
#    'rating': {'kp': 5.24,
#     'imdb': 3.5,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 3226,
#     'imdb': 123,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 84,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4774061/fe4abf28-2b5b-48c1-a126-e84af6ccde26/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4774061/fe4abf28-2b5b-48c1-a126-e84af6ccde26/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1652588/2a000001882903034102fb956f16b111497c/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1652588/2a000001882903034102fb956f16b111497c/x1000'},
#    'genres': [{'name': 'фантастика'}, {'name': 'триллер'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/7ZTWr88v8rQaJAw3SwTGRCeSz7m.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/7ZTWr88v8rQaJAw3SwTGRCeSz7m.png'}},
#   {'id': 5144007,
#    'name': 'Черный шум',
#    'alternativeName': 'Black Noise',
#    'enName': None,
#    'names': [],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Райан\xa0—\xa0глава элитной команды безопасности, отправленной на\xa0частный остров со\xa0спасательной операцией. Задача команды проста: проникнуть в\xa0указанную зону, забрать человека и\xa0покинуть остров. Но\xa0на деле все\xa0оказывается далеко не\xa0так просто. Почти сразу после прибытия наемники сталкиваются с\xa0неожиданным препятствием в\xa0виде жуткого звука, который способен влиять на\xa0мысли и\xa0действия человека. Чем\xa0больше времени команда проводит на\xa0острове, тем\xa0меньше у\xa0них шансов выбраться живыми.',
#    'shortDescription': 'Они должны спасти клиентку и не потерять рассудок на зловещем острове. Фантастический боевик о борьбе за жизнь',
#    'status': None,
#    'rating': {'kp': 4.816,
#     'imdb': 3,
#     'filmCritics': 2.3,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 6884,
#     'imdb': 2089,
#     'filmCritics': 5,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 86,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': 'r',
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10812607/2a9ddfdf-db78-4a37-9474-85e6a83c203e/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10812607/2a9ddfdf-db78-4a37-9474-85e6a83c203e/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1531675/2a0000018d17d7a6f230d616d14ffabbb171/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1531675/2a0000018d17d7a6f230d616d14ffabbb171/x1000'},
#    'genres': [{'name': 'фантастика'}, {'name': 'боевик'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/judVvo8RQFOK8M7RW3Iql4f1t9U.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/judVvo8RQFOK8M7RW3Iql4f1t9U.png'}},
#   {'id': 4948667,
#    'name': 'Нандор Фодор и говорящий мангуст',
#    'alternativeName': 'Nandor Fodor and the Talking Mongoose',
#    'enName': None,
#    'names': [{'name': '南多·福多尔和会说话的猫鼬', 'language': 'CN', 'type': None},
#     {'name': 'Nandor Fodor and the Talking Mongoose: Based on True Events',
#      'language': 'GB',
#      'type': 'On-screen title'},
#     {'name': 'The Detective: The Curious Case of Nandor Fodor and the Talking Mongoose',
#      'language': 'GB',
#      'type': 'digital title'},
#     {'name': 'The Detective',
#      'language': 'GB',
#      'type': 'short digital title'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Парапсихолог Нандор Фодор начал расследование странного происшествия на\xa0острове Мэн. Обычная британская семья Ирвингов утверждает, что\xa0на их\xa0ферме с\xa0ними связалось таинственное существо\xa0—\xa0говорящий мангуст по\xa0кличке Джефф.',
#    'shortDescription': 'Парапсихолог ищет чудо-зверя на острове Мэн. Комедийный детектив с Саймоном Пеггом по реальной истории',
#    'status': None,
#    'rating': {'kp': 5.995,
#     'imdb': 5.4,
#     'filmCritics': 5.2,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 6424,
#     'imdb': 3027,
#     'filmCritics': 34,
#     'russianFilmCritics': 1,
#     'await': 0},
#    'movieLength': 96,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': 'pg13',
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/9784475/45bf5d6e-6d2b-4706-a0a0-be0dd3e1dfc1/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/9784475/45bf5d6e-6d2b-4706-a0a0-be0dd3e1dfc1/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/224348/2a0000018d17f6c0877326edc085e3172ef3/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/224348/2a0000018d17f6c0877326edc085e3172ef3/x1000'},
#    'genres': [{'name': 'комедия'}, {'name': 'детектив'}, {'name': 'фэнтези'}],
#    'countries': [{'name': 'Великобритания'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': None, 'previewUrl': None}},
#   {'id': 4481281,
#    'name': 'Пушистая фортуна',
#    'alternativeName': 'The Furry Fortune',
#    'enName': None,
#    'names': [{'name': 'Пушистая фортуна',
#      'language': 'RU',
#      'type': 'Russian title on kinopoisk'},
#     {'name': 'The Furry Fortune',
#      'language': None,
#      'type': 'Original title on kinopoisk'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Однажды двойняшки Зои\xa0и Дэкс узнают, что\xa0их любимый пёс\xa0Назлс линяет деньгами. Узнав про\xa0такую удивительную способность, завистливый сосед тайно похищает их\xa0домашнего питомца. Зои\xa0и Дэкс разрабатывают хитрый план, чтобы спасти своего верного друга из\xa0рук злодея.',
#    'shortDescription': 'Близнецы спасают от жадного соседа своего питомца, линяющего деньгами. Волшебная комедия с очаровательным псом',
#    'status': None,
#    'rating': {'kp': 7.629,
#     'imdb': 5.4,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 8782,
#     'imdb': 151,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 86,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 6,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10592371/ff4f6dbb-d4ce-43ad-9a71-c4c644b35b23/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10592371/ff4f6dbb-d4ce-43ad-9a71-c4c644b35b23/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/239697/2a0000018cda28420368b62f69a124c81e7e/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/239697/2a0000018cda28420368b62f69a124c81e7e/x1000'},
#    'genres': [{'name': 'фэнтези'}, {'name': 'комедия'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 5318704,
#    'name': 'Крик. Ночь перед Рождеством',
#    'alternativeName': "It's a Wonderful Knife",
#    'enName': None,
#    'names': [],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'В канун Рождества убийца в\xa0костюме Рождественского ангела убил лучшую подругу и\xa0напал на\xa0брата Винни, но\xa0бесстрашная девушка прикончила злодея. Им\xa0оказался местный мэр\xa0Генри Уотерс. Год\xa0спустя никто не\xa0хочет говорить о\xa0произошедшем, Винни грустит по\xa0подруге и, когда узнаёт, что\xa0её парень ей\xa0изменяет, решает, что\xa0жизнь не\xa0удалась, и\xa0загадывает желание, чтобы она\xa0вообще не\xa0появлялась на\xa0свет. Внезапно девушка оказывается в\xa0параллельной реальности, где\xa0она не\xa0родилась, её любимый городок приходит в\xa0упадок, а\xa0распоясавшийся маньяк убил уже\xa027 человек.',
#    'shortDescription': 'Одолев маньяка, Винни попадает в другую реальность, где злодей жив. Хоррор-комедия в праздничных декорациях',
#    'status': None,
#    'rating': {'kp': 5.308,
#     'imdb': 5.2,
#     'filmCritics': 5.7,
#     'russianFilmCritics': 57.1429,
#     'await': None},
#    'votes': {'kp': 8182,
#     'imdb': 8368,
#     'filmCritics': 82,
#     'russianFilmCritics': 7,
#     'await': 0},
#    'movieLength': 87,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': 'r',
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10893610/1a5d608d-8712-499c-b8eb-6f64e9d65f4a/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10893610/1a5d608d-8712-499c-b8eb-6f64e9d65f4a/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1672343/2a0000018ccecf2b310cafcf76b25c523883/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1672343/2a0000018ccecf2b310cafcf76b25c523883/x1000'},
#    'genres': [{'name': 'ужасы'}, {'name': 'комедия'}, {'name': 'фантастика'}],
#    'countries': [{'name': 'США'},
#     {'name': 'Великобритания'},
#     {'name': 'Канада'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/uPD2Jfg4ZtT7E6mEqsAMJAKRCrt.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/uPD2Jfg4ZtT7E6mEqsAMJAKRCrt.png'}},
#   {'id': 4511979,
#    'name': 'За гранью времени',
#    'alternativeName': 'The Fearway',
#    'enName': None,
#    'names': [],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Молодая пара путешествует на\xa0своей машине по\xa0знаменитому Шоссе 66, которое проходит по\xa0Долине смерти. Вдруг они\xa0замечают за\xa0собой странного преследователя. Эта\xa0поездка станет для\xa0них настоящим закольцованным кошмаром во\xa0временной петле.',
#    'shortDescription': 'Проезжая по шоссе с дурной славой, Сара и Майкл понимают, что их преследуют. Инди-хоррор о ловушке времени',
#    'status': None,
#    'rating': {'kp': 5.355,
#     'imdb': 4.1,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 17201,
#     'imdb': 886,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 81,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4774061/f4d5578b-fcee-45a0-a879-f770c04c3f48/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4774061/f4d5578b-fcee-45a0-a879-f770c04c3f48/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1672343/2a0000018732067a5625b34f403685943523/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1672343/2a0000018732067a5625b34f403685943523/x1000'},
#    'genres': [{'name': 'ужасы'},
#     {'name': 'фантастика'},
#     {'name': 'триллер'},
#     {'name': 'детектив'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/o4wsfErVHCUYooyeD2tGNNsaPnL.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/o4wsfErVHCUYooyeD2tGNNsaPnL.png'}},
#   {'id': 5313202,
#    'name': 'Космос. Смерть. Роботы',
#    'alternativeName': 'Cosmic Chaos',
#    'enName': None,
#    'names': [{'name': 'Космос. Смерть. Роботы',
#      'language': 'RU',
#      'type': 'Russian title on kinopoisk'},
#     {'name': 'Cosmic Chaos',
#      'language': None,
#      'type': 'Original title on kinopoisk'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Бои в\xa0виртуальной реальности, выживание в\xa0постапокалиптической пустоши, советский космический корабль, подающий сигнал бедствия.',
#    'shortDescription': 'Люди будущего ищут экзопланеты и противостоят андроидам. Сай-фай-альманах для поклонников Станислава Лема',
#    'status': None,
#    'rating': {'kp': 5.667,
#     'imdb': 4.8,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 25715,
#     'imdb': 101,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 87,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10809116/1dfcea16-d04c-4083-8cdc-022797dab143/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10809116/1dfcea16-d04c-4083-8cdc-022797dab143/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1648503/2a0000018a231c9d0f52c38042153b864607/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1648503/2a0000018a231c9d0f52c38042153b864607/x1000'},
#    'genres': [{'name': 'фантастика'}, {'name': 'триллер'}],
#    'countries': [{'name': 'Канада'},
#     {'name': 'США'},
#     {'name': 'Великобритания'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 1389732,
#    'name': 'Война миров: Вторжение',
#    'alternativeName': 'War of the Worlds: The Attack',
#    'enName': None,
#    'names': [{'name': 'La guerra de los mundos: El ataque',
#      'language': 'ES',
#      'type': None},
#     {'name': '世界之战：入侵', 'language': 'CN', 'type': None},
#     {'name': "La guerre des mondes L'invasion",
#      'language': 'FR',
#      'type': None},
#     {'name': "La guerre des mondes, L'invasion",
#      'language': 'FR',
#      'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Студенты-астрономы Герберт, Огилви и\xa0Ханна отправляются на\xa0поиски метеорита, упавшего где-то в\xa0британской глуши. Вскоре они\xa0выясняют, что\xa0гость из\xa0космоса\xa0—\xa0это не\xa0метеорит, а\xa0корабль пришельцев и\xa0предвестник инопланетного вторжения. Друзья оказываются в\xa0эпицентре военных действий, где\xa0с одной стороны\xa0—\xa0земные войска, а\xa0с другой\xa0—\xa0смертоносные боевые машины марсиан.',
#    'shortDescription': 'Трое друзей оказываются перед лицом инопланетной атаки. Британский сай-фай по мотивам романа Герберта Уэллса',
#    'status': None,
#    'rating': {'kp': 4.836,
#     'imdb': 3.2,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 23059,
#     'imdb': 3144,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 83,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 12,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/6201401/78d5e258-f99f-451a-bba3-01af0d8be747/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/6201401/78d5e258-f99f-451a-bba3-01af0d8be747/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1534341/2a000001879fdd1ba77844d48653f1482a8b/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1534341/2a000001879fdd1ba77844d48653f1482a8b/x1000'},
#    'genres': [{'name': 'фантастика'}, {'name': 'триллер'}],
#    'countries': [{'name': 'Великобритания'}, {'name': 'Канада'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/v4WHkhpw7zQ9WkTAEFqZqfrcENo.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/v4WHkhpw7zQ9WkTAEFqZqfrcENo.png'}},
#   {'id': 4546898,
#    'name': 'Ограбление из будущего',
#    'alternativeName': 'The Tomorrow Job',
#    'enName': None,
#    'names': [{'name': '偷天换未来', 'language': 'CN', 'type': '动作、科幻、悬疑'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Команда киберпреступников использует пилюли, которые позволяют связаться со\xa0своим сознанием в\xa0будущем на\xa01 час. Благодаря этому они\xa0воруют секреты завтрашнего дня.',
#    'shortDescription': 'Преступники совершают дерзкие кражи, перемещая свое сознание в будущее. Боевик для фанатов «Начала»',
#    'status': None,
#    'rating': {'kp': 5.778,
#     'imdb': 4.6,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 27024,
#     'imdb': 1349,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 104,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4303601/3feab301-35fc-4a60-a4b0-cb607eb269bc/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4303601/3feab301-35fc-4a60-a4b0-cb607eb269bc/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1648503/2a0000018a98d43f81044e1f2ea3d27a3158/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1648503/2a0000018a98d43f81044e1f2ea3d27a3158/x1000'},
#    'genres': [{'name': 'боевик'}, {'name': 'фантастика'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/ndJg8Ep5N9k8uEjkENGXzaLaBxA.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/ndJg8Ep5N9k8uEjkENGXzaLaBxA.png'}},
#   {'id': 4749261,
#    'name': 'Хвостатые пришельцы',
#    'alternativeName': 'Space Pups',
#    'enName': None,
#    'names': [],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Брат и\xa0сестра вместе со\xa0своими родителями помогают троице пришельцев из\xa0далекого космоса. Пытаясь избежать внимания и\xa0скрыться от\xa0охотника за\xa0НЛО, инопланетяне принимают облик милых земных собак. С\xa0помощью новых друзей хвостатые пришельцы должны преодолеть много препятствий, чтобы починить свой корабль и\xa0вернуться домой.',
#    'shortDescription': 'Жители далекой планеты притворяются собаками, спасаясь от земных спецслужб. Комедия в духе «Инопланетянина»',
#    'status': None,
#    'rating': {'kp': 7.581,
#     'imdb': 4.9,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 30283,
#     'imdb': 323,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 91,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': 'g',
#    'ageRating': 6,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10592371/d84ec48d-eddf-4ad0-b194-e716d11e287d/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10592371/d84ec48d-eddf-4ad0-b194-e716d11e287d/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1652588/2a00000189f9233d96a7f3d54ce2d694b97b/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1652588/2a00000189f9233d96a7f3d54ce2d694b97b/x1000'},
#    'genres': [{'name': 'фантастика'},
#     {'name': 'приключения'},
#     {'name': 'семейный'}],
#    'countries': [{'name': 'США'}, {'name': 'Таиланд'}, {'name': 'Бразилия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': None, 'previewUrl': None}},
#   {'id': 975402,
#    'name': 'Рубеж выживания',
#    'alternativeName': 'Last Sentinel',
#    'enName': None,
#    'names': [{'name': 'Gateway 6', 'language': 'GB', 'type': None},
#     {'name': 'Viimane vahipost', 'language': 'EE', 'type': None},
#     {'name': '六号关口', 'language': 'CN', 'type': None},
#     {'name': 'El Ultimo Centinela', 'language': 'MX', 'type': None},
#     {'name': 'Рубеж выживания', 'language': 'RU', 'type': None},
#     {'name': 'Часовой', 'language': 'RU', 'type': 'unofficial title'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Четверо специалистов, обслуживающих сверхсекретный объект, уже\xa0давно работают посреди океана без\xa0связи с\xa0внешним миром. Когда ресурсы подходят к\xa0концу, а\xa0на контакт с\xa0ними никто не\xa0выходит, напряжение начинает возрастать. Приборы показывают приближение шторма, на\xa0горизонте появляется не\xa0подающий сигналов корабль. Команда начинает подозревать, что\xa0оказалась пешкой в\xa0чьей-то зловещей игре. Чтобы выбраться из\xa0ловушки и\xa0выжить, им\xa0придется разгадать тайну последнего рубежа.',
#    'shortDescription': 'Дозорные заперты на военной базе в океане из-за таинственного исчезновения сменщиков. Триллер с Кейт Босворт',
#    'status': None,
#    'rating': {'kp': 5.46,
#     'imdb': 4.9,
#     'filmCritics': 0,
#     'russianFilmCritics': 33.3333,
#     'await': None},
#    'votes': {'kp': 68301,
#     'imdb': 7487,
#     'filmCritics': 0,
#     'russianFilmCritics': 3,
#     'await': 0},
#    'movieLength': 117,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4483445/70f0c5a8-251f-41c0-a60a-aececef164d3/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4483445/70f0c5a8-251f-41c0-a60a-aececef164d3/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1534341/2a00000189f8def7e63ef7c7054438622a50/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1534341/2a00000189f8def7e63ef7c7054438622a50/x1000'},
#    'genres': [{'name': 'ужасы'},
#     {'name': 'фантастика'},
#     {'name': 'триллер'},
#     {'name': 'драма'},
#     {'name': 'детектив'}],
#    'countries': [{'name': 'Великобритания'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/4rw91SdT5VCKK5YQltaNlpIYIWS.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/4rw91SdT5VCKK5YQltaNlpIYIWS.png'}},
#   {'id': 1390992,
#    'name': '(Не)идеальные роботы',
#    'alternativeName': 'Robots',
#    'enName': None,
#    'names': [{'name': 'Идеальные роботы', 'language': 'RU', 'type': None},
#     {'name': 'Double Date', 'language': 'IL', 'type': None},
#     {'name': 'Robotai', 'language': 'LT', 'type': None},
#     {'name': 'Podrabiani zakochani', 'language': 'PL', 'type': None},
#     {'name': 'Le robot qui me ressemblait', 'language': 'FR', 'type': 'AMZN'},
#     {'name': 'Роботи', 'language': 'UA', 'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Чарльз\xa0—\xa0ловелас, Элейн\xa0—\xa0охотница за\xa0деньгами состоятельных мужчин. Чтобы эффективнее достигать своих целей, они\xa0незаконным путем покупают себе роботов-двойников, которые делают за\xa0них всю\xa0предварительную работу по\xa0соблазнению клиентов. Однажды их\xa0пути пересекаются. Когда каждый должен получить свое (Чарльз\xa0—\xa0ночь любви, а\xa0Элейн\xa0—\xa0деньги), отлаженная система дает сбой. Их\xa0копии влюбляются друг в\xa0друга и\xa0решают сбежать. Чтобы не\xa0оказаться за\xa0решёткой, Элейн и\xa0Чарльзу придется объединиться и\xa0отправиться в\xa0погоню за\xa0своими двойниками-роботами.',
#    'shortDescription': 'Пара аферистов заводит роботов-двойников для охоты за наживой. Ромком с Шейлин Вудли от сценаристов «Бората»',
#    'status': None,
#    'rating': {'kp': 6.487,
#     'imdb': 5.5,
#     'filmCritics': 3.5,
#     'russianFilmCritics': 66.6667,
#     'await': None},
#    'votes': {'kp': 64435,
#     'imdb': 7945,
#     'filmCritics': 11,
#     'russianFilmCritics': 3,
#     'await': 0},
#    'movieLength': 93,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': 'r',
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/6201401/7db28b34-ab99-4fec-9457-20da264f10e1/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/6201401/7db28b34-ab99-4fec-9457-20da264f10e1/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1652588/2a000001898c43e503977e03d55d4ca63f21/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1652588/2a000001898c43e503977e03d55d4ca63f21/x1000'},
#    'genres': [{'name': 'фантастика'},
#     {'name': 'мелодрама'},
#     {'name': 'комедия'}],
#    'countries': [{'name': 'США'}, {'name': 'Германия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/153Z225ulAJeV9J3o25CD9M1T74.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/153Z225ulAJeV9J3o25CD9M1T74.png'}},
#   {'id': 4946926,
#    'name': '57 секунд',
#    'alternativeName': '57 Seconds',
#    'enName': None,
#    'names': [{'name': '۵۷ ثانیه', 'language': 'IR', 'type': None},
#     {'name': '57초', 'language': 'KR', 'type': None},
#     {'name': '57 vteřin', 'language': 'CZ', 'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Техноблогер Франклин случайно предотвращает покушение на\xa0известного визионера и\xa0инновационного гуру, достигшего невероятных успехов в\xa0сфере медицины. Подобрав оброненное им\xa0кольцо, молодой человек обнаруживает, что\xa0оно дает своему носителю возможность переноситься в\xa0прошлое на\xa057 секунд. Франклин решает воспользоваться находкой и\xa0с помощью чудо-кольца отомстить тем, кого он\xa0считает виновными в\xa0смерти своей сестры.',
#    'shortDescription': 'Блогер использует уникальный гаджет, чтобы отомстить за смерть сестры. Сай-фай-триллер с Джошем Хатчерсоном',
#    'status': None,
#    'rating': {'kp': 6.581,
#     'imdb': 5.4,
#     'filmCritics': 0,
#     'russianFilmCritics': 66.6667,
#     'await': None},
#    'votes': {'kp': 113939,
#     'imdb': 10880,
#     'filmCritics': 0,
#     'russianFilmCritics': 3,
#     'await': 0},
#    'movieLength': 95,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': 'r',
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1600647/3eafdbe8-9a2e-42dc-a3ca-4df4174d40e7/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1600647/3eafdbe8-9a2e-42dc-a3ca-4df4174d40e7/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/212840/2a0000018ab1e82d5cd2fd3b367fb889f47f/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/212840/2a0000018ab1e82d5cd2fd3b367fb889f47f/x1000'},
#    'genres': [{'name': 'фантастика'}, {'name': 'триллер'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/ztVBkZd1sLn6UxlMhl9fXmHgZv.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/ztVBkZd1sLn6UxlMhl9fXmHgZv.png'}},
#   {'id': 4703806,
#    'name': 'Мегалодон',
#    'alternativeName': 'The Black Demon',
#    'enName': None,
#    'names': [{'name': 'Demonio Negro', 'language': 'MX', 'type': None},
#     {'name': 'Marée noire', 'language': 'CA', 'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Пол и\xa0его семья собираются провести отпуск в\xa0райском местечке на\xa0побережье. К\xa0их удивлению, живописный и\xa0дружелюбный поселок покинут и\xa0разрушен. По\xa0ацтекским легендам, в\xa0местных водах обитает последний мегалодон\xa0—\xa0Черный демон. Он\xa0ревностно защищает природу от\xa0вторжения людей, уничтожая все\xa0на своем пути. Отправившись на\xa0прибрежную платформу в\xa0поисках ответов, семья оказывается в\xa0ловушке. И\xa0теперь Полу нужно найти способ спасти своих близких.',
#    'shortDescription': 'Гигантская акула охотится за семьей работника нефтяной вышки. Хоррор о неуловимом монстре в духе «Челюстей»',
#    'status': None,
#    'rating': {'kp': 5.483,
#     'imdb': 3.7,
#     'filmCritics': 4.2,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 112061,
#     'imdb': 10213,
#     'filmCritics': 39,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 100,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': 'r',
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4774061/819695e8-2ac9-496d-830e-edfaa166981b/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4774061/819695e8-2ac9-496d-830e-edfaa166981b/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/223007/2a00000188b4a7db2e1b3edf7d6c69d4eb2e/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/223007/2a00000188b4a7db2e1b3edf7d6c69d4eb2e/x1000'},
#    'genres': [{'name': 'ужасы'},
#     {'name': 'фантастика'},
#     {'name': 'триллер'},
#     {'name': 'драма'},
#     {'name': 'боевик'}],
#    'countries': [{'name': 'США'},
#     {'name': 'Доминикана'},
#     {'name': 'Мексика'},
#     {'name': 'Словения'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/8EQQaq40OeuDjYFoX8BzqatDQuz.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/8EQQaq40OeuDjYFoX8BzqatDQuz.png'}},
#   {'id': 5494995,
#    'name': None,
#    'alternativeName': 'Free Your Mind: The Matrix Now',
#    'enName': None,
#    'names': [{'name': 'Free Your Mind: The Matrix Now',
#      'language': None,
#      'type': 'Original title on kinopoisk'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 6.5,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 3,
#     'imdb': 35,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 81,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': None, 'previewUrl': None},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'фантастика'}],
#    'countries': [{'name': 'Великобритания'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 5462704,
#    'name': None,
#    'alternativeName': 'Mad Scientists: A.I. Maxima',
#    'enName': None,
#    'names': [{'name': 'Mad Scientists: A.I. Maxima',
#      'language': None,
#      'type': 'Original title on kinopoisk'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 9.6,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 9,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 18,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': None, 'previewUrl': None},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'короткометражка'},
#     {'name': 'фантастика'},
#     {'name': 'драма'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 5458321,
#    'name': 'Электросон',
#    'alternativeName': 'An Electric Sleep',
#    'enName': None,
#    'names': [{'name': 'Электросон',
#      'language': 'RU',
#      'type': 'Russian title on kinopoisk'},
#     {'name': 'An Electric Sleep',
#      'language': None,
#      'type': 'Original title on kinopoisk'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 4.7,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 60,
#     'imdb': 35,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10835644/86aabfe4-8813-4a52-b227-40969ec05521/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10835644/86aabfe4-8813-4a52-b227-40969ec05521/x1000'},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'фантастика'}, {'name': 'триллер'}, {'name': 'драма'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 5457979,
#    'name': None,
#    'alternativeName': 'Mythica: Stormbound',
#    'enName': None,
#    'names': [{'name': 'Mythica: Stormbound',
#      'language': None,
#      'type': 'Original title on kinopoisk'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 5.6,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 64,
#     'imdb': 206,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 104,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/9784475/9312eddd-f285-4231-8cef-6dcfe94c0f34/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/9784475/9312eddd-f285-4231-8cef-6dcfe94c0f34/x1000'},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'фэнтези'},
#     {'name': 'боевик'},
#     {'name': 'приключения'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 5457358,
#    'name': None,
#    'alternativeName': 'Hemisphere',
#    'enName': None,
#    'names': [{'name': 'Hemisphere',
#      'language': None,
#      'type': 'Original title on kinopoisk'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 4.4,
#     'filmCritics': 0,
# ...
#    'type': 'movie',
#    'typeNumber': 1,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'ratingMpaa': None,
#    'poster': {'url': None, 'previewUrl': None},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'короткометражка'}, {'name': 'фэнтези'}],
#    'countries': [{'name': 'Великобритания'}],
#    'top10': None,
#    'top250': None,
#    'releaseYears': [],
#    'year': 2023,
#    'ageRating': None,
#    'ticketsOnSale': False,
#    'movieLength': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'id': 5223766,
#    'name': None,
#    'alternativeName': 'Untitled Fashion Commercial',
#    'enName': None,
#    'names': [{'name': 'Untitled Fashion Commercial'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'ratingMpaa': None,
#    'poster': {'url': None, 'previewUrl': None},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'короткометражка'}, {'name': 'фэнтези'}],
#    'countries': [{'name': 'Великобритания'}],
#    'top10': None,
#    'top250': None,
#    'releaseYears': [],
#    'year': 2023,
#    'ageRating': None,
#    'ticketsOnSale': False,
#    'movieLength': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'id': 5220496,
#    'name': None,
#    'alternativeName': 'Echo',
#    'enName': None,
#    'names': [{'name': 'Echo'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 8.5,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 1,
#     'imdb': 6,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'ratingMpaa': None,
#    'poster': {'url': None, 'previewUrl': None},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'короткометражка'}, {'name': 'фэнтези'}],
#    'countries': [{'name': 'Великобритания'}],
#    'top10': None,
#    'top250': None,
#    'releaseYears': [],
#    'ageRating': None,
#    'year': 2023,
#    'ticketsOnSale': False,
#    'movieLength': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None,
#    'logo': {'url': None, 'previewUrl': None}},
#   {'id': 5221470,
#    'name': None,
#    'alternativeName': 'O T H E R',
#    'enName': None,
#    'names': [{'name': 'O T H E R'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'ratingMpaa': None,
#    'poster': {'url': None, 'previewUrl': None},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'короткометражка'},
#     {'name': 'ужасы'},
#     {'name': 'фантастика'}],
#    'countries': [{'name': 'Великобритания'}],
#    'top10': None,
#    'top250': None,
#    'releaseYears': [],
#    'year': 2023,
#    'ageRating': None,
#    'ticketsOnSale': False,
#    'movieLength': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'id': 5221453,
#    'name': None,
#    'alternativeName': 'Airplane - A Dreadnought Dominion film',
#    'enName': None,
#    'names': [{'name': 'Airplane - A Dreadnought Dominion film'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'description': None,
#    'shortDescription': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 12,
#    'ratingMpaa': None,
#    'poster': {'url': None, 'previewUrl': None},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'короткометражка'}, {'name': 'фантастика'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'releaseYears': [],
#    'year': 2023,
#    'ageRating': None,
#    'status': None,
#    'ticketsOnSale': False,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'id': 5220342,
#    'name': None,
#    'alternativeName': 'Square Root of Minus One',
#    'enName': None,
#    'names': [{'name': 'Square Root of Minus One'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'ratingMpaa': None,
#    'poster': {'url': None, 'previewUrl': None},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'фантастика'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'releaseYears': [],
#    'year': 2023,
#    'ageRating': None,
#    'ticketsOnSale': False,
#    'movieLength': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'id': 5218459,
#    'name': None,
#    'alternativeName': 'Loved Ones',
#    'enName': None,
#    'names': [{'name': 'Loved Ones'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 16,
#    'ratingMpaa': None,
#    'poster': {'url': None, 'previewUrl': None},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'короткометражка'},
#     {'name': 'фантастика'},
#     {'name': 'драма'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'releaseYears': [],
#    'year': 2023,
#    'ageRating': None,
#    'ticketsOnSale': False,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'id': 5213810,
#    'name': None,
#    'alternativeName': 'Creep Box',
#    'enName': None,
#    'names': [{'name': 'Creep Box'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 5.7,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 5,
#     'imdb': 52,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'ratingMpaa': None,
#    'poster': {'url': None, 'previewUrl': None},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'фантастика'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'releaseYears': [],
#    'ageRating': None,
#    'year': 2023,
#    'ticketsOnSale': False,
#    'movieLength': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'id': 5213798,
#    'name': None,
#    'alternativeName': 'The Custodian',
#    'enName': None,
#    'names': [{'name': 'The Custodian'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 1,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'ratingMpaa': None,
#    'poster': {'url': None, 'previewUrl': None},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'короткометражка'},
#     {'name': 'ужасы'},
#     {'name': 'фантастика'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'releaseYears': [],
#    'year': 2023,
#    'ageRating': None,
#    'ticketsOnSale': False,
#    'movieLength': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None,
#    'logo': {'url': None, 'previewUrl': None}},
#   {'id': 5196948,
#    'name': 'Другая реальность',
#    'alternativeName': 'The Shift',
#    'enName': None,
#    'names': [{'name': 'Na Linha de Frente', 'language': 'BR', 'type': None},
#     {'name': '轮班特工', 'language': 'CN', 'type': None},
#     {'name': 'شیفت', 'language': 'IR', 'type': None},
#     {'name': 'The Shift: El gran cambio', 'language': 'MX', 'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'description': 'После автокатастрофы Кевин оказывается в\xa0незнакомом месте, а\xa0перед собой видит человека. Загадочный незнакомец представляется Благодетелем и\xa0утверждает, что\xa0умеет «сдвигать» человека из\xa0одной параллельной вселенной в\xa0другую. Усомнившемуся в\xa0его словах Кевину вскоре предоставляются неоспоримые доказательства. Осознав, что\xa0действительно оказался в\xa0альтернативной реальности, Кевин принимается искать способы вернуться в\xa0свой мир, к\xa0жене, которая оплакивает их\xa0исчезнувшего сынишку.',
#    'shortDescription': 'Очнувшись после ДТП, Кевин попадает в иной мир — полный невзгод. Фантастическая драма с религиозным подтекстом',
#    'status': None,
#    'rating': {'kp': 6.254,
#     'imdb': 5.5,
#     'filmCritics': 5,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 5407,
#     'imdb': 5625,
#     'filmCritics': 32,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'ratingMpaa': 'pg13',
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10900341/75aa8a1d-410e-4f4f-97a9-c1630f3cd924/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10900341/75aa8a1d-410e-4f4f-97a9-c1630f3cd924/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/236744/2a0000019122eeb164d9f80036f9885d9775/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/236744/2a0000019122eeb164d9f80036f9885d9775/x1000'},
#    'genres': [{'name': 'фантастика'},
#     {'name': 'боевик'},
#     {'name': 'триллер'},
#     {'name': 'мелодрама'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'releaseYears': [],
#    'ageRating': 18,
#    'year': 2023,
#    'ticketsOnSale': False,
#    'isSeries': False,
#    'movieLength': 115,
#    'seriesLength': None,
#    'totalSeriesLength': None,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/6HlStSuyDNSNJ2QtaXnZq8oM9SA.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/6HlStSuyDNSNJ2QtaXnZq8oM9SA.png'}},
#   {'id': 5198285,
#    'name': 'Изломы разума',
#    'alternativeName': 'Jagged Mind',
#    'enName': None,
#    'names': [{'name': 'Untitled Kelley Kali Project'},
#     {'name': 'Jagged Mind'},
#     {'name': 'Изломы разума', 'language': None, 'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'description': 'Билли мучают провалы в памяти и странные видения, которые приводят ее к выводу, что она застряла в серии временных петель, возможно, связанных с ее загадочной новой подругой.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 4.4,
#     'filmCritics': 5.4,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 163,
#     'imdb': 1122,
#     'filmCritics': 16,
#     'russianFilmCritics': 1,
#     'await': 0},
#    'ratingMpaa': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10893610/8a191519-53ae-445a-abf7-e7c0972d1585/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10893610/8a191519-53ae-445a-abf7-e7c0972d1585/x1000'},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'триллер'}, {'name': 'фантастика'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'releaseYears': [],
#    'ageRating': None,
#    'year': 2023,
#    'ticketsOnSale': False,
#    'movieLength': 88,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/5Jz9Uth0IaFkdbj5qPdwkemwVor.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/5Jz9Uth0IaFkdbj5qPdwkemwVor.png'}},
#   {'id': 5204946,
#    'name': None,
#    'alternativeName': 'The Forbidden Kingdom',
#    'enName': None,
#    'names': [],
#    'type': 'movie',
#    'typeNumber': 1,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 7.4,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 1,
#     'imdb': 18,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'ratingMpaa': None,
#    'poster': {'url': None, 'previewUrl': None},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'фэнтези'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'releaseYears': [],
#    'year': 2023,
#    'ageRating': None,
#    'ticketsOnSale': False,
#    'movieLength': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'id': 5207194,
#    'name': None,
#    'alternativeName': 'ExpoZure',
#    'enName': None,
#    'names': [{'name': 'Exposure'},
#     {'name': 'ExpoZure', 'language': None, 'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'ratingMpaa': None,
#    'poster': {'url': None, 'previewUrl': None},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'короткометражка'}, {'name': 'фантастика'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'releaseYears': [],
#    'year': 2023,
#    'ageRating': None,
#    'ticketsOnSale': False,
#    'movieLength': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'id': 5192771,
#    'name': None,
#    'alternativeName': 'Legacy',
#    'enName': None,
#    'names': [],
#    'type': 'movie',
#    'typeNumber': 1,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'ratingMpaa': None,
#    'poster': {'url': None, 'previewUrl': None},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'короткометражка'},
#     {'name': 'фэнтези'},
#     {'name': 'боевик'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'releaseYears': [],
#    'year': 2023,
#    'ageRating': None,
#    'ticketsOnSale': False,
#    'movieLength': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None,
#    'logo': {'url': None}},
#   {'id': 5206674,
#    'name': None,
#    'alternativeName': 'Overseer: Rising Star',
#    'enName': None,
#    'names': [],
#    'type': 'movie',
#    'typeNumber': 1,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'ratingMpaa': None,
#    'poster': {'url': None, 'previewUrl': None},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'короткометражка'}, {'name': 'фантастика'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'releaseYears': [],
#    'year': 2023,
#    'ageRating': None,
#    'movieLength': 10,
#    'ticketsOnSale': False,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None}],
#  'total': 400,
#  'limit': 100,
#  'page': 1,
#  'pages': 4}

# %% [markdown]
# Посмотрим, что получится, если попробовать обернуть это в `pd.DataFrame`:

# %%
films_df = pd.DataFrame(res['docs'])
films_df.head(3)
# Out:
#         id              name  \
# 0  7048397              None
# 1  6641159  Война пришельцев
# 2  5458632              None
#
#                                      alternativeName enName   type  \
# 0                           The Hunting of the Snark   None  movie
# 1                                      Alien Nemesis   None  movie
# 2  Aliens, Atlantis and the Illuminati: The New A...   None  movie
#
#    typeNumber  year description shortDescription status  ...  \
# 0           1  2023        None             None   None  ...
# 1           1  2023        None             None   None  ...
# 2           1  2023        None             None   None  ...
#
#                       countries top10  top250 isSeries ticketsOnSale  \
# 0  [{'name': 'Великобритания'}]  None    None    False         False
# 1             [{'name': 'США'}]  None    None    False         False
# 2             [{'name': 'США'}]  None    None    False         False
#
#                                               poster  names backdrop logo  \
# 0                                                NaN    NaN      NaN  NaN
# 1  {'previewUrl': 'https://image.openmoviedb.com/...    NaN      NaN  NaN
# 2                                                NaN    NaN      NaN  NaN
#
#   releaseYears
# 0          NaN
# 1          NaN
# 2          NaN
#
# [3 rows x 28 columns]

# %% [markdown]
# Получилось, внезапно, очень славно — вот что означает сила словарей и их связки с Pandas'ом!
#
# Вот только опять проблема с какими-то фильмами-ноунеймами... А еще, некоторые столбцы отображаются странно. Однозначно нужно чистить!

# %%
def clean_page_columns(films_df):
    films_df['rating_kp'] = films_df['rating'].apply(lambda d: d['kp'])
    films_df['rating_imdb'] = films_df['rating'].apply(lambda d: d['imdb'])

    films_df['votes_kp'] = films_df['votes'].apply(lambda d: d['kp'])
    films_df['votes_imdb'] = films_df['votes'].apply(lambda d: d['imdb'])

    films_df['genre_upd'] = films_df['genres'].apply(lambda genres: ', '.join([genre['name'] for genre in genres]))
    films_df['countries_upd'] = films_df['countries'].apply(lambda countries: ', '.join([country['name'] for country in countries]))

    films_df.set_index('id', inplace = True)

    return films_df[['name', 'rating_kp', 'rating_imdb', 'votes_kp', 'votes_imdb', 'year', 'genre_upd', 'countries_upd', 'top250']]

# %%
def filter_noname_films(df, min_kp_votes = 500, min_imdb_votes = 500):
    df_new = df[(~(df['name'].isna())) & (df['votes_kp'] > min_kp_votes) & (df['votes_imdb'] > min_imdb_votes) & (df['rating_kp'] > 0) & (df['rating_imdb'] > 0)]
    return df_new

# %%
page = pd.DataFrame(res['docs'])
films_df_cleaned = clean_page_columns(page)
films_df_cleaned = filter_noname_films(films_df_cleaned)
films_df_cleaned.head()
# Out:
#                                      name  rating_kp  rating_imdb  votes_kp  \
# id
# 5144007                        Черный шум      4.816          3.0      6884
# 4948667  Нандор Фодор и говорящий мангуст      5.995          5.4      6424
# 5318704       Крик. Ночь перед Рождеством      5.308          5.2      8182
# 4511979                 За гранью времени      5.355          4.1     17201
# 1389732            Война миров: Вторжение      4.836          3.2     23059
#
#          votes_imdb  year                             genre_upd  \
# id
# 5144007        2089  2023                    фантастика, боевик
# 4948667        3027  2023            комедия, детектив, фэнтези
# 5318704        8368  2023            ужасы, комедия, фантастика
# 4511979         886  2023  ужасы, фантастика, триллер, детектив
# 1389732        3144  2023                   фантастика, триллер
#
#                        countries_upd top250
# id
# 5144007                          США   None
# 4948667               Великобритания   None
# 5318704  США, Великобритания, Канада   None
# 4511979                          США   None
# 1389732       Великобритания, Канада   None

# %% [markdown]
# О, уже отлично! Теперь проделаем работу в цикле!

# %%
for i in range(2, res['pages'] + 1):
    genres = ['фантастика','фэнтези']
    countries = ['США', "Великобритания"]
    page_id = i

    request = f'https://api.kinopoisk.dev/v1.4/movie?page={page_id}&limit=100&selectFields=id&selectFields=name&selectFields=alternativeName&selectFields=enName&selectFields=type&selectFields=year&selectFields=description&selectFields=shortDescription&selectFields=movieLength&selectFields=isSeries&selectFields=ticketsOnSale&selectFields=totalSeriesLength&selectFields=seriesLength&selectFields=ratingMpaa&selectFields=ageRating&selectFields=top10&selectFields=top250&selectFields=typeNumber&selectFields=status&selectFields=names&selectFields=logo&selectFields=poster&selectFields=backdrop&selectFields=rating&selectFields=votes&selectFields=genres&selectFields=countries&selectFields=releaseYears&type=movie&year=2023&genres.name={genres[0]}&genres.name={genres[1]}&countries.name={countries[0]}&countries.name={countries[1]}'

    page = requests.get(request, headers ={'accept': 'application/json', 'X-API-KEY': API_key})

    res = page.json()

    page = pd.DataFrame(res['docs'])

    page_cleaned = clean_page_columns(page)
    page_cleaned = filter_noname_films(page_cleaned)

    films_df_cleaned = pd.concat([films_df_cleaned, page_cleaned])

# %%
films_df_cleaned
# Out:
#                                                    name  rating_kp  \
# id
# 5144007                                      Черный шум      4.816
# 4948667                Нандор Фодор и говорящий мангуст      5.995
# 5318704                     Крик. Ночь перед Рождеством      5.308
# 4511979                               За гранью времени      5.355
# 1389732                          Война миров: Вторжение      4.836
# ...                                                 ...        ...
# 1017812                           Вайлет в стране чудес      5.855
# 195483                                             Флэш      6.449
# 1289334  Голодные игры: Баллада о змеях и певчих птицах      7.160
# 1319157                                        Гипнотик      6.207
# 1287544                                Капитан Марвел 2      5.215
#
#          rating_imdb  votes_kp  votes_imdb  year  \
# id
# 5144007          3.0      6884        2089  2023
# 4948667          5.4      6424        3027  2023
# 5318704          5.2      8182        8368  2023
# 4511979          4.1     17201         886  2023
# 1389732          3.2     23059        3144  2023
# ...              ...       ...         ...   ...
# 1017812          6.0      7415        4499  2023
# 195483           6.6     61170      228476  2023
# 1289334          6.7     75854      151199  2023
# 1319157          5.5     47032       40944  2023
# 1287544          5.5     36709      143588  2023
#
#                                                  genre_upd  \
# id
# 5144007                                 фантастика, боевик
# 4948667                         комедия, детектив, фэнтези
# 5318704                         ужасы, комедия, фантастика
# 4511979               ужасы, фантастика, триллер, детектив
# 1389732                                фантастика, триллер
# ...                                                    ...
# 1017812                           фэнтези, драма, семейный
# 195483            фантастика, фэнтези, боевик, приключения
# 1289334  фантастика, боевик, триллер, драма, приключени...
# 1319157              боевик, триллер, детектив, фантастика
# 1287544                    фантастика, боевик, приключения
#
#                                   countries_upd top250
# id
# 5144007                                     США   None
# 4948667                          Великобритания   None
# 5318704             США, Великобритания, Канада   None
# 4511979                                     США   None
# 1389732                  Великобритания, Канада   None
# ...                                         ...    ...
# 1017812                             Италия, США   None
# 195483   США, Канада, Австралия, Новая Зеландия   None
# 1289334                             США, Канада   None
# 1319157             США, Великобритания, Канада   None
# 1287544                                     США   None
#
# [71 rows x 9 columns]

# %% [markdown]
# Замечательно! Отсортируем теперь!

# %%
films_df_cleaned.sort_values('rating_kp', ascending = False).head(10)
# Out:
#                                                    name  rating_kp  \
# id
# 1044280                       Стражи Галактики. Часть 3      8.074
# 4396438                               Бедные-несчастные      7.632
# 762646          Подземелья и драконы: Честь среди воров      7.429
# 4830353                   Чудесная история Генри Шугара      7.417
# 1013343                                           Вонка      7.174
# 1289334  Голодные игры: Баллада о змеях и певчих птицах      7.160
# 5024991                                   Мы всем чужие      7.063
# 4985730                                Ты просто космос      6.771
# 5424484                            Рождество в Билтморе      6.686
# 4672681                                      Проблемная      6.671
#
#          rating_imdb  votes_kp  votes_imdb  year  \
# id
# 1044280          7.9    196935      416123  2023
# 4396438          7.8    109538      327259  2023
# 762646           7.2    100213      252441  2023
# 4830353          7.4     15562       78175  2023
# 1013343          7.0     84266      171804  2023
# 1289334          6.7     75854      151199  2023
# 5024991          7.6      5971       68147  2023
# 4985730          6.3      3069        3240  2023
# 5424484          7.7       511        5953  2023
# 4672681          6.8       718        7628  2023
#
#                                                  genre_upd  \
# id
# 1044280           фантастика, боевик, комедия, приключения
# 4396438                         драма, комедия, фантастика
# 762646                            фэнтези, боевик, комедия
# 4830353  короткометражка, драма, комедия, приключения, ...
# 1013343    мюзикл, фэнтези, комедия, приключения, семейный
# 1289334  фантастика, боевик, триллер, драма, приключени...
# 5024991                          драма, мелодрама, фэнтези
# 4985730                     фантастика, мелодрама, комедия
# 5424484                                 фэнтези, мелодрама
# 4672681                         комедия, драма, фантастика
#
#                                   countries_upd top250
# id
# 1044280    США, Новая Зеландия, Франция, Канада   None
# 4396438  Ирландия, Великобритания, США, Венгрия   None
# 762646                              США, Канада   None
# 4830353                     США, Великобритания   None
# 1013343             США, Великобритания, Канада   None
# 1289334                             США, Канада   None
# 5024991                     Великобритания, США   None
# 4985730                                     США   None
# 5424484                                     США   None
# 4672681                                     США   None

# %% [markdown]
# Прекрасно, наконец, что-то знакомое! :)

# %% [markdown]
# А если сделать критерии фильтрации помощнее? Чтобы прям только широкоизвестные были?

# %%
films_hype = filter_noname_films(films_df_cleaned, min_kp_votes=10000, min_imdb_votes=5000)

films_hype.sort_values('rating_kp', ascending = False).head(10)
# Out:
#                                                    name  rating_kp  \
# id
# 1044280                       Стражи Галактики. Часть 3      8.074
# 4396438                               Бедные-несчастные      7.632
# 762646          Подземелья и драконы: Честь среди воров      7.429
# 4830353                   Чудесная история Генри Шугара      7.417
# 1013343                                           Вонка      7.174
# 1289334  Голодные игры: Баллада о змеях и певчих птицах      7.160
# 4511543                               Оставь мир позади      6.589
# 4946926                                       57 секунд      6.581
# 478052                                            Барби      6.562
# 4395987                                Город астероидов      6.507
#
#          rating_imdb  votes_kp  votes_imdb  year  \
# id
# 1044280          7.9    196935      416123  2023
# 4396438          7.8    109538      327259  2023
# 762646           7.2    100213      252441  2023
# 4830353          7.4     15562       78175  2023
# 1013343          7.0     84266      171804  2023
# 1289334          6.7     75854      151199  2023
# 4511543          6.4     57607      224702  2023
# 4946926          5.4    113939       10880  2023
# 478052           6.8    214871      592509  2023
# 4395987          6.5     26610      127402  2023
#
#                                                  genre_upd  \
# id
# 1044280           фантастика, боевик, комедия, приключения
# 4396438                         драма, комедия, фантастика
# 762646                            фэнтези, боевик, комедия
# 4830353  короткометражка, драма, комедия, приключения, ...
# 1013343    мюзикл, фэнтези, комедия, приключения, семейный
# 1289334  фантастика, боевик, триллер, драма, приключени...
# 4511543                         триллер, драма, фантастика
# 4946926                                фантастика, триллер
# 478052                       комедия, приключения, фэнтези
# 4395987              фантастика, драма, мелодрама, комедия
#
#                                   countries_upd top250
# id
# 1044280    США, Новая Зеландия, Франция, Канада   None
# 4396438  Ирландия, Великобритания, США, Венгрия   None
# 762646                              США, Канада   None
# 4830353                     США, Великобритания   None
# 1013343             США, Великобритания, Канада   None
# 1289334                             США, Канада   None
# 4511543                                     США   None
# 4946926                                     США   None
# 478052                      США, Великобритания   None
# 4395987                           Германия, США   None

# %% [markdown]
# Появилась Барби :)

# %% [markdown]
# Построим визуализацию оценок на КиноПоиске и на IMDb

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.kdeplot(films_df_cleaned['rating_kp'], label = 'KP')
sns.kdeplot(films_df_cleaned['rating_imdb'], label = 'IMDb')
plt.legend()

# %%
sns.scatterplot(data = films_df_cleaned, x = 'rating_kp', y = 'rating_imdb', size = 'votes_kp')
# Out:
# <Axes: xlabel='rating_kp', ylabel='rating_imdb'>

# %%
sns.violinplot(films_df_cleaned[['rating_kp', 'rating_imdb']])
# Out:
# <Axes: >

# %% [markdown]
# ### Задача 3: Популярность корейского кино
#
# Исследовать рост популярности корейского кино за последнее десятилетие.

# %%
country = "Корея Южная"
years = "2013-2023"
page_id = 1

request = f'https://api.kinopoisk.dev/v1.4/movie?page={page_id}&limit=100&selectFields=id&selectFields=name&selectFields=alternativeName&selectFields=enName&selectFields=type&selectFields=year&selectFields=description&selectFields=shortDescription&selectFields=movieLength&selectFields=isSeries&selectFields=ticketsOnSale&selectFields=totalSeriesLength&selectFields=seriesLength&selectFields=ratingMpaa&selectFields=ageRating&selectFields=top10&selectFields=top250&selectFields=typeNumber&selectFields=status&selectFields=names&selectFields=logo&selectFields=poster&selectFields=backdrop&selectFields=rating&selectFields=votes&selectFields=genres&selectFields=countries&selectFields=releaseYears&type=movie&year={years}&countries.name={country}'

page = requests.get(request, headers ={'accept': 'application/json', 'X-API-KEY': API_key})
page
# Out:
# <Response [200]>

# %%
res = page.json()
res
# Out:
# {'docs': [{'id': 6431436,
#    'name': 'Блуждания',
#    'alternativeName': 'Mimang',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Парень встречает свою бывшую девушку.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 6.7,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 3,
#     'imdb': 66,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 92,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10768063/ddadfe8f-348e-4fd8-b764-217129b117e2/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10768063/ddadfe8f-348e-4fd8-b764-217129b117e2/x1000'},
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 5444387,
#    'name': 'Кан Даниэль: Мой парад',
#    'alternativeName': 'Kang Daniel: My Parade',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Кан Даниэль, прославившийся в\xa0качестве участника одной из\xa0самых популярных кей-поп-групп Wanna One, готовится к\xa0первому сольному концерте в\xa0Сеуле и\xa0мировому турне\xa0—\xa0много репетирует, общается с\xa0самыми близкими ему\xa0людьми, делится мыслями и\xa0мечтами.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 8.1,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 44,
#     'imdb': 24,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 102,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 12,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10592371/030c2769-6cf4-4ef8-8bc7-fa3f69aefd9e/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10592371/030c2769-6cf4-4ef8-8bc7-fa3f69aefd9e/x1000'},
#    'genres': [{'name': 'концерт'}, {'name': 'музыка'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 5379511,
#    'name': None,
#    'alternativeName': 'Caffeinated',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2015,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 6.7,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 1,
#     'imdb': 157,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 80,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'документальный'},
#     {'name': 'новости'},
#     {'name': 'приключения'}],
#    'countries': [{'name': 'США'},
#     {'name': 'Колумбия'},
#     {'name': 'Эфиопия'},
#     {'name': 'Гватемала'},
#     {'name': 'Гондурас'},
#     {'name': 'Индия'},
#     {'name': 'Италия'},
#     {'name': 'Литва'},
#     {'name': 'Мексика'},
#     {'name': 'Никарагуа'},
#     {'name': 'Корея Южная'},
#     {'name': 'Швеция'},
#     {'name': 'Швейцария'},
#     {'name': 'Турция'},
#     {'name': 'Великобритания'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 6332968,
#    'name': 'Мы не можем попасть на небеса, но мы можем любить',
#    'alternativeName': 'Urineun cheonguke gal sun eopjinam sarangeun hal su ittgettji',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 8.4,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 19,
#     'imdb': 21,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 112,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1898899/e7172905-d302-4bc4-9662-c63658679dd7/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1898899/e7172905-d302-4bc4-9662-c63658679dd7/x1000'},
#    'genres': [{'name': 'драма'}, {'name': 'мелодрама'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 6303993,
#    'name': 'Давай поженимся',
#    'alternativeName': 'Gyeolhon, hagettna?',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Молодая пара решает пожениться, но\xa0на планах ставит крест болезнь отца.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 13,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 102,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10592371/daf01831-d35c-40d3-9f64-f3f8881393f8/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10592371/daf01831-d35c-40d3-9f64-f3f8881393f8/x1000'},
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 6224942,
#    'name': 'Актёрский метод',
#    'alternativeName': 'Mesodeu yeongi',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2020,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 30,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10900341/8db8ec7a-6107-4470-a680-6c09ca91fb6a/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10900341/8db8ec7a-6107-4470-a680-6c09ca91fb6a/x1000'},
#    'genres': [{'name': 'короткометражка'}, {'name': 'комедия'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 6221713,
#    'name': None,
#    'alternativeName': 'The Night Before',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2018,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 38,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'короткометражка'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 6099740,
#    'name': 'Ложь того летнего дня',
#    'alternativeName': 'Geu yeoreumnalui geojitmal',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Сочинение старшеклассницы на\xa0тему «Как я\xa0провёл лето» вызывает у\xa0учителя множество вопросов.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 7.4,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 1,
#     'imdb': 5,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 138,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10703959/aab481d9-70f5-457a-8b67-7d7d5be8d2e1/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10703959/aab481d9-70f5-457a-8b67-7d7d5be8d2e1/x1000'},
#    'genres': [{'name': 'драма'}, {'name': 'мелодрама'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 6121900,
#    'name': 'Работа не ждёт',
#    'alternativeName': 'Haeya hal il',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Сотрудника провинциальной компании тяжёлой промышленности переводят из\xa0менеджеров в\xa0кадры и\xa0дают задание составить список работников на\xa0увольнение из-за грядущей реструктуризации.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 7.4,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 2,
#     'imdb': 8,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 100,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10900341/c4a15b50-e212-453c-b100-441f44228247/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10900341/c4a15b50-e212-453c-b100-441f44228247/x1000'},
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 6113395,
#    'name': 'Старший внук',
#    'alternativeName': 'Jangson',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Парень приезжает из\xa0города в\xa0деревню навестить семью, которая занимается изготовлением тофу.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 7.3,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 1,
#     'imdb': 60,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 121,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10812607/694a5087-31ef-4627-aa2b-7fea5945ff04/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10812607/694a5087-31ef-4627-aa2b-7fea5945ff04/x1000'},
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 6094277,
#    'name': 'О моей дочери',
#    'alternativeName': 'Ttale daehayeo',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Из-за финансовых проблем взрослая дочь приезжает жить к\xa0матери и\xa0приводит с\xa0собой свою девушку.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 7.6,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 3,
#     'imdb': 31,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 106,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10809116/a8009764-14a9-42aa-82c2-1409e1a1e654/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10809116/a8009764-14a9-42aa-82c2-1409e1a1e654/x1000'},
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 5632821,
#    'name': 'Снится ли обычной Вселенной блеск далёких звёзд?',
#    'alternativeName': 'Botongui ujuneun chanranhameul kkumkkuneunga?',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 3,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 69,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10809116/7a4e0e01-f67c-4295-8158-ddee24acb273/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10809116/7a4e0e01-f67c-4295-8158-ddee24acb273/x1000'},
#    'genres': [{'name': 'комедия'}, {'name': 'драма'}, {'name': 'фантастика'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 5613848,
#    'name': 'В конце фильма',
#    'alternativeName': 'I yeonghwaui kkeuteseo',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Режиссёр собирается снять фильм об\xa0альпинистке, которая совершает восхождение на\xa0Нангапарбат, но\xa0проект внезапно срывается. В\xa0то же\xa0время в\xa0ветклинике умирает кот\xa0режиссёра, и\xa0он отправляется в\xa0горы, чтобы похоронить питомца, а\xa0по дороге встречает женщину, которая его\xa0разыскивает. Это\xa0оказывается та\xa0самая альпинистка, о\xa0которой он\xa0хотел снять фильм.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 2,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 175,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10671298/3f97e303-bf67-4575-a35f-db53a19f997c/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10671298/3f97e303-bf67-4575-a35f-db53a19f997c/x1000'},
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 5999154,
#    'name': 'Секрет в квадрате',
#    'alternativeName': 'Bimil',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Полиция расследует серийные убийства, но\xa0улики приводят к\xa0подозреваемому, который умер 10\xa0лет назад.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 7.3,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 214,
#     'imdb': 59,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 110,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10703859/f809dce4-8443-4510-a68b-8d73fdd4451d/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10703859/f809dce4-8443-4510-a68b-8d73fdd4451d/x1000'},
#    'genres': [{'name': 'детектив'}, {'name': 'триллер'}, {'name': 'криминал'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 5503579,
#    'name': 'BTOB. Будем вместе!',
#    'alternativeName': 'BTOB TIME: Be Together the Movie',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'История кей-поп-группы BTOB на\xa0протяжении 10\xa0лет\xa0—\xa0от дебюта до\xa0поп-икон.',
#    'shortDescription': 'Звездный корейский бойз-бенд отмечает юбилей фееричным шоу. Фильм-концерт с интервью и фрагментами репетиций',
#    'status': None,
#    'rating': {'kp': 8.323,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 495,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 101,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10671298/96588530-520d-413a-b483-1e38bd3c3d78/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10671298/96588530-520d-413a-b483-1e38bd3c3d78/x1000'},
#    'genres': [{'name': 'документальный'}, {'name': 'концерт'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'backdrop': {'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/2385704/2a0000019011a401d2efed7b31567bbbd279/x1000',
#     'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/2385704/2a0000019011a401d2efed7b31567bbbd279/orig'}},
#   {'id': 5504162,
#    'name': 'Неизвестно',
#    'alternativeName': 'Mijisu',
#    'enName': None,
#    'names': [{'name': 'Неизвестно',
#      'language': 'RU',
#      'type': 'Russian title on kinopoisk'},
#     {'name': 'Mijisu',
#      'language': None,
#      'type': 'Original title on kinopoisk'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Жизни пяти людей переплетаются загадочным образом.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 4,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 69,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10893610/8de5bbd4-5c6c-4ff8-9a7e-54bbdd315a3c/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10893610/8de5bbd4-5c6c-4ff8-9a7e-54bbdd315a3c/x1000'},
#    'genres': [{'name': 'драма'}, {'name': 'фантастика'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 1265645,
#    'name': 'Большие кошки Серенгети',
#    'alternativeName': 'Big Cats of the Serengeti',
#    'enName': None,
#    'names': [{'name': 'Большие кошки Серенгети',
#      'language': 'RU',
#      'type': 'Russian title on kinopoisk'},
#     {'name': 'Big Cats of the Serengeti',
#      'language': None,
#      'type': 'Original title on kinopoisk'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2019,
#    'description': 'Серенгети\xa0—\xa0регион в\xa0Восточной Африке, в\xa0котором живёт около семидесяти видов крупных млекопитающих. Это\xa0рассказ о\xa0семьях львов и\xa0гепардов, каждая из\xa0которых ведёт борьбу за\xa0выживание в\xa0саванне. Два\xa0львёнка, родившиеся в\xa0сезон засухи, оказываются на\xa0грани голода, поскольку у\xa0их матери заканчивается молоко. Одинокий самец гепарда Мото влюбляется в\xa0Ниоту. Сначала они\xa0становятся друзьями, а\xa0после заводят семью. Но\xa0однажды Ниота исчезает, и\xa0Мото отправляется на\xa0её поиски по\xa0бескрайним африканским равнинам.',
#    'shortDescription': 'Гепарды и львы адаптируются к изменениям климата. Красочный докфильм об обитателях африканского экорегиона',
#    'status': None,
#    'rating': {'kp': 8.329,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 832,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 52,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10893610/31bf75e7-6cd3-4927-825e-c717720d1153/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10893610/31bf75e7-6cd3-4927-825e-c717720d1153/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/224348/2a0000018de572eb5b4edbea3b792b94abfc/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/224348/2a0000018de572eb5b4edbea3b792b94abfc/x1000'},
#    'genres': [{'name': 'документальный'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 5238504,
#    'name': 'Небесное захоронение',
#    'alternativeName': 'Sky Burial',
#    'enName': None,
#    'names': [{'name': 'Небесное захоронение',
#      'language': 'RU',
#      'type': 'Russian title on kinopoisk'},
#     {'name': 'Sky Burial',
#      'language': None,
#      'type': 'Original title on kinopoisk'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2014,
#    'description': 'Мальчик-монах, живущий в\xa0отдаленном районе Мустанг в\xa0Непале, совершает паломничество к\xa0своей тяжело больной бабушке.',
#    'shortDescription': 'Юный послушник отправляется в паломничество ради больной бабушки. Док о жизни и служении буддийских монахов',
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 123,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 50,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 12,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/6201401/29f4b797-5c5f-4517-b08e-3dd0f449286d/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/6201401/29f4b797-5c5f-4517-b08e-3dd0f449286d/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1534341/2a000001856758543192c7dbf9cee390d7fb/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1534341/2a000001856758543192c7dbf9cee390d7fb/x1000'},
#    'genres': [{'name': 'документальный'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 827874,
#    'name': 'Дитя любви',
#    'alternativeName': 'Love Child',
#    'enName': None,
#    'names': [{'name': 'Filha do Amor',
#      'language': 'BR',
#      'type': 'Streaming: HBO Max Brasil'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2014,
#    'description': 'История южнокорейской пары, которая настолько была погружена в онлайн-игры, что их ребенок умер от голода.',
#    'shortDescription': 'Родители сидели за компьютером, пока их ребенок умирал от голода. Док о причинах и последствиях игромании',
#    'status': None,
#    'rating': {'kp': 5.602,
#     'imdb': 5.6,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 165,
#     'imdb': 341,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 75,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1898899/256bb416-8078-4624-974e-b5603c3c3bc6/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1898899/256bb416-8078-4624-974e-b5603c3c3bc6/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/200035/2a0000016a53ecf271f1c86ddac9638736dd/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/200035/2a0000016a53ecf271f1c86ddac9638736dd/x1000'},
#    'genres': [{'name': 'документальный'}, {'name': 'биография'}],
#    'countries': [{'name': 'США'}, {'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': None, 'previewUrl': None}},
#   {'id': 5238550,
#    'name': 'Боробудур — тысячелетний миф',
#    'alternativeName': 'Borobudur — Kingdom of the Ocean Silk Road',
#    'enName': None,
#    'names': [{'name': 'Боробудур — тысячелетний миф',
#      'language': 'RU',
#      'type': 'Russian title on kinopoisk'},
#     {'name': 'Borobudur — Kingdom of the Ocean Silk Road',
#      'language': None,
#      'type': 'Original title on kinopoisk'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2014,
#    'description': 'Боробудур (Индонезия)\xa0—\xa0это каменное сооружение, в\xa0котором человечество воплотило свою мечту. Оно\xa0является всемирным наследие ЮНЕСКО с\xa01991 года. На\xa0Боробудуре изображено 10\xa0000 человек из\xa02 440\xa0племен.',
#    'shortDescription': 'Какие духовные символы изображены на камнях почитаемой буддийской святыни? Док о гигантском храмовом комплексе',
#    'status': None,
#    'rating': {'kp': 7.411,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 426,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 50,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/6201401/745bf5fb-206b-4515-93c7-8e856af4fa16/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/6201401/745bf5fb-206b-4515-93c7-8e856af4fa16/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/2439731/2a000001856564835ce9f0dd342323c632f3/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/2439731/2a000001856564835ce9f0dd342323c632f3/x1000'},
#    'genres': [{'name': 'документальный'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 5238552,
#    'name': 'Люди болот',
#    'alternativeName': 'People in Wetland',
#    'enName': None,
#    'names': [{'name': 'Люди болот',
#      'language': 'RU',
#      'type': 'Russian title on kinopoisk'},
#     {'name': 'People in Wetland',
#      'language': None,
#      'type': 'Original title on kinopoisk'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2014,
#    'description': 'Упхонып, крупнейшая водно-болотная территория в\xa0Южной Корее, славится красивым ландшафтом и\xa0богатым биоразнообразием. Поскольку Упхонып был\xa0зарегистрирован в\xa0Рамсарской конвенции, он\xa0стал резервацией, что\xa0изменило жизнь коренных жителей. Рассказ о\xa0последнем поколении коренных жителей, которые всё\xa0ещё живут на\xa0территории болот Упхонып: рыбаках, наблюдателях за\xa0окружающей средой и\xa0женщинах-дайверах.',
#    'shortDescription': 'Как живет население в заповедной природной зоне? Док о болотах Упхонып с уникальной флорой и фауной',
#    'status': None,
#    'rating': {'kp': 6.961,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 707,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 50,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 6,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4774061/5c5b2a00-514d-4472-a00c-d3c831328cb4/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4774061/5c5b2a00-514d-4472-a00c-d3c831328cb4/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1652588/2a0000018565313443a9c6bb90a31f8772a3/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1652588/2a0000018565313443a9c6bb90a31f8772a3/x1000'},
#    'genres': [{'name': 'документальный'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 1236015,
#    'name': 'Выкуп',
#    'alternativeName': 'Bigongsikjakjeon',
#    'enName': None,
#    'names': [{'name': 'Выкуп',
#      'language': 'RU',
#      'type': 'Russian title on kinopoisk'},
#     {'name': 'Bigongsikjakjeon',
#      'language': None,
#      'type': 'Original title on kinopoisk'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Конец 1980-х. Сотрудник дипломатической службы внезапно получает зашифрованное сообщение от\xa0своего похищенного коллеги, которого долгое время считали погибшим. Он\xa0решает отправиться на\xa0поиски своего сослуживца и\xa0спасти его\xa0любой ценой, вступив в\xa0смертельную схватку с\xa0отъявленными преступниками.',
#    'shortDescription': 'Южнокорейский дипломат должен спасти похищенного в Ливане коллегу. Захватывающий боевик по реальным событиям',
#    'status': None,
#    'rating': {'kp': 7.454,
#     'imdb': 6.6,
#     'filmCritics': 7.4,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 30817,
#     'imdb': 1434,
#     'filmCritics': 9,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 132,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10809116/3924b2af-06eb-449a-b955-1fad0dac22be/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10809116/3924b2af-06eb-449a-b955-1fad0dac22be/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/212840/2a0000018d3057b417c53478bdce2bf58522/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/212840/2a0000018d3057b417c53478bdce2bf58522/x1000'},
#    'genres': [{'name': 'боевик'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 5238462,
#    'name': 'Река — одиссея жизни',
#    'alternativeName': 'The River — Odyssey of Life',
#    'enName': None,
#    'names': [{'name': 'Река — одиссея жизни',
#      'language': 'RU',
#      'type': 'Russian title on kinopoisk'},
#     {'name': 'The River — Odyssey of Life',
#      'language': None,
#      'type': 'Original title on kinopoisk'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2013,
#    'description': 'Исследование флоры и\xa0фауны рек\xa0Южной Кореи на\xa0протяжении четырех времен года.',
#    'shortDescription': 'Один год из жизни речной экосистемы. Медитативный док о рыбах, птицах, земноводных и растениях Южной Кореи',
#    'status': None,
#    'rating': {'kp': 8.211,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 1402,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 50,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 12,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/6201401/9daeb1ee-733e-432a-a4bf-481d92c66fc2/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/6201401/9daeb1ee-733e-432a-a4bf-481d92c66fc2/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1531675/2a0000018567872c0ec2396ff39f54c11695/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1531675/2a0000018567872c0ec2396ff39f54c11695/x1000'},
#    'genres': [{'name': 'документальный'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 1331187,
#    'name': 'Игра киллеров',
#    'alternativeName': 'Bohoja',
#    'enName': None,
#    'names': [{'name': '保护者', 'language': 'CN', 'type': None},
#     {'name': 'Bohoja', 'language': 'SK', 'type': None},
#     {'name': 'A Man Of Reason', 'language': 'US', 'type': None},
#     {'name': 'A Man of Reason', 'language': 'DE', 'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2022,
#    'description': 'Выйдя после 10-летней отсидки, бывший киллер Су-хёк узнаёт, что\xa0у него есть дочь. Мужчина решает обрубить все\xa0свои прежние связи и\xa0начать жизнь законопослушного гражданина, но\xa0его бывший босс, теперь руководящий корпорацией, не\xa0согласен так\xa0просто отпускать ценного кадра и\xa0велит своему подчинённому присматривать за\xa0ним. Но\xa0тот, желая выслужиться, нанимает парочку отмороженных киллеров убрать Су-хёка.',
#    'shortDescription': 'Вышедший из тюрьмы наемник ищет похищенную дочь, с которой он еще не знаком. Суровый экшен из Кореи ',
#    'status': None,
#    'rating': {'kp': 6.433,
#     'imdb': 5.8,
#     'filmCritics': 4.3,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 9652,
#     'imdb': 1092,
#     'filmCritics': 8,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 98,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/9784475/b9c309ae-4eca-4fab-bf6f-56006987f036/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/9784475/b9c309ae-4eca-4fab-bf6f-56006987f036/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1648503/2a0000018d0d051594cf5bdbc1420556375d/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1648503/2a0000018d0d051594cf5bdbc1420556375d/x1000'},
#    'genres': [{'name': 'боевик'}, {'name': 'криминал'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/gsvSnuetilGFUyorw25xwJnOESE.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/gsvSnuetilGFUyorw25xwJnOESE.png'}},
#   {'id': 5326221,
#    'name': 'Невеста напрокат',
#    'alternativeName': None,
#    'enName': None,
#    'names': [{'name': 'Невеста напрокат',
#      'language': 'RU',
#      'type': 'Russian title on kinopoisk'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Группа документалистов из\xa0Южной Кореи приехала в\xa0Казахстан, чтобы снять передачу про\xa0местные свадебные традиции. Но\xa0в первый же\xa0день продюсер попадает в\xa0аварию, и\xa0группа не\xa0успевает попасть на\xa0запланированную свадьбу. Ребята оказываются без\xa0денег и\xa0без свадьбы, поэтому решают поехать в\xa0деревню и\xa0сымитировать свадьбу. Дело за\xa0малым\xa0—\xa0осталось найти жениха и\xa0невесту.',
#    'shortDescription': 'Попавшие в полосу невезения киношники устраивают поддельную свадьбу. Ироничная комедия из Казахстана и Кореи',
#    'status': None,
#    'rating': {'kp': 5.769,
#     'imdb': 6,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 2144,
#     'imdb': 9,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 82,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 12,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10671298/7e821ad0-156d-4008-88ea-a997e1bdb39d/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10671298/7e821ad0-156d-4008-88ea-a997e1bdb39d/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/212840/2a00000189bfb3465728da3fe466f016af94/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/212840/2a00000189bfb3465728da3fe466f016af94/x1000'},
#    'genres': [{'name': 'мелодрама'}, {'name': 'комедия'}],
#    'countries': [{'name': 'Казахстан'}, {'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 5025649,
#    'name': 'Реинкарнация. Картины с того света',
#    'alternativeName': 'Cracked',
#    'enName': None,
#    'names': [{'name': 'Prab Wad', 'language': 'TH', 'type': None},
#     {'name': 'Cracked', 'language': 'US', 'type': None},
#     {'name': 'Трещины', 'language': 'RU', 'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2022,
#    'description': 'После внезапного самоубийства отца, известного художника, Руджа вместе с\xa0маленькой дочерью неохотно возвращается в\xa0отчий дом, чтобы продать две\xa0картины. Женщине позарез нужны деньги на\xa0операцию слепнущей дочке, и\xa0из-за неприятных воспоминаний она\xa0хочет побыстрее завершить дела, но\xa0на картинах обнаруживаются трещины\xa0—\xa0восстановить полотна прибывает молодой художник Тим. А\xa0в доме и\xa0студии отца продолжает твориться всякая чертовщина.',
#    'shortDescription': 'Руджа получает в наследство от отца-самоубийцы зловещие полотна. Мрачный хоррор о силе материнской любви',
#    'status': None,
#    'rating': {'kp': 5.642,
#     'imdb': 5.1,
#     'filmCritics': 6,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 6173,
#     'imdb': 575,
#     'filmCritics': 5,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 93,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10809116/833d9349-436f-40cf-9608-b5e345591648/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10809116/833d9349-436f-40cf-9608-b5e345591648/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1652588/2a0000018d35a88fba3f02a7de0a8d9ed95f/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1652588/2a0000018d35a88fba3f02a7de0a8d9ed95f/x1000'},
#    'genres': [{'name': 'ужасы'}],
#    'countries': [{'name': 'Таиланд'}, {'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': None, 'previewUrl': None}},
#   {'id': 1272314,
#    'name': 'Побег из Могадишо',
#    'alternativeName': 'Mogadisyu',
#    'enName': None,
#    'names': [{'name': '탈출', 'language': 'KR', 'type': 'working title'},
#     {'name': '絕路狂逃', 'language': 'HK', 'type': None},
#     {'name': 'Escape From Mogadishu', 'language': 'HK', 'type': None},
#     {'name': 'หนีตาย โมกาดิชู', 'language': 'TH', 'type': None},
#     {'name': 'Escape from Mogadishu', 'language': 'KR', 'type': 'Daum Movie'},
#     {'name': 'Huida de Mogadiscio', 'language': 'ES', 'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2021,
#    'description': '1990 год. Ни\xa0Южная, ни\xa0Северная Корея не\xa0являются членами ООН, поэтому оба\xa0государства ведут активную работу по\xa0поиску дипломатических союзников в\xa0африканских странах, которые имеют голоса в\xa0Организации. Пока сотрудники обоих посольств в\xa0Могадишо заняты интригами и\xa0подковёрной борьбой, уже\xa010 лет\xa0продолжающаяся в\xa0Сомали гражданская война захлёстывает столицу.',
#    'shortDescription': 'Граждане Северной и Южной Кореи — в центре военного конфликта в Сомали. Драма по реальным событиям 1991 года',
#    'status': None,
#    'rating': {'kp': 7.278,
#     'imdb': 7,
#     'filmCritics': 7.4,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 10929,
#     'imdb': 7775,
#     'filmCritics': 44,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 121,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/9784475/69570312-5646-43a9-a744-56e4a8a24271/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/9784475/69570312-5646-43a9-a744-56e4a8a24271/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1531675/2a0000018cee5d2509d5c519d50b13d8c9ce/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1531675/2a0000018cee5d2509d5c519d50b13d8c9ce/x1000'},
#    'genres': [{'name': 'история'},
#     {'name': 'драма'},
#     {'name': 'военный'},
#     {'name': 'боевик'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/jp5W3WAVPFA8IDgSISHfJV9Wlxm.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/jp5W3WAVPFA8IDgSISHfJV9Wlxm.png'}},
#   {'id': 4935012,
#    'name': 'Объект преследования',
#    'alternativeName': 'Taget',
#    'enName': None,
#    'names': [{'name': '타겟', 'language': 'KR', 'type': '惊悚'},
#     {'name': 'Target', 'language': 'KR', 'type': None},
#     {'name': '目标', 'language': 'CN', 'type': '惊悚'},
#     {'name': 'ทาร์เก็ต เป้าเชือด', 'language': 'TH', 'type': None},
#     {'name': 'Объект преследования', 'language': 'RU', 'type': None},
#     {'name': '千萬別開門', 'language': 'TW', 'type': None},
#     {'name': 'Taget', 'language': 'KR', 'type': None},
#     {'name': 'Đơn hàng từ sát nhân', 'language': 'VN', 'type': None},
#     {'name': 'Alvo', 'language': 'BR', 'type': None},
#     {'name': 'Alvo', 'language': 'PT', 'type': None},
#     {'name': 'Não Compre o Vendedor', 'language': 'PT', 'type': None},
#     {'name': 'هدف', 'language': 'IR', 'type': 'TV'},
#     {'name': 'حرف فروشنده را باور نکن', 'language': 'IR', 'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Переехав в\xa0новую квартиру, Су-хён через сайт объявлений покупает подержанную стиральную машину, которая оказывается нерабочей. Обнаружив, что\xa0аккаунт продавца уже\xa0удалён, девушка обращается в\xa0полицию, а\xa0затем вычисляет мошенника по\xa0похожим объявлениям и\xa0пишет обличающие комментарии, чем\xa0вызывает гнев и\xa0становится объектом его\xa0преследования.',
#    'shortDescription': 'Разгневанный психопат мстит девушке, обвинившей его в мошенничестве. Корейский триллер о сталкере',
#    'status': None,
#    'rating': {'kp': 7.065,
#     'imdb': 6.4,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 46325,
#     'imdb': 3051,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 101,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10809116/2adaee26-62c8-4fce-b1b4-393e09e3a961/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10809116/2adaee26-62c8-4fce-b1b4-393e09e3a961/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1531675/2a0000018e08f2f8df41288ff5700effbb6b/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1531675/2a0000018e08f2f8df41288ff5700effbb6b/x1000'},
#    'genres': [{'name': 'триллер'}, {'name': 'детектив'}, {'name': 'криминал'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/jubONKrSC5eQ9YiNVOJ95xsvjVq.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/jubONKrSC5eQ9YiNVOJ95xsvjVq.png'}},
#   {'id': 5261217,
#    'name': 'Любовь без памяти',
#    'alternativeName': '30il',
#    'enName': None,
#    'names': [{'name': 'بازگشت عشق', 'language': 'IR', 'type': None},
#     {'name': '۳۰ روز', 'language': 'IR', 'type': None},
#     {'name': 'تنظیم مجدد عشق', 'language': 'AF', 'type': None},
#     {'name': '30 Days', 'language': 'US', 'type': None},
#     {'name': '30 วัน โคตร(เกลียด)เธอเลย', 'language': 'TH', 'type': None},
#     {'name': 'Yêu Lại Vợ Ngầu', 'language': 'VN', 'type': None},
#     {'name': '30天', 'language': 'CN', 'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': 'Поженившись по\xa0большой любви, теперь Чон-ёль и\xa0На-ра друг друга на\xa0дух не\xa0переносят. Они\xa0подают заявление на\xa0развод (после чего по\xa0закону должно пройти 30\xa0дней) и, продолжая ругаться за\xa0рулём, попадают в\xa0аварию, в\xa0результате которой обоим отшибает память.',
#    'shortDescription': 'Супруги решаются на развод, но теряют память из-за аварии. Яркий корейский ромком со звездой «Алхимии душ»',
#    'status': None,
#    'rating': {'kp': 7.221,
#     'imdb': 6.8,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 31460,
#     'imdb': 2243,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 120,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10893610/b212f5db-2fd1-43ac-ab2c-66d3e04caee1/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10893610/b212f5db-2fd1-43ac-ab2c-66d3e04caee1/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/200035/2a0000018e5ab407fcca4ee040844885a880/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/200035/2a0000018e5ab407fcca4ee040844885a880/x1000'},
#    'genres': [{'name': 'комедия'}, {'name': 'мелодрама'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/uOi70WCE3xYeyL0LRaWTfqkY9d4.svg',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/uOi70WCE3xYeyL0LRaWTfqkY9d4.svg'}},
#   {'id': 1378892,
#    'name': 'Битва у острова Хансан',
#    'alternativeName': 'Hansan: yongui chulhyeon',
#    'enName': None,
#    'names': [{'name': 'Hansan: Emergence of Dragon',
#      'language': 'US',
#      'type': None},
#     {'name': 'هانسان: اژدهای در حال ظهور', 'language': 'IR', 'type': None},
#     {'name': 'Hansan: Rising Dragon', 'language': 'US', 'type': None},
#     {'name': 'Hansan: Yongui chulhyeon', 'language': 'KR', 'type': None},
#     {'name': 'ฮันซัน แม่ทัพมังกร', 'language': 'TH', 'type': None},
#     {'name': 'ハンサン: 龍の出現', 'language': 'JP', 'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2022,
#    'description': '15 августа 1592 года, Имджинская война. Чосон теряет один город за\xa0другим, а\xa0флот во\xa0главе с\xa0адмиралом Ли\xa0Сунсином готовится дать бой\xa0японским захватчикам у\xa0острова Хансан. Сражение может повернуть ход\xa0войны, поэтому особые надежды адмирал возлагает на\xa0секретное оружие\xa0—\xa0бронированные корабли-черепахи с\xa0головой дракона, впоследствии прозванные японцами боккайсэн (морские чудовища).',
#    'shortDescription': 'Адмирал использует тайное оружие, чтобы изменить ход войны с Японией. Зрелищный боевик о корейском герое',
#    'status': None,
#    'rating': {'kp': 6.819,
#     'imdb': 6.6,
#     'filmCritics': 6.4,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 2394,
#     'imdb': 2250,
#     'filmCritics': 9,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 130,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4483445/e92688b2-ce1d-4b13-ac4c-cc0d474a30a5/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4483445/e92688b2-ce1d-4b13-ac4c-cc0d474a30a5/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/224348/2a0000018a7524465360951ed53ae1553806/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/224348/2a0000018a7524465360951ed53ae1553806/x1000'},
#    'genres': [{'name': 'военный'},
#     {'name': 'биография'},
#     {'name': 'боевик'},
#     {'name': 'история'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/8rwdB54zgnz1P6Qzn3koWZt1zQ4.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/8rwdB54zgnz1P6Qzn3koWZt1zQ4.png'}},
#   {'id': 1392672,
#    'name': 'Армия мёртвых в Пусане',
#    'alternativeName': 'Bangbeom: jaechaui',
#    'enName': None,
#    'names': [{'name': 'Армия мёртвых в Пусане',
#      'language': 'RU',
#      'type': 'Russian title on kinopoisk'},
#     {'name': 'Bangbeom: jaechaui',
#      'language': None,
#      'type': 'Original title on kinopoisk'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2021,
#    'description': 'Происходит серия загадочных убийств, как-то связанная с\xa0восставшими из\xa0мёртвых, которые могут ходить и\xa0говорить. Ожившими трупами явно кто-то манипулирует.',
#    'shortDescription': 'Женщины-детективы ищут некроманта, управляющего полчищем неуязвимых зомби. Сиквел фэнтези-триллера «Метод»',
#    'status': None,
#    'rating': {'kp': 6.445,
#     'imdb': 5.9,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 20974,
#     'imdb': 909,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
# ...
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1531675/2a00000176676e80fa4703de863b2e4d261b/x1000'},
#    'genres': [{'name': 'боевик'}, {'name': 'криминал'}],
#    'countries': [{'name': 'Китай'},
#     {'name': 'Гонконг'},
#     {'name': 'Индия'},
#     {'name': 'Корея Южная'},
#     {'name': 'Тайвань'},
#     {'name': 'Великобритания'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/A1cMDo1f7kQIOdnQ1BxK1psTl0J.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/A1cMDo1f7kQIOdnQ1BxK1psTl0J.png'}},
#   {'id': 1330204,
#    'name': 'Гений математики',
#    'alternativeName': 'Isanghan naraui suhakja',
#    'enName': None,
#    'names': [{'name': 'In Our Prime', 'language': 'US', 'type': None},
#     {'name': 'Isanghan naraeui suhakja', 'language': 'KR', 'type': None},
#     {'name': 'Yisanghan naraui suhakja',
#      'language': 'KR',
#      'type': 'alternative spelling'},
#     {'name': '이상한 나라의 수학자', 'language': 'KR', 'type': None},
#     {'name': 'Кращі часи', 'language': 'UA', 'type': None},
#     {'name': 'در اوج افتخار', 'language': 'IR', 'type': None},
#     {'name': 'ریاضیدانی در سرزمین عجایب', 'language': 'IR', 'type': None},
#     {'name': 'Математик в стране чудес', 'language': 'RU', 'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2022,
#    'description': 'Хан Джи-у учится в\xa0выпускном классе элитной школы со\xa0спецпрограммой, куда обычно берут детей обеспеченных родителей. Хотя сам\xa0парень из\xa0бедной семьи и\xa0попал сюда благодаря отличной успеваемости, здешняя программа по\xa0математике даётся ему\xa0с трудом. Однажды из-за дурацкой выходки Джи-у на\xa0месяц отчисляют из\xa0общежития, и, решив не\xa0расстраивать мать, парень напрашивается жить в\xa0каморке пожилого школьного охранника\xa0—\xa0перебежчика с\xa0Севера, которого ребята прозвали Коммунистическим офицером. А\xa0когда Джи-у выясняет, что\xa0тот неплохо решает самые сложные математические задачи, то\xa0уговаривает Коммунистического офицера стать своим репетитором.',
#    'shortDescription': 'Старшеклассник обращается за помощью к сбежавшему из Северной Кореи математику. Звезда «Олдбоя» в драме о дружбе',
#    'status': None,
#    'rating': {'kp': 7.833,
#     'imdb': 6.8,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 68170,
#     'imdb': 1156,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 117,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4716873/772d9760-b14d-4ef3-b4c7-a17b07f294a3/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4716873/772d9760-b14d-4ef3-b4c7-a17b07f294a3/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/374297/2a0000018867d685e0d0559caa0937ee4765/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/374297/2a0000018867d685e0d0559caa0937ee4765/x1000'},
#    'genres': [{'name': 'драма'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/jyOfBIJj87I1L4lErKl4vrVHoU5.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/jyOfBIJj87I1L4lErKl4vrVHoU5.png'}},
#   {'id': 1445078,
#    'name': 'Три',
#    'alternativeName': 'Three',
#    'enName': None,
#    'names': [{'name': 'Три',
#      'language': 'RU',
#      'type': 'Russian title on kinopoisk'},
#     {'name': 'Three',
#      'language': None,
#      'type': 'Original title on kinopoisk'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2020,
#    'description': 'Казахская ССР, 1979 год. Под\xa0руководством более опытного коллеги молодой следователь пытается вычислить маньяка-каннибала. Следствие осложняется тем, что\xa0у милиции нет\xa0опыта расследования серийных убийств, а\xa0страна готовится к\xa0проведению Олимпийских игр, и\xa0разглашение подобных дел\xa0начальству не\xa0нужно.',
#    'shortDescription': 'В канун Олимпиады в Казахстане орудует маньяк-людоед. Криминальный триллер со звездой «Нулевого пациента»',
#    'status': None,
#    'rating': {'kp': 6.366,
#     'imdb': 5.8,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 60718,
#     'imdb': 97,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 101,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4303601/4fbe8e62-a325-498c-bd17-7ef7be736ee6/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4303601/4fbe8e62-a325-498c-bd17-7ef7be736ee6/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/239697/2a000001812380fa0a9db06a96efb024d455/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/239697/2a000001812380fa0a9db06a96efb024d455/x1000'},
#    'genres': [{'name': 'детектив'}, {'name': 'триллер'}, {'name': 'криминал'}],
#    'countries': [{'name': 'Казахстан'},
#     {'name': 'Корея Южная'},
#     {'name': 'Узбекистан'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 1117379,
#    'name': 'Поменяться местами',
#    'alternativeName': 'Mon inconnue',
#    'enName': None,
#    'names': [{'name': "Ahava Mi'Mabbat Sheni", 'language': 'IL', 'type': None},
#     {'name': 'Mon Inconnue', 'language': 'FR', 'type': None},
#     {'name': '致我的陌生恋人', 'language': 'CN', 'type': None},
#     {'name': '二次情缘', 'language': 'CN', 'type': None},
#     {'name': '陌生恋人', 'language': 'CN', 'type': None},
#     {'name': 'Ricomincio da te', 'language': 'IT', 'type': None},
#     {'name': 'Love at Second Sight', 'language': 'US', 'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2019,
#    'description': 'Однажды утром он и она меняются местами. Он просыпается не успешным писателем в лучах славы, а простым учителем с непомерно завышенным эго. Его девушка, наоборот, теперь известная пианистка, которую зовет замуж крутой музыкальный продюсер. Он знает про нее все, а она - не помнит про него ничего. Чтобы разобраться в происходящем и вернуть свою прежнюю жизнь, ему нужно вновь завоевать ее сердце.',
#    'shortDescription': 'Модный писатель и живущая в его тени жена меняются ролями. Ромком о смелости начать все сначала ради любви',
#    'status': None,
#    'rating': {'kp': 7.209,
#     'imdb': 6.9,
#     'filmCritics': 4.7,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 65040,
#     'imdb': 6535,
#     'filmCritics': 8,
#     'russianFilmCritics': 1,
#     'await': 0},
#    'movieLength': 117,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1946459/9dabc46f-3c12-4eac-b06c-85bc74698e1d/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1946459/9dabc46f-3c12-4eac-b06c-85bc74698e1d/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/2439731/2a0000017801a375ad7c5264dd4b66953b98/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/2439731/2a0000017801a375ad7c5264dd4b66953b98/x1000'},
#    'genres': [{'name': 'комедия'}, {'name': 'мелодрама'}, {'name': 'фэнтези'}],
#    'countries': [{'name': 'Франция'},
#     {'name': 'Бельгия'},
#     {'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/zJbbrElZbp6Izmw4JIKHroP2Cz0.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/zJbbrElZbp6Izmw4JIKHroP2Cz0.png'}},
#   {'id': 1112578,
#    'name': 'Чудесный призрак',
#    'alternativeName': 'Wondeopul goseuteu',
#    'enName': 'Wonderful Ghost',
#    'names': [{'name': 'Wonderful Ghost',
#      'language': 'KR',
#      'type': 'Original Title'},
#     {'name': 'Wondeopool Goseuteu', 'language': 'KR', 'type': None},
#     {'name': '鬼神拍档', 'language': 'TW', 'type': None},
#     {'name': '与鬼同行：大叔追凶', 'language': 'HK', 'type': None},
#     {'name': 'Wonderful Ghost', 'language': 'US', 'type': None},
#     {'name': 'The Soul-Mate', 'language': 'US', 'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2018,
#    'description': 'Получив компромат на местный ночной клуб, новичок-полицейский Тхэ-джин попадает в засаду. Бандиты перестарались и случайно вогнали парня в кому, а его душа отделилась от тела. Страж закона очень хочет завершить расследование и вернуться к своей подружке, но теперь он — всего лишь бесплотный блуждающий призрак. Судьба посылает бедолаге шанс в виде равнодушного к правосудию соседа, хозяина секции по дзюдо. Тот может видеть призрака, разговаривать с ним, но принципиально не желает вмешиваться в чужие дела, заботясь только о маленькой дочке. Теперь Тхэ-джин не отцепится от нового знакомого, пока тот не поможет ему завершить начатое.',
#    'shortDescription': 'Отец-одиночка помогает полицейскому в коме завершить расследование. Трогательная южнокорейская трагикомедия',
#    'status': None,
#    'rating': {'kp': 7.134,
#     'imdb': 6.2,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 78491,
#     'imdb': 1086,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 97,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 12,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1629390/3cb11588-7cd8-4874-abde-fc91888330b5/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1629390/3cb11588-7cd8-4874-abde-fc91888330b5/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/tmdb-images/original/3NRRcN7a9NzrXmfJpte8IQZFpCs.jpg',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/3NRRcN7a9NzrXmfJpte8IQZFpCs.jpg'},
#    'genres': [{'name': 'комедия'},
#     {'name': 'фэнтези'},
#     {'name': 'криминал'},
#     {'name': 'мелодрама'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/egzp8YSf1Tqy0epAGpGtxLrOkSO.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/egzp8YSf1Tqy0epAGpGtxLrOkSO.png'}},
#   {'id': 839823,
#    'name': 'Трудный день',
#    'alternativeName': 'Kkeutkkaji ganda',
#    'enName': 'A Hard Day',
#    'names': [{'name': 'A Hard Day', 'language': 'US', 'type': None},
#     {'name': 'Ggeut-gga-ji Gan-da', 'language': 'KR', 'type': 'Romanized'},
#     {'name': 'Kkeut-kka-ji-gan-da', 'language': 'KR', 'type': None},
#     {'name': 'A Hard Day', 'language': 'NL', 'type': None},
#     {'name': 'Ggeutggaji Ganda', 'language': 'ID', 'type': None},
#     {'name': 'Ciężki dzień', 'language': 'PL', 'type': None},
#     {'name': 'O zi grea', 'language': 'RO', 'type': None},
#     {'name': 'Тяжёлый день', 'language': 'RU', 'type': 'Alternative Title'},
#     {'name': 'Težak dan', 'language': 'RS', 'type': None},
#     {'name': '非常警探', 'language': 'TW', 'type': None},
#     {'name': 'A Hard Day', 'language': 'KR', 'type': 'Daum Movie'},
#     {'name': 'A Hard Day', 'language': 'ES', 'type': 'Castilian Spanish'},
#     {'name': 'A Hard Day（끝까지 간다）', 'language': 'KR', 'type': None},
#     {'name': 'A Hard Day KR', 'language': 'KR', 'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2014,
#    'description': 'По дороге на похороны матери детектив отдела специальных преступлений Ко Гон-су сбивает человека. Произошедшая авария может мгновенно поставить крест на его карьере, разрушив всю жизнь. Чтобы скрыть преступление, он принимает не самое блестящее решение, которое запустит цепочку не самых приятных для полицейского событий.',
#    'shortDescription': 'Полицейский прячет тело сбитого человека в гробу матери. Лихо закрученный корейский боевик с черным юмором',
#    'status': None,
#    'rating': {'kp': 7.212,
#     'imdb': 7.2,
#     'filmCritics': 7.5,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 57118,
#     'imdb': 17191,
#     'filmCritics': 33,
#     'russianFilmCritics': 1,
#     'await': 0},
#    'movieLength': 111,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1704946/7b7a35e3-2831-44fe-85c8-e56de6dcd9fd/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1704946/7b7a35e3-2831-44fe-85c8-e56de6dcd9fd/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/tmdb-images/original/u0os34ctKo55sx6krTbO381ohNR.jpg',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/u0os34ctKo55sx6krTbO381ohNR.jpg'},
#    'genres': [{'name': 'триллер'}, {'name': 'боевик'}, {'name': 'криминал'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/tIcHxVF7VGYYRHbpI80xM6jYNCJ.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/tIcHxVF7VGYYRHbpI80xM6jYNCJ.png'}},
#   {'id': 4961757,
#    'name': 'Криминальный город: Разборки в Пусане',
#    'alternativeName': 'Beomjoe dosi 3',
#    'enName': None,
#    'names': [{'name': 'The Outlaws 3', 'language': 'US', 'type': None},
#     {'name': 'บู๊ระห่ำล่าล้างนรก: ทุบนรกแตก', 'language': 'TH', 'type': None},
#     {'name': '犯罪都市3', 'language': 'CN', 'type': '动作、犯罪'},
#     {'name': 'Beom-Joe-do-si 3', 'language': 'KR', 'type': None},
#     {'name': '犯罪都市 NO WAY OUT', 'language': 'JP', 'type': None},
#     {'name': 'The Roundup - No Way Out (2023)',
#      'language': 'DE',
#      'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': '2015 год. Детектив Ма\xa0Сок-то перевёлся в\xa0инчхонский следственный отдел, работает с\xa0новой командой, и\xa0покой ему\xa0только снится. Втайне от\xa0главы клана ушлые якудза поставляют в\xa0город новый синтетический наркотик, который становится дико популярным в\xa0увеселительных заведениях. Используя собственное неотразимое обаяние, а\xa0также сокрушительные удары правой и\xa0левой, через цепочку информаторов детектив Ма\xa0выясняет\xa0—\xa0с японцами сотрудничает кто-то из\xa0местных.',
#    'shortDescription': 'Полицейский пытается раскрыть сложнейший наркотрафик из Японии. Третья часть корейского детективного боевика',
#    'status': None,
#    'rating': {'kp': 7.558,
#     'imdb': 6.6,
#     'filmCritics': 7.1,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 81075,
#     'imdb': 7049,
#     'filmCritics': 13,
#     'russianFilmCritics': 2,
#     'await': 0},
#    'movieLength': 105,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10893610/d1469ec3-d32a-4788-aa24-1f9195c2a3f1/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10893610/d1469ec3-d32a-4788-aa24-1f9195c2a3f1/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1652588/2a0000018ae276beac2049c84a4b98dd9ef0/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1652588/2a0000018ae276beac2049c84a4b98dd9ef0/x1000'},
#    'genres': [{'name': 'криминал'},
#     {'name': 'боевик'},
#     {'name': 'триллер'},
#     {'name': 'детектив'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/giNfryjrc5b88t0J3cCuTzAqb0w.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/giNfryjrc5b88t0J3cCuTzAqb0w.png'}}],
#  'total': 2224,
#  'limit': 100,
#  'page': 1,
#  'pages': 23}

# %%
films_df = pd.DataFrame(res['docs'])
films_df.head(3)
# Out:
#         id                    name         alternativeName enName   type  \
# 0  6431436               Блуждания                  Mimang   None  movie
# 1  5444387  Кан Даниэль: Мой парад  Kang Daniel: My Parade   None  movie
# 2  5379511                    None             Caffeinated   None  movie
#
#    typeNumber  year                                        description  \
# 0           1  2023              Парень встречает свою бывшую девушку.
# 1           1  2023  Кан Даниэль, прославившийся в качестве участни...
# 2           1  2015                                               None
#
#   shortDescription status  ...  \
# 0             None   None  ...
# 1             None   None  ...
# 2             None   None  ...
#
#                                               poster  \
# 0  {'url': 'https://image.openmoviedb.com/kinopoi...
# 1  {'url': 'https://image.openmoviedb.com/kinopoi...
# 2                                                NaN
#
#                                               genres  \
# 0                                [{'name': 'драма'}]
# 1          [{'name': 'концерт'}, {'name': 'музыка'}]
# 2  [{'name': 'документальный'}, {'name': 'новости...
#
#                                            countries top10 top250 isSeries  \
# 0                          [{'name': 'Корея Южная'}]  None   None    False
# 1                          [{'name': 'Корея Южная'}]  None   None    False
# 2  [{'name': 'США'}, {'name': 'Колумбия'}, {'name...  None   None    False
#
#    ticketsOnSale backdrop names logo
# 0          False      NaN   NaN  NaN
# 1          False      NaN   NaN  NaN
# 2          False      NaN   NaN  NaN
#
# [3 rows x 27 columns]

# %%
page = pd.DataFrame(res['docs'])
films_df_cleaned = clean_page_columns(page)
films_df_cleaned = filter_noname_films(films_df_cleaned)
films_df_cleaned.head()
# Out:
#                                        name  rating_kp  rating_imdb  votes_kp  \
# id
# 1236015                               Выкуп      7.454          6.6     30817
# 1331187                       Игра киллеров      6.433          5.8      9652
# 5025649  Реинкарнация. Картины с того света      5.642          5.1      6173
# 1272314                   Побег из Могадишо      7.278          7.0     10929
# 4935012                Объект преследования      7.065          6.4     46325
#
#          votes_imdb  year                        genre_upd  \
# id
# 1236015        1434  2023                           боевик
# 1331187        1092  2022                 боевик, криминал
# 5025649         575  2022                            ужасы
# 1272314        7775  2021  история, драма, военный, боевик
# 4935012        3051  2023      триллер, детектив, криминал
#
#                 countries_upd top250
# id
# 1236015           Корея Южная   None
# 1331187           Корея Южная   None
# 5025649  Таиланд, Корея Южная   None
# 1272314           Корея Южная   None
# 4935012           Корея Южная   None

# %%
from tqdm import tqdm

# %%
for i in range(2, res['pages'] + 1):
    country = "Корея Южная"
    years = "2013-2023"
    page_id = i

    request = f'https://api.kinopoisk.dev/v1.4/movie?page={page_id}&limit=100&selectFields=id&selectFields=name&selectFields=alternativeName&selectFields=enName&selectFields=type&selectFields=year&selectFields=description&selectFields=shortDescription&selectFields=movieLength&selectFields=isSeries&selectFields=ticketsOnSale&selectFields=totalSeriesLength&selectFields=seriesLength&selectFields=ratingMpaa&selectFields=ageRating&selectFields=top10&selectFields=top250&selectFields=typeNumber&selectFields=status&selectFields=names&selectFields=logo&selectFields=poster&selectFields=backdrop&selectFields=rating&selectFields=votes&selectFields=genres&selectFields=countries&selectFields=releaseYears&type=movie&year={years}&countries.name={country}'

    page = requests.get(request, headers ={'accept': 'application/json', 'X-API-KEY': API_key})

    res = page.json()

    page = pd.DataFrame(res['docs'])

    page_cleaned = clean_page_columns(page)
    page_cleaned = filter_noname_films(page_cleaned)

    films_df_cleaned = pd.concat([films_df_cleaned, page_cleaned])
# Out:
# <ipython-input-64-fa338a98b7a0>:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   films_df_cleaned = pd.concat([films_df_cleaned, page_cleaned])
# <ipython-input-64-fa338a98b7a0>:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   films_df_cleaned = pd.concat([films_df_cleaned, page_cleaned])
# <ipython-input-64-fa338a98b7a0>:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   films_df_cleaned = pd.concat([films_df_cleaned, page_cleaned])
# <ipython-input-64-fa338a98b7a0>:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   films_df_cleaned = pd.concat([films_df_cleaned, page_cleaned])
# <ipython-input-64-fa338a98b7a0>:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   films_df_cleaned = pd.concat([films_df_cleaned, page_cleaned])
# <ipython-input-64-fa338a98b7a0>:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   films_df_cleaned = pd.concat([films_df_cleaned, page_cleaned])
# <ipython-input-64-fa338a98b7a0>:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   films_df_cleaned = pd.concat([films_df_cleaned, page_cleaned])
# <ipython-input-64-fa338a98b7a0>:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   films_df_cleaned = pd.concat([films_df_cleaned, page_cleaned])
# <ipython-input-64-fa338a98b7a0>:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   films_df_cleaned = pd.concat([films_df_cleaned, page_cleaned])
# <ipython-input-64-fa338a98b7a0>:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   films_df_cleaned = pd.concat([films_df_cleaned, page_cleaned])
# <ipython-input-64-fa338a98b7a0>:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   films_df_cleaned = pd.concat([films_df_cleaned, page_cleaned])
# <ipython-input-64-fa338a98b7a0>:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   films_df_cleaned = pd.concat([films_df_cleaned, page_cleaned])
# <ipython-input-64-fa338a98b7a0>:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   films_df_cleaned = pd.concat([films_df_cleaned, page_cleaned])
# <ipython-input-64-fa338a98b7a0>:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   films_df_cleaned = pd.concat([films_df_cleaned, page_cleaned])
# <ipython-input-64-fa338a98b7a0>:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   films_df_cleaned = pd.concat([films_df_cleaned, page_cleaned])
# <ipython-input-64-fa338a98b7a0>:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   films_df_cleaned = pd.concat([films_df_cleaned, page_cleaned])
# <ipython-input-64-fa338a98b7a0>:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   films_df_cleaned = pd.concat([films_df_cleaned, page_cleaned])
# <ipython-input-64-fa338a98b7a0>:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   films_df_cleaned = pd.concat([films_df_cleaned, page_cleaned])
# <ipython-input-64-fa338a98b7a0>:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   films_df_cleaned = pd.concat([films_df_cleaned, page_cleaned])
# <ipython-input-64-fa338a98b7a0>:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   films_df_cleaned = pd.concat([films_df_cleaned, page_cleaned])
# <ipython-input-64-fa338a98b7a0>:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   films_df_cleaned = pd.concat([films_df_cleaned, page_cleaned])
# <ipython-input-64-fa338a98b7a0>:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   films_df_cleaned = pd.concat([films_df_cleaned, page_cleaned])

# %%
films_df_cleaned.head()
# Out:
#                                        name  rating_kp  rating_imdb  votes_kp  \
# id
# 1236015                               Выкуп      7.454          6.6     30817
# 1331187                       Игра киллеров      6.433          5.8      9652
# 5025649  Реинкарнация. Картины с того света      5.642          5.1      6173
# 1272314                   Побег из Могадишо      7.278          7.0     10929
# 4935012                Объект преследования      7.065          6.4     46325
#
#          votes_imdb  year                        genre_upd  \
# id
# 1236015        1434  2023                           боевик
# 1331187        1092  2022                 боевик, криминал
# 5025649         575  2022                            ужасы
# 1272314        7775  2021  история, драма, военный, боевик
# 4935012        3051  2023      триллер, детектив, криминал
#
#                 countries_upd  top250
# id
# 1236015           Корея Южная     NaN
# 1331187           Корея Южная     NaN
# 5025649  Таиланд, Корея Южная     NaN
# 1272314           Корея Южная     NaN
# 4935012           Корея Южная     NaN

# %% [markdown]
# Сгруппируем по годам:

# %%
df_groupped_korea = films_df_cleaned.groupby('year')[['rating_kp', 'rating_imdb']].mean()
df_groupped_korea
# Out:
#       rating_kp  rating_imdb
# year
# 2013   6.806833     6.606667
# 2014   6.862667     6.566667
# 2015   6.692633     6.503333
# 2016   6.828966     6.741379
# 2017   6.829257     6.748571
# 2018   6.780139     6.630556
# 2019   6.683053     6.594737
# 2020   6.771964     6.439286
# 2021   6.873458     6.520833
# 2022   6.820410     6.289744
# 2023   6.898818     6.378788

# %% [markdown]
# И, конечно, графики:

# %%
plt.plot(df_groupped_korea.index, df_groupped_korea['rating_kp'], label = 'kp')
plt.plot(df_groupped_korea.index, df_groupped_korea['rating_imdb'], label = 'imdb')

plt.legend()

plt.show()

# %% [markdown]
# ### Задача 4: Фильмы с Тимоти Шаламе <3
#
# Вывести самые высоко оценненые фильмы с Тимоти Шаламе за его карьеру

# %% [markdown]
# Найдем в интернете ID актера — Тимоти Шаламе:

# %%
actor_id = "1665224"
years = "2000-2025"
page_id = 1

request = f'https://api.kinopoisk.dev/v1.4/movie?page={page_id}&limit=100&selectFields=id&selectFields=name&selectFields=alternativeName&selectFields=enName&selectFields=type&selectFields=year&selectFields=description&selectFields=shortDescription&selectFields=movieLength&selectFields=isSeries&selectFields=ticketsOnSale&selectFields=totalSeriesLength&selectFields=seriesLength&selectFields=ratingMpaa&selectFields=ageRating&selectFields=top10&selectFields=top250&selectFields=typeNumber&selectFields=status&selectFields=names&selectFields=logo&selectFields=poster&selectFields=backdrop&selectFields=rating&selectFields=votes&selectFields=genres&selectFields=countries&selectFields=releaseYears&type=movie&year={years}&persons.id={actor_id}'

page = requests.get(request, headers ={'accept': 'application/json', 'X-API-KEY': API_key})
page
# Out:
# <Response [200]>

# %%
res = page.json()
res
# Out:
# {'docs': [{'id': 6290547,
#    'name': 'Марти Превосходный',
#    'alternativeName': 'Marty Supreme',
#    'enName': None,
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2025,
#    'description': None,
#    'shortDescription': None,
#    'status': 'completed',
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 1657},
#    'movieLength': None,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'genres': [{'name': 'драма'},
#     {'name': 'биография'},
#     {'name': 'спорт'},
#     {'name': 'комедия'}],
#    'countries': [{'name': 'США'}, {'name': 'Финляндия'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False},
#   {'id': 462654,
#    'name': 'Красивый мальчик',
#    'alternativeName': 'Beautiful Boy',
#    'enName': None,
#    'names': [{'name': '뷰티풀 보이', 'language': 'KR', 'type': None},
#     {'name': 'Beautiful boy, siempre serás mi hijo',
#      'language': 'ES',
#      'type': None},
#     {'name': 'Querido Menino', 'language': 'BR', 'type': None},
#     {'name': 'Güzel Oğlum', 'language': 'TR', 'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2018,
#    'description': 'Реальная история молодого наркомана Ника Шеффа, представленная глазами его отца. Когда талантливый подросток становится причиной всех семейных бед, Шефф-старший ищет в\xa0произошедшем свою вину...',
#    'shortDescription': 'Отец спасает сына от наркозависимости. Глубокая драма по реальной истории со Стивом Кареллом и Тимоти Шаламе',
#    'status': None,
#    'rating': {'kp': 7.318,
#     'imdb': 7.4,
#     'filmCritics': 6.4,
#     'russianFilmCritics': 100,
#     'await': None},
#    'votes': {'kp': 44999,
#     'imdb': 107196,
#     'filmCritics': 265,
#     'russianFilmCritics': 7,
#     'await': 0},
#    'movieLength': 120,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': 'r',
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10671298/7ce25cf3-73b2-4781-b46e-cd07c831ad8d/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10671298/7ce25cf3-73b2-4781-b46e-cd07c831ad8d/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/tmdb-images/original/vy5bKKjcdws80nF9xSCeuXqOyuL.jpg',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/vy5bKKjcdws80nF9xSCeuXqOyuL.jpg'},
#    'genres': [{'name': 'драма'}, {'name': 'биография'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/hkDaKopAd8sp5TkahKeWhYmJLKD.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/hkDaKopAd8sp5TkahKeWhYmJLKD.png'}},
#   {'id': 928993,
#    'name': 'Жаркие летние ночи',
#    'alternativeName': 'Hot Summer Nights',
#    'enName': None,
#    'names': [{'name': "Chaudes nuits d'été", 'language': 'FR', 'type': None},
#     {'name': 'HOT SUMMER NIGHTS ホット・サマー・ナイツ', 'language': 'JP', 'type': None},
#     {'name': 'HOT SUMMER NIGHTS／ホット・サマー・ナイツ：2018',
#      'language': 'JP',
#      'type': None},
#     {'name': 'Gorące Letnie Noce', 'language': 'PL', 'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2017,
#    'description': 'Одним летом обычный подросток Дэниэл знакомится с\xa0главным бунтарем города, который затягивает паренька в\xa0наркоторговлю. Ко\xa0всему прочему, Дэниэл еще и\xa0влюбляется. Так, в\xa0короткие сроки его жизнь переворачивается с\xa0ног на\xa0голову.',
#    'shortDescription': 'Влюбленный Дэниел продает наркотики на каникулах. Тимоти Шаламе в криминальной мелодраме с атмосферой 1990-х',
#    'status': None,
#    'rating': {'kp': 6.767,
#     'imdb': 6.4,
#     'filmCritics': 5.3,
#     'russianFilmCritics': 70,
#     'await': None},
#    'votes': {'kp': 48238,
#     'imdb': 24764,
#     'filmCritics': 41,
#     'russianFilmCritics': 10,
#     'await': 0},
#    'movieLength': 107,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': 'r',
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1900788/bb10624c-12fa-4f42-b4a6-254aba7b064a/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1900788/bb10624c-12fa-4f42-b4a6-254aba7b064a/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/tmdb-images/original/iBIgNzzVa1lacALNiHvnQPFfWJ4.jpg',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/iBIgNzzVa1lacALNiHvnQPFfWJ4.jpg'},
#    'genres': [{'name': 'драма'}, {'name': 'мелодрама'}, {'name': 'криминал'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/Ms5BYRj8qcbCVl8j8PCX5TzHW3.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/Ms5BYRj8qcbCVl8j8PCX5TzHW3.png'}},
#   {'id': 669958,
#    'name': 'Любите Куперов',
#    'alternativeName': 'Love the Coopers',
#    'enName': 'The Most Wonderful Time',
#    'names': [{'name': 'The Most Wonderful Time',
#      'language': 'US',
#      'type': 'working title'},
#     {'name': 'Let It Snow', 'language': 'US', 'type': 'working title'},
#     {'name': 'Christmas with the Coopers', 'language': 'GB', 'type': None},
#     {'name': 'O Natal dos Coopers', 'language': 'BR', 'type': None},
#     {'name': 'Natale all’improvviso', 'language': 'IT', 'type': None},
#     {'name': '谷家大鑊過聖誕', 'language': 'HK', 'type': None},
#     {'name': 'Navidad con los Cooper', 'language': 'MX', 'type': None},
#     {'name': 'Navidad con los Cooper', 'language': 'ES', 'type': None},
#     {'name': 'Μια Φορά το Χρόνο', 'language': 'GR', 'type': None},
#     {'name': 'クーパー家の晩餐会：2015', 'language': 'JP', 'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2015,
#    'description': 'Феерическая рождественская комедия о том, что бывает, когда на праздник собираются представители четырех поколений одной большой семьи…',
#    'shortDescription': 'Для каждого из Куперов сочельник с родней — настоящий стресс. Звездный ансамбль в драмеди о семейных ценностях',
#    'status': None,
#    'rating': {'kp': 6.575,
#     'imdb': 5.8,
#     'filmCritics': 3.9,
#     'russianFilmCritics': 60,
#     'await': None},
#    'votes': {'kp': 76015,
#     'imdb': 27167,
#     'filmCritics': 119,
#     'russianFilmCritics': 5,
#     'await': 0},
#    'movieLength': 107,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': 'pg13',
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4303601/eba04342-f366-4889-8af9-dbc15eee428e/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4303601/eba04342-f366-4889-8af9-dbc15eee428e/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/tmdb-images/original/AgtqNrhuRr7YjNqwmglnyVfvxil.jpg',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/AgtqNrhuRr7YjNqwmglnyVfvxil.jpg'},
#    'genres': [{'name': 'фэнтези'}, {'name': 'мелодрама'}, {'name': 'комедия'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/wce97ZZmIQGr8ArfRxlCOvOZOSz.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/wce97ZZmIQGr8ArfRxlCOvOZOSz.png'}},
#   {'id': 963016,
#    'name': 'Недруги',
#    'alternativeName': 'Hostiles',
#    'enName': None,
#    'names': [{'name': '하스타일', 'language': 'KR', 'type': None},
#     {'name': 'Недруги', 'language': 'UA', 'type': None},
#     {'name': 'Hostis', 'language': 'BR', 'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2017,
#    'description': 'После долгих лет войны легендарный капитан армии Джозеф Блокер дышал злобой на всех краснокожих. В каждом из них он видел врага. В 1892 году, на исходе войны, Блокер получает приказ доставить на родину в Монтану умирающего вождя Шайенов, известного как Жёлтый Ястреб, и его семью. По пути из армейского форпоста в поселение индейцев к отряду капитана пристаёт обезумевшая от горя Розали Куэйд, на глазах которой команчи расправились с её детьми. Все вместе они идут по земле, где обитают враждебные племена и беглые преступники. Там за каждым углом ожидает смертельная опасность. Недруги в прошлом, военные и Шайенны должны научиться доверять друг другу и объединить усилия, чтобы выжить в этом опасном путешествии.',
#    'shortDescription': 'Вопреки ненависти к индейцам ветеран войны сопровождает их вождя на родину. Вестерн с Кристианом Бэйлом',
#    'status': None,
#    'rating': {'kp': 7.432,
#     'imdb': 7.2,
#     'filmCritics': 6.8,
#     'russianFilmCritics': 75,
#     'await': None},
#    'votes': {'kp': 153854,
#     'imdb': 98799,
#     'filmCritics': 224,
#     'russianFilmCritics': 4,
#     'await': 0},
#    'movieLength': 134,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': 'r',
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1599028/cc44c626-432a-4228-b6cb-ee5ceff0d08d/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1599028/cc44c626-432a-4228-b6cb-ee5ceff0d08d/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/tmdb-images/original/exZBs673IRqVtUMIHJPE1fC0Ga8.jpg',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/exZBs673IRqVtUMIHJPE1fC0Ga8.jpg'},
#    'genres': [{'name': 'драма'}, {'name': 'вестерн'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/5G9vDUV61KGoGnsjX2bfKpj9cZL.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/5G9vDUV61KGoGnsjX2bfKpj9cZL.png'}},
#   {'id': 1047626,
#    'name': 'Дождливый день в Нью-Йорке',
#    'alternativeName': 'A Rainy Day in New York',
#    'enName': None,
#    'names': [{'name': 'Mia broxerh mera sth Nea Yorki',
#      'language': 'GR',
#      'type': None},
#     {'name': 'Mia broheri mera sth Nea Yorki', 'language': 'GR', 'type': None},
#     {'name': '雨天・紐約', 'language': 'TW', 'type': None},
#     {'name': 'Um Dia de Chuva em Nova York', 'language': 'BR', 'type': None},
#     {'name': '레이니 데이 인 뉴욕', 'language': 'KR', 'type': None},
#     {'name': '情迷紐約下雨天', 'language': 'HK', 'type': None},
#     {'name': 'Día de lluvia en Nueva York', 'language': 'ES', 'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2019,
#    'description': 'Гэтсби\xa0—\xa0из состоятельной нью-йоркской семьи, его\xa0девушка Эшли\xa0—\xa0дочь банкира из\xa0Аризоны, оба\xa0учатся в\xa0колледже Ярдли. Когда местное издание отправляет Эшли в\xa0Нью-Йорк взять интервью у\xa0известного режиссера, Гэтсби приходит в\xa0восторг\xa0—\xa0теперь он\xa0покажет ей\xa0родной город. Парочка заселяется в\xa0шикарный номер с\xa0видом на\xa0Центральный парк и\xa0строит планы, но\xa0судьба распоряжается иначе: Эшли затягивает в\xa0мир звёздной богемы, а\xa0Гэтсби встречает бывших одноклассников и\xa0младшую сестру своей школьной любви.',
#    'shortDescription': 'Влюбленные планируют пару дел порознь, но увидятся ли они снова? Вуди Аллен — об иронии судьбы',
#    'status': None,
#    'rating': {'kp': 7.207,
#     'imdb': 6.5,
#     'filmCritics': 5.4,
#     'russianFilmCritics': 84.2105,
#     'await': None},
#    'votes': {'kp': 165420,
#     'imdb': 54370,
#     'filmCritics': 113,
#     'russianFilmCritics': 19,
#     'await': 0},
#    'movieLength': 92,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': 'pg13',
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1898899/b35ac1ed-ed96-4136-b951-5cf6f3069c3e/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1898899/b35ac1ed-ed96-4136-b951-5cf6f3069c3e/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/239697/2a0000016f36fadd5a4731b829575b7aebea/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/239697/2a0000016f36fadd5a4731b829575b7aebea/x1000'},
#    'genres': [{'name': 'мелодрама'}, {'name': 'комедия'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/o2ws7wlqgGi2OhFWc6AT00yKyWp.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/o2ws7wlqgGi2OhFWc6AT00yKyWp.png'}},
#   {'id': 5373829,
#    'name': None,
#    'alternativeName': "L'énigme Charlotte Rampling",
#    'enName': None,
#    'names': [{'name': 'Rätselhafte Charlotte Rampling - Porträt einer Kultschauspielerin',
#      'language': 'DE',
#      'type': 'complete title'},
#     {'name': 'Rätselhafte Charlotte Rampling', 'language': 'DE', 'type': None},
#     {'name': 'Tajemnicza Charlotte Rampling', 'language': 'PL', 'type': None}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2023,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 6.1,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 5,
#     'imdb': 25,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 54,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': None, 'previewUrl': None},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'документальный'}, {'name': 'биография'}],
#    'countries': [{'name': 'Франция'}, {'name': 'Бельгия'}],
#    'ticketsOnSale': False,
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'releaseYears': [],
#    'logo': {'url': None, 'previewUrl': None}},
#   {'id': 4414052,
#    'name': None,
#    'alternativeName': 'Cadillac: ScissorHandsFree',
#    'enName': None,
#    'names': [],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2021,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 7.971,
#     'imdb': 8.1,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 365,
#     'imdb': 868,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 1,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': None, 'previewUrl': None},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'короткометражка'},
#     {'name': 'ужасы'},
#     {'name': 'комедия'}],
#    'countries': [{'name': 'США'}],
#    'ticketsOnSale': False,
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'releaseYears': []},
#   {'id': 1132268,
#    'name': 'Великие артисты: Шоу ужасов',
#    'alternativeName': 'Great Performers: Horror Show',
#    'enName': None,
#    'names': [],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2017,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 6.5,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 108,
#     'imdb': 331,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 10,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/6201401/bcbde41e-bb9d-4fd4-8388-ae1b0b5a0ea0/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/6201401/bcbde41e-bb9d-4fd4-8388-ae1b0b5a0ea0/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/tmdb-images/original/cyxZxh6MUKWAINgIQejHJhxnYMc.jpg',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/cyxZxh6MUKWAINgIQejHJhxnYMc.jpg'},
#    'genres': [{'name': 'короткометражка'}, {'name': 'ужасы'}],
#    'countries': [{'name': 'США'}],
#    'ticketsOnSale': False,
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'releaseYears': [],
#    'logo': {'url': None, 'previewUrl': None}},
#   {'id': 1322864,
#    'name': '92-я церемония вручения премии «Оскар»',
#    'alternativeName': '92nd Annual Academy Awards',
#    'enName': None,
#    'names': [],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2020,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 6.821,
#     'imdb': 6.6,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 578,
#     'imdb': 1341,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 170,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1599028/441c1b58-632e-48a7-9e8b-cffea7201107/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1599028/441c1b58-632e-48a7-9e8b-cffea7201107/x1000'},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'церемония'}, {'name': 'музыка'}],
#    'countries': [{'name': 'США'}],
#    'ticketsOnSale': False,
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'releaseYears': []},
#   {'id': 4372509,
#    'name': '94-я церемония вручения премии «Оскар»',
#    'alternativeName': '94th Annual Academy Awards',
#    'enName': None,
#    'names': [],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2022,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 5.285,
#     'imdb': 4.2,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 404,
#     'imdb': 1179,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 170,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/6201401/41563d7f-ea57-4648-a4ec-506b195b1643/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/6201401/41563d7f-ea57-4648-a4ec-506b195b1643/x1000'},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'церемония'}, {'name': 'музыка'}],
#    'countries': [{'name': 'США'}],
#    'ticketsOnSale': False,
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'releaseYears': []},
#   {'id': 1252322,
#    'name': '76-я церемония вручения премии «Золотой глобус»',
#    'alternativeName': '2019 Golden Globe Awards',
#    'enName': None,
#    'names': [],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2019,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 0,
#     'imdb': 5.5,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 113,
#     'imdb': 491,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': 145,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': None, 'previewUrl': None},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'реальное ТВ'},
#     {'name': 'комедия'},
#     {'name': 'музыка'}],
#    'countries': [{'name': 'США'}],
#    'ticketsOnSale': False,
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'releaseYears': []},
#   {'id': 1112140,
#    'name': '75-я церемония вручения премии «Золотой глобус»',
#    'alternativeName': '75th Golden Globe Awards',
#    'enName': None,
#    'names': [],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2018,
#    'description': None,
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 6.435,
#     'imdb': 5.6,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 272,
#     'imdb': 665,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'totalSeriesLength': None,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1900788/a7c3af48-1e87-4f5f-a352-53fd25cada75/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1900788/a7c3af48-1e87-4f5f-a352-53fd25cada75/x1000'},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'церемония'}],
#    'countries': [{'name': 'США'}],
#    'ticketsOnSale': False,
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'releaseYears': []},
#   {'id': 5276455,
#    'name': 'Боб Дилан: Никому не известный',
#    'alternativeName': 'A Complete Unknown',
#    'enName': None,
#    'names': [{'name': 'A Complete Unknown',
#      'language': None,
#      'type': 'Original title on kinopoisk'}],
#    'type': 'movie',
#    'typeNumber': 1,
#    'year': 2024,
#    'description': '1965 год. На\xa0музыкальном фестивале в\xa0Ньюпорте производит фурор выступление молодого Боба Дилана.',
#    'shortDescription': None,
#    'status': None,
#    'rating': {'kp': 7.213,
#     'imdb': 7.6,
#     'filmCritics': 7.5,
#     'russianFilmCritics': 85.7143,
#     'await': None},
#    'votes': {'kp': 1623,
#     'imdb': 27550,
#     'filmCritics': 291,
#     'russianFilmCritics': 7,
#     'await': 0},
#    'ratingMpaa': 'r',
#    'ageRating': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/9784475/d1a0565d-9e27-4c98-8834-4d47d0c8dd53/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/9784475/d1a0565d-9e27-4c98-8834-4d47d0c8dd53/x1000'},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'драма'}, {'name': 'биография'}, {'name': 'музыка'}],
#    'countries': [{'name': 'США'}],
#    'top10': None,
#    'top250': None,
#    'releaseYears': [],
#    'ticketsOnSale': False,
#    'movieLength': 141,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'id': 669884,
#    'ageRating': None,
#    'alternativeName': 'Trooper',
#    'countries': [{'name': 'США'}],
#    'description': None,
#    'enName': None,
#    'genres': [{'name': 'драма'}],
#    'movieLength': None,
#    'name': 'Конный полицейский',
#    'names': [{'name': 'Конный полицейский'}, {'name': 'Trooper'}],
#    'poster': {'url': None, 'previewUrl': None},
#    'rating': {'kp': 0,
#     'imdb': 5,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'ratingMpaa': None,
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'type': 'movie',
#    'typeNumber': 1,
#    'votes': {'kp': 27,
#     'imdb': 50,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'year': 2013,
#    'backdrop': {'url': None, 'previewUrl': None},
#    'logo': {'url': None, 'previewUrl': None},
#    'top10': None,
#    'top250': None,
#    'status': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'id': 437547,
#    'ageRating': None,
#    'alternativeName': 'Loving Leah',
#    'countries': [{'name': 'США'}],
#    'description': None,
#    'enName': None,
#    'genres': [{'name': 'драма'}, {'name': 'мелодрама'}],
#    'movieLength': 95,
#    'name': 'Любящая Лея',
#    'names': [{'name': 'Un mariage de raison', 'language': 'FR', 'type': None}],
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1773646/d53a5425-2f2b-4dd0-8a66-d9c64d8cf89a/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1773646/d53a5425-2f2b-4dd0-8a66-d9c64d8cf89a/x1000'},
#    'rating': {'kp': 0,
#     'imdb': 7.1,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'ratingMpaa': None,
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'type': 'movie',
#    'typeNumber': 1,
#    'votes': {'kp': 289,
#     'imdb': 3670,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'year': 2009,
#    'backdrop': {'url': 'https://image.openmoviedb.com/tmdb-images/original/whFn52IATIAvHtrXC3WGaywJj5F.jpg',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/whFn52IATIAvHtrXC3WGaywJj5F.jpg'},
#    'logo': {'url': None, 'previewUrl': None},
#    'top10': None,
#    'top250': None,
#    'status': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'id': 4422719,
#    'countries': [{'name': 'Италия'}, {'name': 'США'}],
#    'genres': [{'name': 'драма'}, {'name': 'мелодрама'}, {'name': 'ужасы'}],
#    'names': [{'name': 'Целиком и полностью'},
#     {'name': 'Bones and All'},
#     {'name': "Luca Guadagnino's Bones and All",
#      'language': 'US',
#      'type': None},
#     {'name': 'Bones & All', 'language': 'US', 'type': 'book title'},
#     {'name': 'Do ostatniej kosteczki', 'language': 'PL', 'type': None},
#     {'name': '본즈 앤 올', 'language': 'KR', 'type': None},
#     {'name': 'Hasta Los Huesos', 'language': 'MX', 'type': None},
#     {'name': '骨肉的總和', 'language': 'HK', 'type': None},
#     {'name': 'Ossos e Tudo', 'language': 'PT', 'type': 'Oficial'},
#     {'name': 'Até os Ossos', 'language': 'BR', 'type': None}],
#    'alternativeName': 'Bones and All',
#    'description': '1980-е. 18-летняя Марен с\xa0отцом постоянно переезжают. Когда девушка пытается откусить палец новой подруге, и\xa0им снова приходится пуститься в\xa0бега, терпению отца приходит конец. Он\xa0уходит и\xa0оставляет дочери аудиокассету с\xa0объяснениями, немного денег и\xa0свидетельство о\xa0рождении. Марен отправляется на\xa0поиски матери, о\xa0которой у\xa0неё не\xa0осталось даже детских воспоминаний, и\xa0вскоре встречает незнакомца, такого же\xa0как она\xa0сама\xa0—\xa0не представляющего жизни без\xa0поедания человеческой плоти.',
#    'enName': None,
#    'movieLength': 131,
#    'name': 'Целиком и полностью',
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/6201401/080b4840-3ce6-4b8b-a6d2-9d1ab017b34f/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/6201401/080b4840-3ce6-4b8b-a6d2-9d1ab017b34f/x1000'},
#    'rating': {'kp': 6.367,
#     'imdb': 6.8,
#     'filmCritics': 7.4,
#     'russianFilmCritics': 66.6667,
#     'await': None},
#    'ratingMpaa': 'r',
#    'shortDescription': None,
#    'status': None,
#    'ticketsOnSale': False,
#    'type': 'movie',
#    'typeNumber': 1,
#    'votes': {'kp': 11840,
#     'imdb': 64955,
#     'filmCritics': 289,
#     'russianFilmCritics': 3,
#     'await': 0},
#    'year': 2022,
#    'ageRating': None,
#    'backdrop': {'url': None, 'previewUrl': None},
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/3k8OEnsAXAVqsYKk938eljc0Uhf.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/3k8OEnsAXAVqsYKk938eljc0Uhf.png'},
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'id': 4681413,
#    'alternativeName': 'A Man Named Scott',
#    'countries': [{'name': 'США'}],
#    'description': None,
#    'enName': None,
#    'genres': [{'name': 'документальный'}, {'name': 'музыка'}],
#    'movieLength': 95,
#    'name': 'Мужчина по имени Скотт',
#    'names': [{'name': 'Мужчина по имени Скотт'},
#     {'name': 'A Man Named Scott'},
#     {'name': 'A Man Named Scott: The Kid Cudi Story',
#      'language': 'US',
#      'type': 'alternative title'}],
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4303601/79ea2993-298e-4492-8c0a-dfd53286e196/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4303601/79ea2993-298e-4492-8c0a-dfd53286e196/x1000'},
#    'rating': {'kp': 8.053,
#     'imdb': 7.7,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'ratingMpaa': None,
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'type': 'movie',
#    'typeNumber': 1,
#    'votes': {'kp': 340,
#     'imdb': 1794,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'year': 2021,
#    'ageRating': None,
#    'backdrop': {'url': None, 'previewUrl': None},
#    'logo': {'url': None, 'previewUrl': None},
#    'top10': None,
#    'top250': None,
#    'status': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'id': 4540126,
#    'alternativeName': 'Dune: Part Two',
#    'countries': [{'name': 'США'},
#     {'name': 'Канада'},
#     {'name': 'ОАЭ'},
#     {'name': 'Венгрия'},
#     {'name': 'Италия'},
#     {'name': 'Новая Зеландия'},
#     {'name': 'Иордания'},
#     {'name': 'Гамбия'}],
#    'description': 'Герцог Пол\xa0Атрейдес присоединяется к\xa0фрименам, чтобы стать Муад Дибом, одновременно пытаясь остановить наступление войны.',
#    'enName': None,
#    'genres': [{'name': 'фантастика'},
#     {'name': 'боевик'},
#     {'name': 'драма'},
#     {'name': 'приключения'}],
#    'movieLength': 166,
#    'name': 'Дюна: Часть вторая',
#    'names': [{'name': 'Dune 2', 'language': 'US', 'type': None},
#     {'name': 'Dune: Part 2', 'language': 'US', 'type': None},
#     {'name': '듄 2', 'language': 'KR', 'type': None},
#     {'name': 'デューン 砂の惑星PART2', 'language': 'JP', 'type': None},
#     {'name': 'Duna 2', 'language': 'MX', 'type': None},
#     {'name': 'Hành Tinh Cát 2', 'language': 'VN', 'type': None},
#     {'name': 'Diuna: Część druga', 'language': 'PL', 'type': None},
#     {'name': 'Duna: Parte Dois', 'language': 'PT', 'type': None},
#     {'name': 'Kopa. II dalis', 'language': 'LT', 'type': None},
#     {'name': 'Dune: Del 2', 'language': 'DK', 'type': None},
#     {'name': 'Düün: teine osa', 'language': 'EE', 'type': None},
#     {'name': 'Dune : Deuxième Partie', 'language': 'CA', 'type': 'Québec'},
#     {'name': 'Dűne: Második rész', 'language': 'HU', 'type': None},
#     {'name': 'ड्यून पार्ट टू', 'language': 'IN', 'type': None},
#     {'name': 'Kopa. Antra dalis', 'language': 'LT', 'type': None},
#     {'name': 'Дюна: Часть 2', 'language': 'RU', 'type': None},
#     {'name': 'Дина 2', 'language': 'RS', 'type': None},
#     {'name': '沙丘：第二部', 'language': 'TW', 'type': None},
#     {'name': 'Дюна 2', 'language': 'UA', 'type': None},
#     {'name': 'Duna 2', 'language': 'AZ', 'type': None},
#     {'name': 'Duna: Parte 2', 'language': 'AR', 'type': None},
#     {'name': 'Dune Two', 'language': 'US', 'type': None},
#     {'name': 'Dyyni: Osa kaksi', 'language': 'FI', 'type': None},
#     {'name': '沙丘2', 'language': 'CN', 'type': None},
#     {'name': 'Dune - Part 2', 'language': 'DE', 'type': None},
#     {'name': 'Duna 2', 'language': 'BR', 'type': None},
#     {'name': 'Duna Parte 2', 'language': 'BR', 'type': None},
#     {'name': 'Dune Part Two', 'language': 'US', 'type': None},
#     {'name': 'Hành Tinh Cát II', 'language': 'VN', 'type': None},
#     {'name': '듄: 파트 2', 'language': 'KR', 'type': None},
#     {'name': 'Duna: Parte 2', 'language': 'BR', 'type': None},
#     {'name': 'Dune - Part Two (2024)', 'language': 'DE', 'type': None},
#     {'name': 'Dune 2', 'language': 'DE', 'type': None},
#     {'name': 'Dune：Part Two',
#      'language': 'US',
#      'type': "Full Title With Alt Char Set Colon  '：' For Windows Filenames"},
#     {'name': 'დიუნი: ნაწილი ორი', 'language': 'GE', 'type': None}],
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/9784475/0c67265b-6631-4e25-b89c-3ddf4e5a1ee7/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/9784475/0c67265b-6631-4e25-b89c-3ddf4e5a1ee7/x1000'},
#    'rating': {'kp': 8.209,
#     'imdb': 8.5,
#     'filmCritics': 8.4,
#     'russianFilmCritics': 90.9091,
#     'await': None},
#    'ratingMpaa': 'pg13',
#    'shortDescription': None,
#    'status': None,
#    'ticketsOnSale': False,
#    'type': 'movie',
#    'typeNumber': 1,
#    'votes': {'kp': 186362,
#     'imdb': 595351,
#     'filmCritics': 454,
#     'russianFilmCritics': 11,
#     'await': 0},
#    'year': 2024,
#    'ageRating': None,
#    'backdrop': {'url': None, 'previewUrl': None},
#    'logo': {'url': None, 'previewUrl': None},
#    'top10': None,
#    'top250': 56,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'status': None,
#    'rating': {'kp': 8.64,
#     'imdb': 8.7,
#     'filmCritics': 7.1,
#     'russianFilmCritics': 80.6452,
#     'await': None},
#    'votes': {'kp': 980655,
#     'imdb': 2127525,
#     'filmCritics': 378,
#     'russianFilmCritics': 31,
#     'await': 0},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1531675/2a000001862c40fa5c5394735529ee7e7188/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1531675/2a000001862c40fa5c5394735529ee7e7188/x1000'},
#    'movieLength': 169,
#    'id': 258687,
#    'type': 'movie',
#    'name': 'Интерстеллар',
#    'description': 'Когда засуха, пыльные бури и вымирание растений приводят человечество к продовольственному кризису, коллектив исследователей и учёных отправляется сквозь червоточину (которая предположительно соединяет области пространства-времени через большое расстояние) в путешествие, чтобы превзойти прежние ограничения для космических путешествий человека и найти планету с подходящими для человечества условиями.',
#    'year': 2014,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1600647/430042eb-ee69-4818-aed0-a312400a26bf/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1600647/430042eb-ee69-4818-aed0-a312400a26bf/x1000'},
#    'genres': [{'name': 'фантастика'},
#     {'name': 'драма'},
#     {'name': 'приключения'}],
#    'countries': [{'name': 'США'},
#     {'name': 'Великобритания'},
#     {'name': 'Канада'}],
#    'typeNumber': 1,
#    'alternativeName': 'Interstellar',
#    'enName': None,
#    'names': [{'name': 'Интерстеллар'},
#     {'name': 'Interstellar'},
#     {'name': '星际穿越', 'language': 'CN', 'type': None},
#     {'name': 'Xing Ji Chuan Yue', 'language': 'CN', 'type': 'romanization'},
#     {'name': 'Bein kokhavim', 'language': 'IL', 'type': 'romanization'},
#     {'name': 'ইন্টারস্টেলার', 'language': 'BD', 'type': 'Bengali'},
#     {'name': '星際啟示錄', 'language': 'HK', 'type': None},
#     {'name': 'Interestelar', 'language': 'BR', 'type': 'Modern title'},
#     {'name': 'Starp zvaigznēm', 'language': 'LV', 'type': None},
#     {'name': 'Csillagok Között', 'language': 'HU', 'type': None},
#     {'name': 'インターステラー', 'language': 'JP', 'type': None},
#     {'name': 'ინტერსტელარი', 'language': 'GE', 'type': None},
#     {'name': 'インターステラー：2014', 'language': 'JP', 'type': None},
#     {'name': 'Hố Đen Tử Thần', 'language': 'VN', 'type': None},
#     {'name': 'Ulduzlararası', 'language': 'AZ', 'type': None}],
#    'ratingMpaa': 'pg13',
#    'shortDescription': 'Фантастический эпос про задыхающуюся Землю, космические полеты и парадоксы времени. «Оскар» за спецэффекты',
#    'ticketsOnSale': False,
#    'ageRating': 18,
#    'logo': {'url': 'https://avatars.mds.yandex.net/get-ott/2439731/2a0000016fae962c6bf6cc87fd2098ed9035/orig'},
#    'top10': None,
#    'top250': 2,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'status': None,
#    'rating': {'kp': 7.013,
#     'imdb': 7.4,
#     'filmCritics': 8.8,
#     'russianFilmCritics': 93.75,
#     'await': None},
#    'votes': {'kp': 83887,
#     'imdb': 334309,
#     'filmCritics': 401,
#     'russianFilmCritics': 16,
#     'await': 0},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/374297/2a00000162d8952a748dd80d11647578fc97/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/374297/2a00000162d8952a748dd80d11647578fc97/x1000'},
#    'movieLength': 94,
#    'id': 958293,
#    'type': 'movie',
#    'name': 'Леди Бёрд',
#    'description': 'Кристина МакФерсон учится в консервативной католической школе в Сакраменто. Она ищет себя, своё место в мире и пытается быть не похожей на других. Её волосы выкрашены в странный красно-розовый цвет, а имя Леди Бёрд она дала себе сама и именно так просит её называть. И главная её мечта - вырваться из этого провинциального захолустья и поехать учиться в Нью-Йорк.',
#    'year': 2017,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1629390/1d700110-958c-4f3d-a943-c1f831fdd8cf/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1629390/1d700110-958c-4f3d-a943-c1f831fdd8cf/x1000'},
#    'genres': [{'name': 'драма'}, {'name': 'комедия'}],
#    'countries': [{'name': 'США'}],
#    'typeNumber': 1,
#    'alternativeName': 'Lady Bird',
#    'enName': None,
#    'names': [{'name': 'Леди Бёрд'},
#     {'name': 'Lady Bird'},
#     {'name': 'Леді-птах', 'language': 'UA', 'type': None},
#     {'name': 'Lady Bird - A Hora de Voar', 'language': 'BR', 'type': None},
#     {'name': '레이디 버드', 'language': 'KR', 'type': None},
#     {'name': 'Uğur Böceği', 'language': 'TR', 'type': None},
#     {'name': 'レディ・バード：2017', 'language': 'JP', 'type': None},
#     {'name': 'کفشدوزک', 'language': 'IR', 'type': None}],
#    'ageRating': 18,
#    'ratingMpaa': 'r',
#    'shortDescription': 'Кристина не ладит с мамой, мечтает о большом городе, влюбляется, познает себя и мир. Нежная драма о взрослении',
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://avatars.mds.yandex.net/get-ott/2419418/2a000001785f6bbb03ae30d9a976fd2897ea/orig'},
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'status': None,
#    'rating': {'kp': 7.489,
#     'imdb': 7.2,
#     'filmCritics': 6.3,
#     'russianFilmCritics': 46.6667,
#     'await': None},
#    'votes': {'kp': 291498,
#     'imdb': 631247,
#     'filmCritics': 304,
#     'russianFilmCritics': 15,
#     'await': 0},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'movieLength': 138,
#    'id': 1338480,
#    'type': 'movie',
#    'name': 'Не смотрите наверх',
#    'description': 'Астрономы открывают новую комету и, рассчитав её траекторию, узнают, что\xa0через полгода она\xa0столкнётся с\xa0Землёй, что\xa0положит конец существованию человечества и\xa0всего живого на\xa0планете. Двое учёных с\xa0трудом добиваются аудиенции у\xa0президента США, но\xa0там к\xa0их предупреждению относятся с\xa0недоверием, тогда они\xa0выступают в\xa0популярной телепередаче, но\xa0большинство всё равно не\xa0воспринимает угрозу всерьёз.',
#    'year': 2021,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4774061/9c7a6c39-a9fc-4c15-a634-ada778f7b86c/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4774061/9c7a6c39-a9fc-4c15-a634-ada778f7b86c/x1000'},
#    'genres': [{'name': 'драма'}, {'name': 'фантастика'}, {'name': 'комедия'}],
#    'countries': [{'name': 'США'}, {'name': 'Канада'}],
#    'typeNumber': 1,
#    'alternativeName': "Don't Look Up",
#    'enName': None,
#    'names': [{'name': 'Не смотрите наверх'},
#     {'name': "Don't Look Up"},
#     {'name': 'لا تبحث', 'language': 'EG', 'type': None},
#     {'name': 'Не смотри вверх', 'language': 'RU', 'type': None},
#     {'name': 'Yukarı Bakma', 'language': 'TR', 'type': None},
#     {'name': '不要抬头', 'language': 'CN', 'type': None},
#     {'name': "Don't Look Up Déni cosmique", 'language': 'FR', 'type': None},
#     {'name': '돈 룩 업', 'language': 'KR', 'type': None},
#     {'name': 'بالا را نگاه نکن', 'language': 'IR', 'type': None},
#     {'name': 'Não Olhe para Cima', 'language': 'BR', 'type': None},
#     {'name': '千万别抬头', 'language': 'CN', 'type': None},
#     {'name': 'No mires arriba', 'language': 'ES', 'type': None},
#     {'name': 'อย่ามองฟ้า', 'language': 'TH', 'type': None}],
#    'ratingMpaa': 'r',
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'ageRating': 18,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/xxrYdmXy67mZSo7G7s6QQTvu1iB.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/xxrYdmXy67mZSo7G7s6QQTvu1iB.png'},
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'status': None,
#    'rating': {'kp': 5.605,
#     'imdb': 5.2,
#     'filmCritics': 4.5,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 1930,
#     'imdb': 6230,
#     'filmCritics': 36,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'movieLength': 87,
#    'id': 568798,
#    'type': 'movie',
#    'name': 'Аддеролловые дневники',
#    'description': 'Будучи уже весьма известным писателем, Эллиот никак не может избавиться от демонов прошлого. Он раз за разом возвращается к своему детству, из которого не вынес практически ничего, кроме боли. Мать умерла, когда он был совсем мал, а отец вымещал на нем всю свою злобу и жестокость, спасение от которой мальчик находил в наркотиках. Выплеснув накопленные эмоции на бумаге, Эллиот мгновенно становится популярным, но сразу же сталкивается с писательским блоком. Он бросает светскую жизнь и становится затворником, общаясь только с эксцентричным компьютерным гением Хэнком Райзером, обвиненным в убийстве собственной жены.',
#    'year': 2015,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1900788/fdf0c674-c188-41a2-b603-392d94833c46/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1900788/fdf0c674-c188-41a2-b603-392d94833c46/x1000'},
#    'genres': [{'name': 'триллер'},
#     {'name': 'драма'},
#     {'name': 'криминал'},
#     {'name': 'детектив'}],
#    'countries': [{'name': 'США'}],
#    'typeNumber': 1,
#    'alternativeName': 'The Adderall Diaries',
#    'enName': None,
#    'names': [{'name': 'Аддеролловые дневники'},
#     {'name': 'The Adderall Diaries'},
#     {'name': 'Traumas de Infância', 'language': 'BR', 'type': 'TMDB'},
#     {'name': 'True Deception', 'language': 'GB', 'type': 'DVD title'},
#     {'name': 'Le verità sospese', 'language': 'IT', 'type': None},
#     {'name': 'Au-delà de mensonges', 'language': 'CA', 'type': 'DVD title'},
#     {'name': 'Podvod', 'language': 'CZ', 'type': None}],
#    'ratingMpaa': 'r',
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'ageRating': None,
#    'logo': {'url': 'https://imagetmdb.com/t/p/original/wR4XVyCWt2bVsNYgoUcw81qDU5o.png'},
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'status': None,
#    'rating': {'kp': 5.102,
#     'imdb': 4.4,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 378,
#     'imdb': 258,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'backdrop': {'url': 'https://image.openmoviedb.com/tmdb-images/original/iriexzcDbWY0k6ofKaiy9dWSReY.jpg',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/iriexzcDbWY0k6ofKaiy9dWSReY.jpg'},
#    'movieLength': 6,
#    'id': 429005,
#    'type': 'movie',
#    'name': 'Клоун',
#    'description': None,
#    'year': 2008,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1898899/125646a5-7dfb-47eb-ac92-54a9534738e9/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1898899/125646a5-7dfb-47eb-ac92-54a9534738e9/x1000'},
#    'genres': [{'name': 'короткометражка'},
#     {'name': 'ужасы'},
#     {'name': 'триллер'}],
#    'countries': [{'name': 'США'}],
#    'typeNumber': 1,
#    'alternativeName': 'Clown',
#    'enName': None,
#    'names': [{'name': 'Клоун'}, {'name': 'Clown'}],
#    'ageRating': None,
#    'ratingMpaa': None,
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'logo': {'url': None, 'previewUrl': None},
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'status': None,
#    'rating': {'kp': 7.136,
#     'imdb': 7.3,
#     'filmCritics': 6.6,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 58491,
#     'imdb': 160047,
#     'filmCritics': 146,
#     'russianFilmCritics': 2,
#     'await': 0},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/2439731/2a000001713eeb5c81bd7a28b04075a69fda/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/2439731/2a000001713eeb5c81bd7a28b04075a69fda/x1000'},
#    'movieLength': 140,
#    'id': 1114570,
#    'type': 'movie',
#    'name': 'Король Англии',
#    'description': 'Англия, начало XV века, разгар Столетней войны. Принц Уэльский Хел ведёт распутный образ жизни со своим приятелем Фальстафом и не помышляет о притязаниях на трон. Но когда от болезни умирает его отец, король Генрих IV, а младший брат погибает на поле боя, Хелу приходится принять корону. Став Генрихом V, молодой правитель ловко разбирается с заговорами и восстаниями, а также решает, что французские монархи не проявляют к нему должного уважения.',
#    'year': 2019,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1900788/a27abaf4-595f-446f-a8fd-60b329c5bb36/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1900788/a27abaf4-595f-446f-a8fd-60b329c5bb36/x1000'},
#    'genres': [{'name': 'биография'},
#     {'name': 'драма'},
#     {'name': 'военный'},
#     {'name': 'история'}],
#    'countries': [{'name': 'Великобритания'},
#     {'name': 'Венгрия'},
#     {'name': 'США'},
#     {'name': 'Австралия'}],
#    'typeNumber': 1,
#    'alternativeName': 'The King',
#    'enName': None,
#    'names': [{'name': 'Король Англии'},
#     {'name': 'The King'},
#     {'name': 'เดอะ คิง', 'language': 'TH', 'type': None},
#     {'name': 'The King - Netflix', 'language': 'DE', 'type': None},
#     {'name': 'Král', 'language': 'CZ', 'type': None},
#     {'name': 'El Rey', 'language': 'ES', 'type': None}],
#    'ageRating': 18,
#    'ratingMpaa': 'r',
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/rhXrloIPTfR9c0M4TUjGXD49MWV.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/rhXrloIPTfR9c0M4TUjGXD49MWV.png'},
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'status': None,
#    'rating': {'kp': 6.64,
#     'imdb': 6.6,
#     'filmCritics': 4.9,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 16314,
#     'imdb': 33873,
#     'filmCritics': 138,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'movieLength': 119,
#    'id': 798110,
#    'type': 'movie',
#    'name': 'Мужчины, женщины и дети',
#    'description': 'История о группе подростков и их родителях, которые пытаются понять, как интернет изменил их отношения, их связь, самооценку и любовь друг к другу.',
#    'year': 2014,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1600647/02057923-19c1-43df-a32c-0f6c6eaae6aa/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1600647/02057923-19c1-43df-a32c-0f6c6eaae6aa/x1000'},
#    'genres': [{'name': 'драма'}, {'name': 'комедия'}],
#    'countries': [{'name': 'США'}],
#    'typeNumber': 1,
#    'alternativeName': 'Men, Women & Children',
#    'enName': None,
#    'names': [{'name': 'Мужчины, женщины и дети'},
#     {'name': 'Men, Women & Children'},
#     {'name': 'Erkekler, Kadınlar ve Çocuklar', 'language': 'TR', 'type': None},
#     {'name': 'Men, women and children', 'language': 'IT', 'type': None},
#     {'name': 'Zeitgeist', 'language': 'AT', 'type': None},
#     {'name': 'Zeitgeist', 'language': 'DE', 'type': None},
#     {'name': 'Homens, Mulheres e Filhos', 'language': 'BR', 'type': None},
#     {'name': 'Hombres, mujeres & niños', 'language': 'ES', 'type': None}],
#    'ageRating': 18,
#    'ratingMpaa': 'r',
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://imagetmdb.com/t/p/original/4BGZ77cbM4jxlqloifv6P8AsCgb.png'},
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'status': None,
#    'rating': {'kp': 0,
#     'imdb': 4.3,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 280,
#     'imdb': 263,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'movieLength': 75,
#    'id': 768017,
#    'type': 'movie',
#    'name': 'Худшие друзья',
#    'description': 'После того как Джейк пострадал в а аварии, единственным человеком, который пришёл к нему на помощь, оказался его друг детства Сэм. Благодаря работе физиотерапевта и поддержке Сэма, Джейк поправляется. Но когда в их жизнях появляется Зои, школьная любовь Сэма, они становятся соперниками.',
#    'year': 2014,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1600647/a7fca9d0-fcc8-4f49-a1f7-68c4d3a0c9a9/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1600647/a7fca9d0-fcc8-4f49-a1f7-68c4d3a0c9a9/x1000'},
#    'genres': [{'name': 'драма'}, {'name': 'мелодрама'}, {'name': 'комедия'}],
#    'countries': [{'name': 'США'}],
#    'typeNumber': 1,
#    'alternativeName': 'Worst Friends',
#    'enName': None,
# ...
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'status': None,
#    'rating': {'kp': 7.483,
#     'imdb': 7.1,
#     'filmCritics': 7.1,
#     'russianFilmCritics': 79.1667,
#     'await': None},
#    'votes': {'kp': 79679,
#     'imdb': 156941,
#     'filmCritics': 320,
#     'russianFilmCritics': 24,
#     'await': 0},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/239697/2a0000017df860f57b5c5ae55e5cc63ccb66/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/239697/2a0000017df860f57b5c5ae55e5cc63ccb66/x1000'},
#    'movieLength': 107,
#    'id': 1211076,
#    'type': 'movie',
#    'name': 'Французский вестник. Приложение к газете «Либерти. Канзас ивнинг сан»',
#    'description': 'Собрание удивительных историй, опубликованных на\xa0страницах последнего выпуска еженедельного американского журнала, который выходил в\xa0свет в\xa0вымышленном французском городе в\xa0середине двадцатого века.',
#    'year': 2020,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4303601/6aaba78d-2883-4f0a-8465-1228993dd20c/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4303601/6aaba78d-2883-4f0a-8465-1228993dd20c/x1000'},
#    'genres': [{'name': 'драма'}, {'name': 'мелодрама'}, {'name': 'комедия'}],
#    'countries': [{'name': 'США'},
#     {'name': 'Германия'},
#     {'name': 'Канада'},
#     {'name': 'Франция'},
#     {'name': 'Великобритания'},
#     {'name': 'Швеция'}],
#    'typeNumber': 1,
#    'alternativeName': 'The French Dispatch of the Liberty, Kansas Evening Sun',
#    'enName': None,
#    'names': [{'name': 'Французский вестник. Приложение к газете «Либерти. Канзас ивнинг сан»'},
#     {'name': 'The French Dispatch'},
#     {'name': 'The French Dispatch of the Liberty, Kansas Evening Sun',
#      'language': 'US',
#      'type': 'Full Title'},
#     {'name': 'La crónica francesa del Liberty, Kansas Evening Sun',
#      'language': 'ES',
#      'type': None},
#     {'name': 'ก๊วนข่าวหัวเห็ด', 'language': 'TH', 'type': 'Thai Title'},
#     {'name': 'A Crônica Francesa', 'language': 'BR', 'type': None},
#     {'name': 'Fransız Postası', 'language': 'TR', 'type': None},
#     {'name': '法蘭西特派週報：堪薩斯州自由城太陽晚报',
#      'language': 'TW',
#      'type': 'Full Title / Disney+'},
#     {'name': '프렌치 디스패치', 'language': 'KR', 'type': None},
#     {'name': 'フレンチ・ディスパッチ ザ・リバティ', 'language': 'JP', 'type': None},
#     {'name': 'Prantsuse lähetus', 'language': 'EE', 'type': None}],
#    'ratingMpaa': 'r',
#    'shortDescription': 'После смерти главреда журналисты выпускают последний номер. Уэс Андерсон признается в любви старой прессе',
#    'ticketsOnSale': False,
#    'ageRating': 18,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/ojYi5IWXMTLRd8vhmAojdAnoHJJ.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/ojYi5IWXMTLRd8vhmAojdAnoHJJ.png'},
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'status': None,
#    'rating': {'kp': 7.801,
#     'imdb': 7.8,
#     'filmCritics': 8.5,
#     'russianFilmCritics': 75,
#     'await': None},
#    'votes': {'kp': 250753,
#     'imdb': 259124,
#     'filmCritics': 441,
#     'russianFilmCritics': 8,
#     'await': 0},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/2439731/2a00000170a4d732dbfd7bcfac139cb071ec/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/2439731/2a00000170a4d732dbfd7bcfac139cb071ec/x1000'},
#    'movieLength': 135,
#    'id': 807339,
#    'type': 'movie',
#    'name': 'Маленькие женщины',
#    'description': 'История взросления четырёх непохожих друг на друга сестер. Где-то бушует Гражданская война, но проблемы, с которыми сталкиваются девушки, актуальны как никогда: первая любовь, горькое разочарование, томительная разлука и непростые поиски себя и своего места в жизни.',
#    'year': 2019,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4774061/f6e389ae-a9ac-477c-a769-b02ddb0cf3ec/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4774061/f6e389ae-a9ac-477c-a769-b02ddb0cf3ec/x1000'},
#    'genres': [{'name': 'драма'}, {'name': 'мелодрама'}],
#    'countries': [{'name': 'США'}],
#    'typeNumber': 1,
#    'alternativeName': 'Little Women',
#    'enName': None,
#    'names': [{'name': 'Маленькие женщины'},
#     {'name': 'Little Women'},
#     {'name': 'Unge Kvinner', 'language': 'NO', 'type': None},
#     {'name': 'Mujercitas', 'language': 'ES', 'type': None},
#     {'name': '작은 아씨들', 'language': 'KR', 'type': None},
#     {'name': 'Adoráveis Mulheres', 'language': 'BR', 'type': None},
#     {'name': 'Les quatre filles du docteur March',
#      'language': 'CA',
#      'type': 'Regional French title'},
#     {'name': 'Малки жени', 'language': 'BG', 'type': None},
#     {'name': '小妇人', 'language': 'CN', 'type': None},
#     {'name': '小婦人', 'language': 'HK', 'type': None},
#     {'name': '她們', 'language': 'TW', 'type': None},
#     {'name': 'Küçük Kadınlar', 'language': 'TR', 'type': None},
#     {'name': 'Những người phụ nữ nhỏ bé', 'language': 'VN', 'type': None},
#     {'name': 'Čas deklištva', 'language': 'SI', 'type': None},
#     {'name': 'Fiicele doctorului March', 'language': 'RO', 'type': None},
#     {'name': 'Mažosios moterys', 'language': 'LT', 'type': None},
#     {'name': 'Piccole donne', 'language': 'IT', 'type': None},
#     {'name': 'Μικρές κυρίες', 'language': 'GR', 'type': None},
#     {'name': 'Kisasszonyok', 'language': 'HU', 'type': None},
#     {'name': 'Pikku naisia', 'language': 'FI', 'type': None},
#     {'name': 'Väikesed naised', 'language': 'EE', 'type': None},
#     {'name': 'نساء صغيرات', 'language': 'AE', 'type': None},
#     {'name': 'ストーリー・オブ・マイライフ/わたしの若草物語：2019', 'language': 'JP', 'type': None}],
#    'ratingMpaa': 'pg',
#    'shortDescription': 'Бойкая Джо и ее сестры взрослеют и ищут себя в Америке XIX века. Остроумный и воздушный фильм Греты Гервиг',
#    'ticketsOnSale': False,
#    'ageRating': 12,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/AaB9fxjDSEm8u14RKWJBst2IvjK.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/AaB9fxjDSEm8u14RKWJBst2IvjK.png'},
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'id': 1013343,
#    'type': 'movie',
#    'name': 'Вонка',
#    'rating': {'kp': 7.174,
#     'imdb': 7,
#     'filmCritics': 7.2,
#     'russianFilmCritics': 50,
#     'await': None},
#    'description': 'Мечтая открыть магазин в\xa0городе, известном своим шоколадом, молодой и\xa0бедный Вилли Вонка обнаруживает, что\xa0индустрией управляет картель жадных шоколатье.',
#    'votes': {'kp': 84266,
#     'imdb': 171804,
#     'filmCritics': 328,
#     'russianFilmCritics': 6,
#     'await': 0},
#    'year': 2023,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10893610/2cce4627-1099-477e-a2ec-a0025cb1fea4/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10893610/2cce4627-1099-477e-a2ec-a0025cb1fea4/x1000'},
#    'genres': [{'name': 'мюзикл'},
#     {'name': 'фэнтези'},
#     {'name': 'комедия'},
#     {'name': 'приключения'},
#     {'name': 'семейный'}],
#    'countries': [{'name': 'США'},
#     {'name': 'Великобритания'},
#     {'name': 'Канада'}],
#    'typeNumber': 1,
#    'alternativeName': 'Wonka',
#    'enName': None,
#    'movieLength': 116,
#    'names': [{'name': 'Вилли Вонка'},
#     {'name': 'Wonka'},
#     {'name': 'Willy Wonka', 'language': 'US', 'type': 'working title'},
#     {'name': 'Вонка', 'language': None, 'type': None},
#     {'name': 'วองก้า', 'language': 'TH', 'type': None}],
#    'ratingMpaa': 'pg',
#    'shortDescription': None,
#    'status': None,
#    'ticketsOnSale': False,
#    'ageRating': None,
#    'backdrop': {'url': None, 'previewUrl': None},
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/9C84PouYW5NvkGiZqbJBgy1709m.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/9C84PouYW5NvkGiZqbJBgy1709m.png'},
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'status': None,
#    'rating': {'kp': 7.674,
#     'imdb': 8,
#     'filmCritics': 7.7,
#     'russianFilmCritics': 70.8333,
#     'await': None},
#    'votes': {'kp': 803179,
#     'imdb': 938473,
#     'filmCritics': 514,
#     'russianFilmCritics': 24,
#     'await': 0},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1672343/2a0000017c9a7befa597b53c1700dcaa89b7/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1672343/2a0000017c9a7befa597b53c1700dcaa89b7/x1000'},
#    'movieLength': 155,
#    'id': 409424,
#    'type': 'movie',
#    'name': 'Дюна',
#    'description': 'Наследник знаменитого дома Атрейдесов Пол\xa0отправляется вместе с\xa0семьей на\xa0одну из\xa0самых опасных планет во\xa0Вселенной\xa0—\xa0Арракис. Здесь нет\xa0ничего, кроме песка, палящего солнца, гигантских чудовищ и\xa0основной причины межгалактических конфликтов\xa0—\xa0невероятно ценного ресурса, который называется меланж. В\xa0результате захвата власти Пол\xa0вынужден бежать и\xa0скрываться, и\xa0это становится началом его\xa0эпического путешествия. Враждебный мир\xa0Арракиса приготовил для\xa0него множество тяжелых испытаний, но\xa0только тот, кто\xa0готов взглянуть в\xa0глаза своему страху, достоин стать избранным.',
#    'year': 2021,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4303601/9eb762d6-4cdd-464f-9937-aebf30067acc/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4303601/9eb762d6-4cdd-464f-9937-aebf30067acc/x1000'},
#    'genres': [{'name': 'фантастика'},
#     {'name': 'боевик'},
#     {'name': 'драма'},
#     {'name': 'приключения'}],
#    'countries': [{'name': 'США'}, {'name': 'Канада'}, {'name': 'Венгрия'}],
#    'typeNumber': 1,
#    'alternativeName': 'Dune',
#    'enName': None,
#    'names': [{'name': 'Дюна'},
#     {'name': 'Dune: Part One'},
#     {'name': 'デューン', 'language': 'JP', 'type': None},
#     {'name': '듄', 'language': 'KR', 'type': None},
#     {'name': 'Duna', 'language': 'BR', 'type': None},
#     {'name': 'Dune։ Part One', 'language': 'US', 'type': None},
#     {'name': 'Dune։ Part One 3D', 'language': 'US', 'type': '3D version'},
#     {'name': 'חולית: חלק ראשון', 'language': 'IL', 'type': None},
#     {'name': 'デューン 砂の惑星', 'language': 'JP', 'type': None},
#     {'name': 'DUNE デューン 砂の惑星', 'language': 'JP', 'type': None},
#     {'name': 'ดูน', 'language': 'TH', 'type': None},
#     {'name': 'Hành Tinh Cát', 'language': 'VN', 'type': None},
#     {'name': 'Dune: 1', 'language': 'ES', 'type': 'Castellano'},
#     {'name': 'Duna: Parte Um', 'language': 'BR', 'type': None},
#     {'name': 'Duna: Primeira Part',
#      'language': 'BR',
#      'type': 'Voice-over (TV Globo)'},
#     {'name': '沙丘', 'language': 'CN', 'type': None},
#     {'name': 'Dune, première partie', 'language': 'FR', 'type': None},
#     {'name': 'Duna: Pjesa e Parë', 'language': 'AL', 'type': None},
#     {'name': 'Dune: Parte uno', 'language': 'ES', 'type': None},
#     {'name': 'Duna: Parte 1', 'language': 'BR', 'type': None},
#     {'name': 'Dune 1', 'language': 'US', 'type': 'Series Title'},
#     {'name': 'Dune：Part One',
#      'language': 'US',
#      'type': 'Full On Screen Title With Alt Char Set Colon for Windows Filenames'},
#     {'name': 'დიუნი', 'language': 'GE', 'type': None}],
#    'ageRating': 12,
#    'ratingMpaa': 'pg13',
#    'shortDescription': 'Атрейдесы прибывают на планету, где им никто не рад. Фантастический эпос Дени Вильнёва с шестью «Оскарами»',
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/s2IfGSnQ7Yf5s6NjLlR8GmubhHC.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/s2IfGSnQ7Yf5s6NjLlR8GmubhHC.png'},
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'status': None,
#    'rating': {'kp': 5.746,
#     'imdb': 5.5,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 244,
#     'imdb': 435,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'movieLength': 13,
#    'id': 798853,
#    'type': 'movie',
#    'name': 'Спиннеры',
#    'description': 'В маленьком захолустном городке, опустевшем из-за экономического застоя, двое подростков-приятелей Джейс и Дерек решают подзаработать сайн-спиннерами - промоутерами, вращающими доски с баннерной рекламой. После того, как к Джейсу цепляются местные задиры, он решает приобрести оружие у некоей Брианны. На встречу приезжает мать с маленькой дочкой.',
#    'year': 2014,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1773646/402f7b29-da82-47e6-a1b5-475adce85774/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1773646/402f7b29-da82-47e6-a1b5-475adce85774/x1000'},
#    'genres': [{'name': 'короткометражка'}, {'name': 'драма'}],
#    'countries': [{'name': 'США'}],
#    'typeNumber': 1,
#    'alternativeName': 'Spinners',
#    'enName': None,
#    'names': [{'name': 'Спиннеры'}, {'name': 'Spinners'}],
#    'ratingMpaa': None,
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'ageRating': None,
#    'logo': {'url': None, 'previewUrl': None},
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'status': None,
#    'rating': {'kp': 5.148,
#     'imdb': 5.2,
#     'filmCritics': 5.4,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 1491,
#     'imdb': 2392,
#     'filmCritics': 17,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'movieLength': 90,
#    'id': 843343,
#    'type': 'movie',
#    'name': 'Один и два',
#    'description': 'Брат и сестра обнаруживают у себя сверхъестественные способности и с их помощью решают сбежать из дома, пока их не разлучили...',
#    'year': 2015,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1600647/99237cb2-8b9c-4700-b3d6-fa70d4eac05d/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1600647/99237cb2-8b9c-4700-b3d6-fa70d4eac05d/x1000'},
#    'genres': [{'name': 'фэнтези'}, {'name': 'триллер'}, {'name': 'драма'}],
#    'countries': [{'name': 'США'}],
#    'typeNumber': 1,
#    'alternativeName': 'One and Two',
#    'enName': None,
#    'names': [{'name': 'Один и два'},
#     {'name': 'One and Two'},
#     {'name': 'Jeden, Dwa', 'language': 'PL', 'type': None}],
#    'ageRating': None,
#    'ratingMpaa': None,
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'logo': {'url': None},
#    'top10': None,
#    'top250': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None},
#   {'id': 737538,
#    'type': 'movie',
#    'name': 'Мисс Стивенс',
#    'rating': {'kp': 6.748,
#     'imdb': 6.6,
#     'filmCritics': 7.4,
#     'russianFilmCritics': 0,
#     'await': None},
#    'description': 'Учительница отправляется вместе с группой старшеклассников на главный театральный фестиваль штата.',
#    'votes': {'kp': 2377,
#     'imdb': 7940,
#     'filmCritics': 23,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'year': 2015,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1898899/ba2afe8f-00bf-4a84-958e-5bc2299e36ba/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1898899/ba2afe8f-00bf-4a84-958e-5bc2299e36ba/x1000'},
#    'genres': [{'name': 'драма'}, {'name': 'комедия'}],
#    'countries': [{'name': 'США'}],
#    'typeNumber': 1,
#    'alternativeName': 'Miss Stevens',
#    'enName': None,
#    'names': [{'name': 'Мисс Стивенс'}, {'name': 'Miss Stevens'}],
#    'ageRating': None,
#    'movieLength': 86,
#    'ratingMpaa': None,
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'backdrop': {'url': None, 'previewUrl': None},
#    'logo': {'url': None, 'previewUrl': None},
#    'top10': None,
#    'top250': None,
#    'status': None,
#    'isSeries': False,
#    'seriesLength': None,
#    'totalSeriesLength': None}],
#  'total': 36,
#  'limit': 100,
#  'page': 1,
#  'pages': 1}

# %%
films_df = pd.DataFrame(res['docs'])
films_df.head(3)
# Out:
#         id                name    alternativeName enName   type  typeNumber  \
# 0  6290547  Марти Превосходный      Marty Supreme   None  movie           1
# 1   462654    Красивый мальчик      Beautiful Boy   None  movie           1
# 2   928993  Жаркие летние ночи  Hot Summer Nights   None  movie           1
#
#    year                                        description  \
# 0  2025                                               None
# 1  2018  Реальная история молодого наркомана Ника Шеффа...
# 2  2017  Одним летом обычный подросток Дэниэл знакомитс...
#
#                                     shortDescription     status  ...  \
# 0                                               None  completed  ...
# 1  Отец спасает сына от наркозависимости. Глубока...       None  ...
# 2  Влюбленный Дэниел продает наркотики на каникул...       None  ...
#
#                                   countries top10  top250 isSeries  \
# 0  [{'name': 'США'}, {'name': 'Финляндия'}]  None     NaN    False
# 1                         [{'name': 'США'}]  None     NaN    False
# 2                         [{'name': 'США'}]  None     NaN    False
#
#   ticketsOnSale                                              names  \
# 0         False                                                NaN
# 1         False  [{'name': '뷰티풀 보이', 'language': 'KR', 'type': ...
# 2         False  [{'name': 'Chaudes nuits d'été', 'language': '...
#
#                                               poster  \
# 0                                                NaN
# 1  {'url': 'https://image.openmoviedb.com/kinopoi...
# 2  {'url': 'https://image.openmoviedb.com/kinopoi...
#
#                                             backdrop  \
# 0                                                NaN
# 1  {'url': 'https://image.openmoviedb.com/tmdb-im...
# 2  {'url': 'https://image.openmoviedb.com/tmdb-im...
#
#                                                 logo releaseYears
# 0                                                NaN          NaN
# 1  {'url': 'https://image.openmoviedb.com/tmdb-im...          NaN
# 2  {'url': 'https://image.openmoviedb.com/tmdb-im...          NaN
#
# [3 rows x 28 columns]

# %%
films_df_cleaned = clean_page_columns(films_df)
films_df_cleaned = filter_noname_films(films_df_cleaned)
films_df_cleaned.head()
# Out:
#                                name  rating_kp  rating_imdb  votes_kp  \
# id
# 462654             Красивый мальчик      7.318          7.4     44999
# 928993           Жаркие летние ночи      6.767          6.4     48238
# 669958               Любите Куперов      6.575          5.8     76015
# 963016                      Недруги      7.432          7.2    153854
# 1047626  Дождливый день в Нью-Йорке      7.207          6.5    165420
#
#          votes_imdb  year                    genre_upd countries_upd  top250
# id
# 462654       107196  2018             драма, биография           США     NaN
# 928993        24764  2017   драма, мелодрама, криминал           США     NaN
# 669958        27167  2015  фэнтези, мелодрама, комедия           США     NaN
# 963016        98799  2017               драма, вестерн           США     NaN
# 1047626       54370  2019           мелодрама, комедия           США     NaN

# %%
df_shalame = films_df_cleaned.sort_values('rating_kp', ascending=False)
df_shalame.head(10)
# Out:
#                                                       name  rating_kp  \
# id
# 258687                                        Интерстеллар      8.640
# 4540126                                 Дюна: Часть вторая      8.209
# 807339                                   Маленькие женщины      7.801
# 409424                                                Дюна      7.674
# 979148                            Назови меня своим именем      7.614
# 1338480                                 Не смотрите наверх      7.489
# 1211076  Французский вестник. Приложение к газете «Либе...      7.483
# 963016                                             Недруги      7.432
# 462654                                    Красивый мальчик      7.318
# 5276455                     Боб Дилан: Никому не известный      7.213
#
#          rating_imdb  votes_kp  votes_imdb  year  \
# id
# 258687           8.7    980655     2127525  2014
# 4540126          8.5    186362      595351  2024
# 807339           7.8    250753      259124  2019
# 409424           8.0    803179      938473  2021
# 979148           7.8    164245      320611  2017
# 1338480          7.2    291498      631247  2021
# 1211076          7.1     79679      156941  2020
# 963016           7.2    153854       98799  2017
# 462654           7.4     44999      107196  2018
# 5276455          7.6      1623       27550  2024
#
#                                       genre_upd  \
# id
# 258687           фантастика, драма, приключения
# 4540126  фантастика, боевик, драма, приключения
# 807339                         драма, мелодрама
# 409424   фантастика, боевик, драма, приключения
# 979148                         драма, мелодрама
# 1338480              драма, фантастика, комедия
# 1211076               драма, мелодрама, комедия
# 963016                           драма, вестерн
# 462654                         драма, биография
# 5276455                драма, биография, музыка
#
#                                              countries_upd  top250
# id
# 258687                         США, Великобритания, Канада     2.0
# 4540126  США, Канада, ОАЭ, Венгрия, Италия, Новая Зелан...    56.0
# 807339                                                 США     NaN
# 409424                                США, Канада, Венгрия     NaN
# 979148                      Италия, Франция, США, Бразилия     NaN
# 1338480                                        США, Канада     NaN
# 1211076  США, Германия, Канада, Франция, Великобритания...     NaN
# 963016                                                 США     NaN
# 462654                                                 США     NaN
# 5276455                                                США     NaN

# %% [markdown]
# ### Задача 5: Самые длинные фантастические сериалы
#
# Найти ТОП-10 самых длинных фантастических сериалов.

# %%
genres = ["фантастика", "фэнтези"]
page_id = 1

request = f'https://api.kinopoisk.dev/v1.4/movie?page={page_id}&limit=100&selectFields=id&selectFields=name&selectFields=alternativeName&selectFields=enName&selectFields=type&selectFields=year&selectFields=description&selectFields=shortDescription&selectFields=movieLength&selectFields=isSeries&selectFields=ticketsOnSale&selectFields=totalSeriesLength&selectFields=seriesLength&selectFields=ratingMpaa&selectFields=ageRating&selectFields=top10&selectFields=top250&selectFields=typeNumber&selectFields=status&selectFields=names&selectFields=logo&selectFields=poster&selectFields=backdrop&selectFields=rating&selectFields=votes&selectFields=genres&selectFields=countries&selectFields=releaseYears&type=tv-series&sortField=totalSeriesLength&sortType=-1&genres.name={genres[0]}&genres.name={genres[1]}'

page = requests.get(request, headers ={'accept': 'application/json', 'X-API-KEY': API_key})
page
# Out:
# <Response [200]>

# %%
res = page.json()
res
# Out:
# {'docs': [{'id': 419572,
#    'type': 'tv-series',
#    'name': 'Раузан',
#    'rating': {'kp': 7.715,
#     'imdb': 7.4,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'description': 'Себастьян де Монтоза красив и богат, но страдает каталепсией - унаследованной от отца болезнью, от которой вскоре должен умереть. Молодой человек известен как загадочный, эксцентричный ловелас, который соблазняет самых красивых девушек, а потом безжалостно их бросает. \n\nНо в один прекрасный день он влюбляется в богатую красавицу Соледад де Сантино и решает на ней жениться... Но на его пути возникает сразу несколько препятствий. Во-первых, это его собственный брат, а во-вторых, девушка, которую он любил, и которая ждет от него ребенка, считает его мертвым, потому что после очередного приступа его похоронили заживо...',
#    'votes': {'kp': 431,
#     'imdb': 44,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'year': 2000,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1629390/13bd8db3-cdc2-48d4-9048-6c5546285d17/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1629390/13bd8db3-cdc2-48d4-9048-6c5546285d17/x1000'},
#    'genres': [{'name': 'фэнтези'}, {'name': 'драма'}, {'name': 'мелодрама'}],
#    'countries': [{'name': 'Колумбия'}],
#    'typeNumber': 2,
#    'ageRating': None,
#    'alternativeName': 'Rauzán',
#    'enName': None,
#    'movieLength': None,
#    'names': [{'name': 'Раузан'}, {'name': 'Rauzán'}],
#    'ratingMpaa': None,
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'backdrop': {'url': None, 'previewUrl': None},
#    'logo': {'url': None, 'previewUrl': None},
#    'releaseYears': [{'start': 2000, 'end': 2001}],
#    'top10': None,
#    'top250': None,
#    'status': 'completed',
#    'isSeries': True,
#    'seriesLength': 45,
#    'totalSeriesLength': 4500},
#   {'status': 'completed',
#    'rating': {'kp': 7.127,
#     'imdb': 8.2,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 3372,
#     'imdb': 5736,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'id': 891645,
#    'type': 'tv-series',
#    'name': 'Министерство времени',
#    'description': 'Министерство времени - секретное правительственное учреждение, о существовании которого знает ограниченное количество людей. Его цель: обнаружение и предотвращение вторжений из прошлого в наше время, либо наоборот - использование истории в своих интересах.\n\nПереход в другие эпохи осуществляется через врата, охраняемые министерством. Хулиан Мартинес вместе с помощниками из прошлого, Амелией Фольч (из XIX века, первая женщина, попавшая в университет Барселоны) и Алонсо де Энтрерриос (солдат Фландрской армии из XVI века), путешествуют во времени в различные периоды испанской истории и пытаются не допустить изменения прошлого, чтобы настоящее осталось прежним.',
#    'year': 2015,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1946459/f3d2be4c-a928-438a-9231-3335abf07630/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1946459/f3d2be4c-a928-438a-9231-3335abf07630/x1000'},
#    'genres': [{'name': 'фантастика'},
#     {'name': 'фэнтези'},
#     {'name': 'боевик'},
#     {'name': 'триллер'},
#     {'name': 'комедия'},
#     {'name': 'приключения'}],
#    'countries': [{'name': 'Испания'}],
#    'typeNumber': 2,
#    'alternativeName': 'El ministerio del tiempo',
#    'enName': None,
#    'names': [{'name': 'Министерство времени'},
#     {'name': 'El ministerio del tiempo'}],
#    'ageRating': None,
#    'movieLength': None,
#    'ratingMpaa': None,
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/n0k72lfsaV5HQM3vW1ZdM029usW.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/n0k72lfsaV5HQM3vW1ZdM029usW.png'},
#    'releaseYears': [{'start': 2015, 'end': 2020}],
#    'top10': None,
#    'top250': None,
#    'isSeries': True,
#    'seriesLength': None,
#    'totalSeriesLength': 3155},
#   {'id': 494493,
#    'type': 'tv-series',
#    'name': 'Королевство ветров',
#    'rating': {'kp': 8.083,
#     'imdb': 7.5,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'description': 'Король Юри, сын первого короля Когурё, великого Коджумона, в первую очередь - отец, а потом уже правитель. Его сыну Мухюлю сразу после рождения прорицательница предсказала роковую судьбу, мальчик убьёт собственную мать, брата, отца, и даже родного сына, из-за него падёт королевство Когурё, и будет страдать народ. Прорицательница настаивает, чтобы родной отец, собственными руками забрал у новорожденного сына жизнь.',
#    'votes': {'kp': 1253,
#     'imdb': 1523,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'year': 2008,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1599028/7e05fdff-b1db-4273-be21-3aac9edecf83/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1599028/7e05fdff-b1db-4273-be21-3aac9edecf83/x1000'},
#    'genres': [{'name': 'фэнтези'}, {'name': 'драма'}, {'name': 'история'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'typeNumber': 2,
#    'alternativeName': 'Baramui nara',
#    'enName': None,
#    'names': [{'name': 'Королевство ветров'},
#     {'name': 'Baramui nara'},
#     {'name': 'The Kingdom of the Wind',
#      'language': 'KR',
#      'type': 'Literal title'},
#     {'name': '바람의 나라', 'language': 'KR', 'type': 'Original title'},
#     {'name': 'Baramui Nara', 'language': 'KR', 'type': 'Revised Romanization'},
#     {'name': 'Ba-lam-eui Na-ra', 'language': 'KR', 'type': None},
#     {'name': 'Country of Wind', 'language': 'US', 'type': None},
#     {'name': 'The Land of Wind', 'language': 'US', 'type': None}],
#    'movieLength': None,
#    'ratingMpaa': None,
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'ageRating': None,
#    'backdrop': {'url': None, 'previewUrl': None},
#    'logo': {'url': None, 'previewUrl': None},
#    'releaseYears': [{'start': 2008, 'end': 2008}],
#    'top10': None,
#    'top250': None,
#    'status': 'completed',
#    'isSeries': True,
#    'seriesLength': 60,
#    'totalSeriesLength': 2160},
#   {'id': 5028856,
#    'name': 'Сердце спасателя',
#    'alternativeName': 'Ku Phai Hua Jai Su',
#    'names': [],
#    'type': 'tv-series',
#    'typeNumber': 2,
#    'description': None,
#    'shortDescription': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'ratingMpaa': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4716873/e3f1218f-01a7-4ba1-b483-fe05e254a0aa/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4716873/e3f1218f-01a7-4ba1-b483-fe05e254a0aa/x1000'},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'ужасы'},
#     {'name': 'драма'},
#     {'name': 'мелодрама'},
#     {'name': 'комедия'},
#     {'name': 'фэнтези'},
#     {'name': 'детектив'}],
#    'countries': [{'name': 'Таиланд'}],
#    'releaseYears': [{'start': 2022, 'end': 2022}],
#    'top10': None,
#    'top250': None,
#    'year': 2022,
#    'ageRating': None,
#    'status': 'completed',
#    'ticketsOnSale': False,
#    'isSeries': True,
#    'seriesLength': 39,
#    'totalSeriesLength': 1755},
#   {'id': 761595,
#    'type': 'tv-series',
#    'name': 'Китайский паладин 3',
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'description': 'Цзинтянь — раздолбай и шутник, работает помощником в лавке ростовщика и главная любовь его жизни — деньги, а мечта — стать хозяином этой лавки. Однако внезапно вокруг него появляются подозрительные и не очень личности, которые утверждают, что он — реинкарнация небесного генерала Фэйпэна...\n\nТан Сюэцзянь — капризная и избалованная внучка главы Танов, Тан Куня, на чей дом покушается злой культ.\n\nСюй Чанцин — старший адепт секты Шушань, наставники которого пророчат ему бессмертие, когда он достигнет просветления. Но интересно, что будет, когда он вспомнит о своих прошлых жизнях?..\n\nЦзысюань — жрица богини Нюйва и хранительница земли, готовая на все ради своей любви, которая длится вот уже 200 лет...\n\nЛункуэй — принцесса царства Цзян, 1000 лет назад заточенная в волшебном мече, в чьем сердце лишь одно желание — всегда быть со старшим братом. Чунлоу — король демонов, одержимый идеей найти достойного противника. И 2000 лет назад он нашел его в генерале Фэйпэне, однако тогда их битве помешали, и в настоящем времени он преследует Цзинтяня с целью завершить поединок.',
#    'votes': {'kp': 69,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'year': 2009,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1946459/4226fb29-0f1a-4068-882c-76c5f86d183c/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1946459/4226fb29-0f1a-4068-882c-76c5f86d183c/x1000'},
#    'genres': [{'name': 'фэнтези'}, {'name': 'боевик'}, {'name': 'история'}],
#    'countries': [{'name': 'Китай'}],
#    'typeNumber': 2,
#    'alternativeName': 'Xian Jian Qi Xia Zhuan Zhi Ling Zhu Shen Jian',
#    'enName': None,
#    'names': [{'name': 'Китайский паладин 3'},
#     {'name': 'Xian Jian Qi Xia Zhuan Zhi Ling Zhu Shen Jian'}],
#    'movieLength': None,
#    'ratingMpaa': None,
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'ageRating': None,
#    'backdrop': {'url': None, 'previewUrl': None},
#    'logo': {'url': None},
#    'releaseYears': [{'start': 2009, 'end': 2009}],
#    'top10': None,
#    'top250': None,
#    'status': 'completed',
#    'isSeries': True,
#    'seriesLength': 45,
#    'totalSeriesLength': 1665},
#   {'id': 5211444,
#    'name': 'Лунное пророчество',
#    'alternativeName': 'Likit Haeng Jan',
#    'names': [],
#    'type': 'tv-series',
#    'typeNumber': 2,
#    'description': 'Девушки Дуангкэв и\xa0Опал внешне похожи, но\xa0живут в\xa0разных мирах. Однажды в\xa0полнолуние они\xa0меняются телами.',
#    'shortDescription': None,
#    'rating': {'kp': 0,
#     'imdb': 8,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 17,
#     'imdb': 9,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'ratingMpaa': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/6201401/1517259f-1d2f-49a3-8581-8a7d0da13ff0/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/6201401/1517259f-1d2f-49a3-8581-8a7d0da13ff0/x1000'},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'мелодрама'}, {'name': 'фэнтези'}],
#    'countries': [{'name': 'Таиланд'}],
#    'releaseYears': [{'start': 2019, 'end': 2019}],
#    'top10': None,
#    'top250': None,
#    'ageRating': None,
#    'year': 2019,
#    'status': 'completed',
#    'ticketsOnSale': False,
#    'isSeries': True,
#    'seriesLength': 110,
#    'totalSeriesLength': 1540},
#   {'id': 5028672,
#    'name': 'Тигр против бандитов',
#    'alternativeName': 'Chart Payak Khom Nak Laeng',
#    'names': [{'name': 'Shadow Enemy'}],
#    'type': 'tv-series',
#    'typeNumber': 2,
#    'description': None,
#    'shortDescription': None,
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 1,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'ratingMpaa': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4486454/40c8f3f9-12ea-4fae-b1ef-831207246676/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4486454/40c8f3f9-12ea-4fae-b1ef-831207246676/x1000'},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'фэнтези'}, {'name': 'боевик'}, {'name': 'криминал'}],
#    'countries': [{'name': 'Таиланд'}],
#    'releaseYears': [{'start': 2022, 'end': 2022}],
#    'top10': None,
#    'top250': None,
#    'year': 2022,
#    'ageRating': None,
#    'status': 'completed',
#    'ticketsOnSale': False,
#    'isSeries': True,
#    'seriesLength': 85,
#    'totalSeriesLength': 1530,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/4GaUe6Oj8lspwGubOeAWe6wRtf9.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/4GaUe6Oj8lspwGubOeAWe6wRtf9.png'},
#    'enName': None},
#   {'status': 'completed',
#    'rating': {'kp': 0,
#     'imdb': 6.4,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 101,
#     'imdb': 58,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'id': 807487,
#    'type': 'tv-series',
#    'name': 'Даосский маг Чон У-чхи',
#    'description': None,
#    'year': 2012,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1600647/1321cab5-4c30-4717-b35d-ea3229107d19/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1600647/1321cab5-4c30-4717-b35d-ea3229107d19/x1000'},
#    'genres': [{'name': 'фэнтези'},
#     {'name': 'боевик'},
#     {'name': 'мелодрама'},
#     {'name': 'комедия'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'typeNumber': 2,
#    'alternativeName': 'Jeon Woo-chi',
#    'enName': None,
#    'names': [{'name': 'Даосский маг Чон У-чхи'}, {'name': 'Jeon Woo-chi'}],
#    'movieLength': None,
#    'ratingMpaa': None,
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'ageRating': None,
#    'logo': {'url': None},
#    'releaseYears': [{'start': 2012, 'end': 2013}],
#    'top10': None,
#    'top250': None,
#    'isSeries': True,
#    'seriesLength': 63,
#    'totalSeriesLength': 1512},
#   {'id': 5028723,
#    'names': [],
#    'genres': [{'name': 'мелодрама'}, {'name': 'фэнтези'}],
#    'countries': [{'name': 'Таиланд'}],
#    'releaseYears': [{'start': 2022, 'end': 2023}],
#    'alternativeName': 'Sao Song Winyan',
#    'backdrop': {'url': None, 'previewUrl': None},
#    'description': None,
#    'movieLength': None,
#    'name': 'Девушка с двумя душами',
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10671298/6db90c60-5874-4645-baa7-6847ab4c6056/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10671298/6db90c60-5874-4645-baa7-6847ab4c6056/x1000'},
#    'rating': {'kp': 0,
#     'imdb': 8.6,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'ratingMpaa': None,
#    'shortDescription': None,
#    'status': 'completed',
#    'top10': None,
#    'top250': None,
#    'type': 'tv-series',
#    'typeNumber': 2,
#    'votes': {'kp': 1,
#     'imdb': 7,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'year': 2022,
#    'ageRating': None,
#    'ticketsOnSale': False,
#    'isSeries': True,
#    'seriesLength': 49,
#    'totalSeriesLength': 1470},
#   {'id': 485068,
#    'type': 'tv-series',
#    'name': 'Легенда',
#    'rating': {'kp': 8.059,
#     'imdb': 7.7,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'description': 'Две тысячи лет народ царства Когурё ждал, когда придет истинный правитель. Он пробудит Стражей четырех стихий и с их помощью установит мир на земле. И вот, наконец, звезда, знаменующая его появление, взошла на небосклоне.',
#    'votes': {'kp': 1262,
#     'imdb': 267,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'year': 2007,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1900788/435cc283-b155-40ef-8a9b-9334987e9eb7/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1900788/435cc283-b155-40ef-8a9b-9334987e9eb7/x1000'},
#    'genres': [{'name': 'фэнтези'}, {'name': 'драма'}, {'name': 'приключения'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'typeNumber': 2,
#    'alternativeName': 'Taewang sasingi',
#    'enName': "Story of the First King's Four Gods",
#    'names': [{'name': 'Легенда'},
#     {'name': 'Taewang sasingi'},
#     {'name': '太王四神记', 'language': 'CN', 'type': None},
#     {'name': 'The legend', 'language': 'GB', 'type': None},
#     {'name': 'Tae Wang Sa Shin Gi',
#      'language': 'KR',
#      'type': 'Revised Romanization'},
#     {'name': "Story of the First King's Four Gods",
#      'language': 'US',
#      'type': None}],
#    'ageRating': None,
#    'movieLength': None,
#    'ratingMpaa': None,
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'backdrop': {'url': None, 'previewUrl': None},
#    'logo': {'url': None},
#    'releaseYears': [{'start': 2007, 'end': 2007}],
#    'top10': None,
#    'top250': None,
#    'status': 'completed',
#    'isSeries': True,
#    'seriesLength': 60,
#    'totalSeriesLength': 1440},
#   {'id': 1331277,
#    'type': 'tv-series',
#    'name': 'Милый дом',
#    'rating': {'kp': 7.355,
#     'imdb': 7.2,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'description': 'После гибели родителей и\xa0сестры замкнутый старшеклассник Чха\xa0Хён-су остаётся совсем один, и\xa0ему приходится переехать в\xa0маленькую квартирку в\xa0занюханном жилом комплексе Green Home. Не\xa0видя никаких причин жить дальше, парень решает покончить с\xa0собой, но\xa0внезапно некоторые люди начинают превращаться в\xa0агрессивных чудовищ. Хён-су придётся преодолеть себя и\xa0поближе познакомиться с\xa0новыми соседями, чтобы совместными усилиями противостоять неожиданной угрозе.',
#    'votes': {'kp': 31180,
#     'imdb': 36953,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'year': 2020,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4486454/44bc437f-aa1c-4681-9c6a-93ad3b0a3681/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4486454/44bc437f-aa1c-4681-9c6a-93ad3b0a3681/x1000'},
#    'genres': [{'name': 'ужасы'}, {'name': 'боевик'}, {'name': 'фантастика'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'typeNumber': 2,
#    'alternativeName': 'Seuwiteuhom',
#    'backdrop': {'url': None, 'previewUrl': None},
#    'enName': None,
#    'movieLength': None,
#    'names': [{'name': 'Милый дом'},
#     {'name': 'Seuwiteuhom'},
#     {'name': 'Sweet Home', 'language': 'BR', 'type': None},
#     {'name': 'خانه شیرین', 'language': 'IR', 'type': None},
#     {'name': 'خانه آرام', 'language': 'IR', 'type': None},
#     {'name': '스위트홈', 'language': 'KR', 'type': None},
#     {'name': '甜蜜家园', 'language': 'SG', 'type': None},
#     {'name': 'สวีทโฮม', 'language': 'TH', 'type': None},
#     {'name': 'Sweet Home', 'language': 'TW', 'type': None},
#     {'name': 'NF Sweet Home', 'language': 'US', 'type': None},
#     {'name': 'Dulce Hogar', 'language': 'ES', 'type': None},
#     {'name': '甜蜜家園', 'language': 'TW', 'type': None},
#     {'name': '스위트홈 시즌 3', 'language': 'KR', 'type': None},
#     {'name': '스위트홈 시즌 2', 'language': 'KR', 'type': None}],
#    'status': 'completed',
#    'ageRating': 18,
#    'ratingMpaa': None,
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/eMUn8JkfBbyUiIKFZCCQXSo6xJu.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/eMUn8JkfBbyUiIKFZCCQXSo6xJu.png'},
#    'releaseYears': [{'start': 2020, 'end': 2024}],
#    'top10': None,
#    'top250': None,
#    'isSeries': True,
#    'seriesLength': 55,
#    'totalSeriesLength': 1440},
#   {'id': 5028725,
#    'name': 'Ожерелье наги',
#    'alternativeName': 'Soi Nakhee',
#    'names': [],
#    'type': 'tv-series',
#    'typeNumber': 2,
#    'description': None,
#    'shortDescription': None,
#    'status': 'completed',
#    'rating': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 0,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'ratingMpaa': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1898899/0a7591bf-14cf-447c-a237-691207b9e39e/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1898899/0a7591bf-14cf-447c-a237-691207b9e39e/x1000'},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'фэнтези'},
#     {'name': 'мелодрама'},
#     {'name': 'детектив'}],
#    'countries': [{'name': 'Таиланд'}],
#    'releaseYears': [{'start': 2023, 'end': 2023}],
#    'top10': None,
#    'top250': None,
#    'year': 2023,
#    'ageRating': None,
#    'ticketsOnSale': False,
#    'isSeries': True,
#    'seriesLength': 82,
#    'totalSeriesLength': 1394},
#   {'id': 774797,
#    'type': 'tv-series',
#    'name': 'Лок и ключ',
#    'rating': {'kp': 7.093,
#     'imdb': 7.3,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'description': 'Овдовевшая женщина с тремя детьми переезжает в фамильное имение Дом Ключей в городке Мэтисон. Семья надеется начать жизнь заново, оставив в прошлом недавние трагические происшествия - отец семейства был жестоко убит. Но особняк скрывает в своих стенах некие ключи и чудовище, которое за ними охотится.',
#    'votes': {'kp': 24572,
#     'imdb': 101801,
#     'filmCritics': 0,
#     'russianFilmCritics': 2,
#     'await': 0},
#    'year': 2020,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1946459/b40cbbd7-b778-4197-a2f6-a3b5f84c0c9b/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1946459/b40cbbd7-b778-4197-a2f6-a3b5f84c0c9b/x1000'},
#    'genres': [{'name': 'фэнтези'},
#     {'name': 'триллер'},
#     {'name': 'драма'},
#     {'name': 'ужасы'}],
#    'countries': [{'name': 'Канада'}, {'name': 'США'}],
#    'typeNumber': 2,
#    'alternativeName': 'Locke & Key',
#    'backdrop': {'url': None, 'previewUrl': None},
#    'enName': 'Locke and Key',
#    'movieLength': None,
#    'names': [{'name': 'Лок и ключ'},
#     {'name': 'Locke & Key'},
#     {'name': '致命钥匙', 'language': 'CN', 'type': None},
#     {'name': '钥匙', 'language': 'CN', 'type': None},
#     {'name': 'Ключи Локков', 'language': 'RU', 'type': None},
#     {'name': 'Локки и ключ', 'language': 'RU', 'type': None},
#     {'name': 'Ключі Локків', 'language': 'UA', 'type': None},
#     {'name': 'Locke and Key', 'language': 'US', 'type': None}],
#    'status': 'completed',
#    'ratingMpaa': None,
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'ageRating': None,
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/3bkUej1FlGE6bbDom8MdpMxZ1eX.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/3bkUej1FlGE6bbDom8MdpMxZ1eX.png'},
#    'releaseYears': [{'start': 2020, 'end': 2022}],
#    'top10': None,
#    'top250': None,
#    'isSeries': True,
#    'seriesLength': 48,
#    'totalSeriesLength': 1344},
#   {'status': 'completed',
#    'rating': {'kp': 7.367,
#     'imdb': 8.1,
#     'filmCritics': 0,
#     'russianFilmCritics': 90,
#     'await': None},
#    'votes': {'kp': 31554,
#     'imdb': 99687,
#     'filmCritics': 0,
#     'russianFilmCritics': 10,
#     'await': 0},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1672343/2a0000016badb050bed6587d6ebcca090f58/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1672343/2a0000016badb050bed6587d6ebcca090f58/x1000'},
#    'id': 939002,
#    'type': 'tv-series',
#    'name': 'Легион',
#    'description': 'Дэвиду Хэллеру поставлен диагноз — шизофрения. Постепенно выясняется, что картины и голоса, которые он видит и слышит, вполне реальны, а не бред его воспаленного разума.',
#    'year': 2017,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1629390/68151a93-440c-47cc-9803-e8544dad5629/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1629390/68151a93-440c-47cc-9803-e8544dad5629/x1000'},
#    'genres': [{'name': 'фантастика'},
#     {'name': 'боевик'},
#     {'name': 'триллер'},
#     {'name': 'драма'}],
#    'countries': [{'name': 'США'}],
#    'typeNumber': 2,
#    'alternativeName': 'Legion',
#    'enName': None,
#    'names': [{'name': 'Легион'},
#     {'name': 'Legion'},
#     {'name': 'S02 Legion', 'language': 'FR', 'type': None},
#     {'name': '리전', 'language': 'KR', 'type': None}],
#    'movieLength': None,
#    'ratingMpaa': None,
#    'shortDescription': 'Дэвид осознает, что его фантазии — реальность, а сам он — мутант. Супергеройский сериал по комиксам Marvel',
#    'ticketsOnSale': False,
#    'ageRating': 18,
#    'logo': {'url': None, 'previewUrl': None},
#    'releaseYears': [{'start': 2017, 'end': 2019}],
#    'top10': None,
#    'top250': None,
#    'isSeries': True,
#    'seriesLength': None,
#    'totalSeriesLength': 1316},
#   {'status': 'completed',
#    'rating': {'kp': 7.674,
#     'imdb': 8.2,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 19228,
#     'imdb': 201394,
#     'filmCritics': 0,
#     'russianFilmCritics': 2,
#     'await': 0},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/223007/2a000001701511c926ff75a85ef85a644c4a/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/223007/2a000001701511c926ff75a85ef85a644c4a/x1000'},
#    'id': 977493,
#    'type': 'tv-series',
#    'name': 'В лучшем мире',
#    'description': 'Элеанор попадает в\xa0Рай, где\xa0от вина нет\xa0похмелья, матерные ругательства заменяются смешными эвфемизмами, а\xa0жители\xa0—\xa0сплошные святоши. Только вот\xa0сама Элеанор оказалась там\xa0по ошибке, но\xa0никто, кроме неё, об\xa0этом не\xa0знает.',
#    'year': 2016,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1599028/8e62cff6-149b-4f59-b91f-0dab5b693c48/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1599028/8e62cff6-149b-4f59-b91f-0dab5b693c48/x1000'},
#    'genres': [{'name': 'фэнтези'},
#     {'name': 'драма'},
#     {'name': 'мелодрама'},
#     {'name': 'комедия'},
#     {'name': 'детектив'}],
#    'countries': [{'name': 'США'}],
#    'typeNumber': 2,
#    'alternativeName': 'The Good Place',
#    'enName': 'The Good Place Presents: The Selection',
#    'names': [{'name': 'В лучшем мире'},
#     {'name': 'The Good Place'},
#     {'name': 'Доброто място', 'language': 'BG', 'type': None},
#     {'name': 'O Bom Lugar', 'language': 'BR', 'type': None},
#     {'name': 'The Good Place - O Bom Lugar', 'language': 'BR', 'type': None},
#     {'name': 'Dobré místo', 'language': 'CZ', 'type': 'TV Seznam'},
#     {'name': 'Хорошее место', 'language': 'RU', 'type': None},
#     {'name': 'У кращому місці', 'language': 'UA', 'type': None},
#     {'name': 'The Good Place Presents: The Selection',
#      'language': 'US',
#      'type': 'specials'}],
#    'movieLength': None,
#    'ratingMpaa': None,
#    'shortDescription': 'Эгоистка Элеонор по ошибке попадает в рай. Комедия о том, как стать лучше, от автора «Парков и зон отдыха»',
#    'ticketsOnSale': False,
#    'ageRating': 18,
#    'logo': {'url': None, 'previewUrl': None},
#    'releaseYears': [{'start': 2016, 'end': 2020}],
#    'top10': None,
#    'top250': None,
#    'isSeries': True,
#    'seriesLength': None,
#    'totalSeriesLength': 1303},
#   {'id': 707409,
#    'name': 'Аран и магистрат',
#    'alternativeName': 'Alangsattojeon',
#    'names': [{'name': 'Аран и магистрат',
#      'language': 'RU',
#      'type': 'Russian title on kinopoisk'},
#     {'name': 'Alangsattojeon',
#      'language': None,
#      'type': 'Original title on kinopoisk'}],
#    'type': 'tv-series',
#    'typeNumber': 2,
#    'year': 2012,
#    'description': 'Чосон. Дух убитой девушки А-ран появляется перед правительственным чиновником Ын-о и просит найти её убийцу. Тот соглашается и всеми способами пытается исполнить последнее желание девушки.',
#    'shortDescription': 'Юноша помогает призраку красавицы узнать правду о ее смерти. Костюмная дорама по мотивам корейской мифологии',
#    'status': 'completed',
#    'rating': {'kp': 7.597,
#     'imdb': 7.3,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 11227,
#     'imdb': 963,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'totalSeriesLength': 1200,
#    'seriesLength': 60,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4486454/14f5ea40-3a40-4f9a-a8e8-21e195d0c03d/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4486454/14f5ea40-3a40-4f9a-a8e8-21e195d0c03d/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/224348/2a0000017fb1066c985fcddea64d488a4af3/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/224348/2a0000017fb1066c985fcddea64d488a4af3/x1000'},
#    'genres': [{'name': 'комедия'}, {'name': 'детектив'}, {'name': 'фэнтези'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'releaseYears': [{'start': 2012, 'end': 2012}],
#    'top10': None,
#    'top250': None,
#    'isSeries': True,
#    'ticketsOnSale': False},
#   {'id': 797916,
#    'name': 'Повелитель солнца',
#    'alternativeName': 'Jugunui taeyang',
#    'names': [{'name': 'The Sun of My Master', 'language': 'KR', 'type': None},
#     {'name': 'Joogoonui Taeyang',
#      'language': 'KR',
#      'type': 'Revised Romanization'},
#     {'name': 'The Sun of the Lord', 'language': 'KR', 'type': None},
#     {'name': 'Повелитель солнца', 'language': 'RU', 'type': None},
#     {'name': "The Master's Sun", 'language': 'US', 'type': None}],
#    'type': 'tv-series',
#    'typeNumber': 2,
#    'year': 2013,
#    'description': 'Чу Джун-вон\xa0—\xa0исключительно жадный топ-менеджер. Он\xa0переводит в\xa0денежный эквивалент всё, даже личные отношения. Тхэ\xa0Гон-щиль\xa0—\xa0простая секретарша, и\xa0её с\xa0легкостью можно довести до\xa0слез. По\xa0воле случая она\xa0начинает видеть духов. И\xa0с того момента бессонница становится её вечной ночной спутницей.',
#    'shortDescription': 'Секретарша помогает умершим уладить незавершенные земные дела. Комедийная дорама о назойливых призраках',
#    'status': 'completed',
#    'rating': {'kp': 8.166,
#     'imdb': 8.1,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 41491,
#     'imdb': 5841,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'totalSeriesLength': 1190,
#    'seriesLength': 70,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4483445/f911097e-f9e3-49fd-9bb5-d280c8baed71/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4483445/f911097e-f9e3-49fd-9bb5-d280c8baed71/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/2439731/2a000001854d0d68700070bbafb3683ae326/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/2439731/2a000001854d0d68700070bbafb3683ae326/x1000'},
#    'genres': [{'name': 'фэнтези'}, {'name': 'мелодрама'}, {'name': 'комедия'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'releaseYears': [{'start': 2013, 'end': 2013}],
#    'top10': None,
#    'top250': None,
#    'isSeries': True,
#    'ticketsOnSale': False,
#    'enName': "The Master's Sun",
#    'logo': {'url': None, 'previewUrl': None}},
#   {'id': 765093,
#    'name': 'Я тебя слышу',
#    'alternativeName': 'Neoui moksoriga deulleo',
#    'names': [{'name': 'Я тебя слышу',
#      'language': 'RU',
#      'type': 'Russian title on kinopoisk'},
#     {'name': 'Neoui moksoriga deulleo',
#      'language': None,
#      'type': 'Original title on kinopoisk'}],
#    'type': 'tv-series',
#    'typeNumber': 2,
#    'year': 2013,
#    'description': 'Чан Хэ-сон\xa0—\xa0смелая, немного нахальная юристка. У\xa0нее колючий характер, острый язык, к\xa0тому же\xa0она совсем лишена манер и\xa0не в\xa0восторге от\xa0своей работы. Пак\xa0Су-ха\xa0—\xa019-летний паренёк, обладающий экстрасенсорными способностями, он\xa0умеет слышать мысли людей. И\xa0Ча Гван-у\xa0—\xa0серьёзный и\xa0мужественный бывший полицейский, который становится государственным адвокатом.',
#    'shortDescription': 'Чан Хэ-сон спасла мальчика, и годы спустя он появляется в ее жизни. Фантастическая дорама о телепатии и любви',
#    'status': 'completed',
#    'rating': {'kp': 8.221,
#     'imdb': 8,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 37945,
#     'imdb': 5013,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'totalSeriesLength': 1134,
#    'seriesLength': 63,
#    'ratingMpaa': None,
#    'ageRating': 12,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/6201401/9b0e68ad-c211-44cb-8c68-3df145489997/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/6201401/9b0e68ad-c211-44cb-8c68-3df145489997/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/2439731/2a0000017f58b95a0490d75fa5e13b98a0e2/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/2439731/2a0000017f58b95a0490d75fa5e13b98a0e2/x1000'},
#    'genres': [{'name': 'мелодрама'},
#     {'name': 'комедия'},
#     {'name': 'фантастика'},
#     {'name': 'детектив'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'releaseYears': [{'start': 2013, 'end': 2013}],
#    'top10': None,
#    'top250': None,
#    'isSeries': True,
#    'ticketsOnSale': False},
#   {'id': 665236,
#    'name': 'Открытие ведьм',
#    'alternativeName': 'A Discovery of Witches',
#    'names': [{'name': 'Открытие ведьм',
#      'language': 'RU',
#      'type': 'Russian title on kinopoisk'},
#     {'name': 'A Discovery of Witches',
#      'language': None,
#      'type': 'Original title on kinopoisk'}],
#    'type': 'tv-series',
#    'typeNumber': 2,
#    'year': 2018,
#    'description': 'История любви на фоне оксфордской академической жизни. Историк Диана Бишоп специализируется на старинных рукописях и однажды обнаруживает в архивах некий манускрипт, связанный с магией. С этих пор жизнь Дианы превращается в кошмар, зато судьба сводит её с обаятельным генетиком Мэттью Клермонтом. Пикантность ситуации заключается в том, что Диана — потомственная ведьма, а Мэттью — вампир.',
#    'shortDescription': 'Потомственная ведьма и вампир объединяются для изучения магии. Мистика и романтика в декорациях Оксфорда',
#    'status': 'completed',
#    'rating': {'kp': 7.794,
#     'imdb': 7.8,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 301424,
#     'imdb': 67011,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'totalSeriesLength': 1107,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1898899/51020590-1105-4419-a06a-4aecaa978a3e/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1898899/51020590-1105-4419-a06a-4aecaa978a3e/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1531675/2a0000017e35b8c1cb026ffd3af407a5e11b/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1531675/2a0000017e35b8c1cb026ffd3af407a5e11b/x1000'},
#    'genres': [{'name': 'фэнтези'}, {'name': 'драма'}, {'name': 'мелодрама'}],
#    'countries': [{'name': 'Великобритания'}],
#    'releaseYears': [{'start': 2018, 'end': 2022}],
#    'top10': None,
#    'top250': None,
#    'isSeries': True,
#    'ticketsOnSale': False},
#   {'id': 717443,
#    'type': 'tv-series',
#    'name': 'До смерти красива',
#    'rating': {'kp': 5.672,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'description': 'Вселенная порой любит подшутить над смертными и вот тогда-то их жизненные пути начинаются пересекаться самыми странными и нелепыми способами. Так случилось и с героинями этой истории - успешной, красивой, гламурной Дианой, звездой модельного бизнеса и зажатой, неуверенной в себе Дарьей, занимающейся юриспруденцией. Им предстоит искать ответы на свои вопросы в ситуациях, в которые их шутя будет кидать жизнь.',
#    'votes': {'kp': 1077,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'year': 2013,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1600647/02615340-5167-4db1-ace3-3b522007c306/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1600647/02615340-5167-4db1-ace3-3b522007c306/x1000'},
#    'genres': [{'name': 'фантастика'}, {'name': 'драма'}, {'name': 'комедия'}],
#    'countries': [{'name': 'Россия'}],
#    'typeNumber': 2,
#    'alternativeName': None,
#    'enName': None,
#    'names': [],
#    'movieLength': None,
#    'ratingMpaa': None,
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'ageRating': 12,
#    'backdrop': {'url': None, 'previewUrl': None},
#    'logo': {'url': None},
#    'releaseYears': [{'start': 2013, 'end': 2013}],
#    'top10': None,
#    'top250': None,
#    'status': 'completed',
#    'isSeries': True,
#    'seriesLength': 46,
#    'totalSeriesLength': 1104},
#   {'id': 5147208,
#    'name': 'Сигнал',
#    'alternativeName': '23:23',
#    'names': [],
#    'type': 'tv-series',
#    'typeNumber': 2,
#    'description': None,
#    'shortDescription': None,
#    'rating': {'kp': 0,
#     'imdb': 8.2,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 17,
#     'imdb': 21,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'ratingMpaa': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10835644/98539294-9acf-4488-96f8-92d6dae5ca3f/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10835644/98539294-9acf-4488-96f8-92d6dae5ca3f/x1000'},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'фэнтези'},
#     {'name': 'боевик'},
#     {'name': 'триллер'},
#     {'name': 'драма'},
#     {'name': 'криминал'},
#     {'name': 'детектив'},
#     {'name': 'фантастика'}],
#    'countries': [{'name': 'Таиланд'}],
#    'releaseYears': [{'start': 2023, 'end': 2023}],
#    'top10': None,
#    'top250': None,
#    'year': 2023,
#    'ageRating': None,
#    'status': 'completed',
#    'ticketsOnSale': False,
#    'isSeries': True,
#    'seriesLength': 60,
#    'totalSeriesLength': 1080,
#    'enName': None,
#    'logo': {'url': None, 'previewUrl': None}},
#   {'id': 674374,
#    'type': 'tv-series',
#    'name': 'Я отменяю смерть',
#    'rating': {'kp': 6.451,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'description': 'Рита унаследовала от матери старинный браслет, который просто упал с руки погибшей женщины, при жизни же она его никогда не снимала. Девушка надела браслет и поняла, что теперь может слышать голоса умерших, вернее, их крики о помощи, а также перемещаться во времени, всего на сутки, но для нее этого достаточно, чтобы успеть предотвратить чью-нибудь смерть. Рита быстро осознает, что браслет снять не удастся и от странного дара никуда не деться. Тогда она устраивается на работу в морг, чтобы быть ближе к тем, кому нужна ее помощь.\n\nНо в мире все стремится к равновесию. И если есть тот, кто бездумно спасает всех, то где-то должен быть и тот, кто этому мешает. В жизни Риты появляется новый человек – Артур. Он тоже носит похожий браслет и тоже путешествует во времени, но его задача - помешать спасению. Таким образом, сохраняется баланс между добром и злом, между смертью и жизнью.\n\nВсе меняется, когда Рита и Артур понимают, что любят друг друга, а как быть вместе тем, у кого совершенно разные предназначения, когда у одного задача спасать, а у другого убивать?',
#    'votes': {'kp': 1208,
#     'imdb': 0,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'year': 2012,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1599028/9cda2f01-0919-4ed9-b4b3-53ea571984a5/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1599028/9cda2f01-0919-4ed9-b4b3-53ea571984a5/x1000'},
#    'genres': [{'name': 'детектив'},
#     {'name': 'триллер'},
#     {'name': 'фэнтези'},
#     {'name': 'мелодрама'}],
#    'countries': [{'name': 'Россия'}],
#    'typeNumber': 2,
#    'alternativeName': None,
#    'enName': None,
#    'names': [],
#    'movieLength': None,
#    'ratingMpaa': None,
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'ageRating': 12,
#    'backdrop': {'url': None, 'previewUrl': None},
#    'logo': {'url': None},
#    'releaseYears': [{'start': 2012, 'end': 2012}],
#    'top10': None,
#    'top250': None,
#    'status': 'completed',
#    'isSeries': True,
#    'seriesLength': 45,
#    'totalSeriesLength': 1080},
#   {'id': 420592,
#    'type': 'tv-series',
#    'name': 'Человек, который вернулся от смерти',
#    'rating': {'kp': 0,
#     'imdb': 8.4,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'description': None,
#    'votes': {'kp': 7,
#     'imdb': 43,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'year': 1969,
#    'poster': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'ужасы'},
#     {'name': 'фантастика'},
#     {'name': 'триллер'},
#     {'name': 'драма'},
#     {'name': 'криминал'},
#     {'name': 'детектив'}],
#    'countries': [{'name': 'Аргентина'}],
#    'typeNumber': 2,
#    'alternativeName': 'El hombre que volvió de la muerte',
#    'enName': None,
#    'names': [{'name': 'Человек, который вернулся от смерти'},
#     {'name': 'El hombre que volvió de la muerte'}],
#    'movieLength': None,
#    'ratingMpaa': None,
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'ageRating': None,
#    'backdrop': {'url': None, 'previewUrl': None},
#    'logo': {'url': None},
#    'releaseYears': [{'start': 1969, 'end': 1969}],
#    'top10': None,
#    'top250': None,
#    'status': 'completed',
#    'isSeries': True,
#    'seriesLength': None,
#    'totalSeriesLength': 1080},
#   {'id': 5165672,
#    'name': 'Проклятый камень',
#    'alternativeName': 'Manee Phitsawat',
#    'names': [{'name': 'Манипуляция'}, {'name': 'Manee Phitsawat'}],
#    'type': 'tv-series',
#    'typeNumber': 2,
#    'description': 'История о\xa0демоническом украшении, которое способно подчинять себе людей и\xa0заставлять их\xa0творить зло.',
#    'shortDescription': None,
#    'status': 'completed',
#    'rating': {'kp': 0,
#     'imdb': 6.2,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'votes': {'kp': 198,
#     'imdb': 10,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'ratingMpaa': None,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10812607/67d08f5b-6249-4277-876a-3c3cb74aed79/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10812607/67d08f5b-6249-4277-876a-3c3cb74aed79/x1000'},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'фэнтези'},
#     {'name': 'триллер'},
#     {'name': 'драма'},
#     {'name': 'мелодрама'}],
#    'countries': [{'name': 'Таиланд'}],
#    'releaseYears': [{'start': 2023, 'end': 2023}],
#    'top10': None,
#    'top250': None,
#    'year': 2023,
#    'ageRating': None,
#    'ticketsOnSale': False,
#    'isSeries': True,
#    'seriesLength': 69,
#    'totalSeriesLength': 1035},
#   {'id': 736394,
#    'name': 'Назад в прошлое: 9 шансов всё изменить',
#    'alternativeName': 'Nain: ahop beonui siganyeohaeng',
#    'names': [{'name': 'Назад в прошлое: 9 шансов всё изменить',
#      'language': 'RU',
#      'type': 'Russian title on kinopoisk'},
#     {'name': 'Nain: ahop beonui siganyeohaeng',
#      'language': None,
#      'type': 'Original title on kinopoisk'}],
#    'type': 'tv-series',
#    'typeNumber': 2,
#    'year': 2013,
#    'description': 'Потеряв брата, молодой телеведущий приобрёл возможность перемещаться в\xa0прошлое, чтобы изменить настоящее. Но\xa0есть одно НО\xa0—\xa0переместиться он\xa0может только 9\xa0раз.',
#    'shortDescription': 'У него есть всего несколько попыток, чтобы изменить прошлое семьи. Фантастическая дорама от режиссера «Хваюги»',
#    'status': 'completed',
#    'rating': {'kp': 7.844,
#     'imdb': 8,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 5558,
#     'imdb': 616,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'totalSeriesLength': 1000,
#    'seriesLength': 50,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/6201401/17cf0a62-f244-4393-bbb7-9e8f70d59c7f/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/6201401/17cf0a62-f244-4393-bbb7-9e8f70d59c7f/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1531675/2a0000017f58babecfc95fbd393cd2fe587c/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1531675/2a0000017f58babecfc95fbd393cd2fe587c/x1000'},
#    'genres': [{'name': 'фантастика'}, {'name': 'мелодрама'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'releaseYears': [{'start': 2013, 'end': 2013}],
#    'top10': None,
#    'top250': None,
#    'isSeries': True,
#    'ticketsOnSale': False},
#   {'id': 453372,
#    'type': 'tv-series',
#    'name': 'Vизитеры',
#    'rating': {'kp': 7.101,
#     'imdb': 6.8,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'description': 'Сегодня весь мир проснулся и увидел, что над каждым городом парят космические корабли. Прибывшие утверждают что пришли с миром, и предлагают подарки в виде медицинских открытий и технологических усовершенствований. Они обещают, что не навредят. Они лгут. Большинство человечества верит, что чужие прибыли как раз тогда, когда мы в них нуждались. Люди с радостью принимают их помощь.\n\nНо во время расследования террористической ячейки агент госбезопасности Эрика Эванс обнаруживает нечто вовсе не безобидное. Когда ее напарник пытается ее убить, Эрика обнаруживает, что пришельцы планируют внедриться в правительства и крупные корпорации, чтобы в будущем захватить все человечество. Но убедить в этом остальных практически невозможно, ведь в руках пришельцев два мощных козыря. Во-первых, они завоевали веру и любовь людей, благодаря своим подаркам. Во-вторых, они взяли под контроль почти всех подростков.\n\nТысячи подростков, включая сына Эрики, были назначены “послами мира”, но на самом деле они шпионят для пришельцев, не подозревая об этом. Эрика вынуждена вступить в движение сопротивления, где она знакомится с Райаном, пришельцем, который хочет спасти человечество. Эрике придется находить равновесие между сопротивлением, работой, и заботой о своем сыне, который принял сторону врагов.',
#    'votes': {'kp': 22985,
#     'imdb': 59713,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'year': 2009,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1629390/ac7eb286-4297-4539-8730-652fe870c373/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1629390/ac7eb286-4297-4539-8730-652fe870c373/x1000'},
#    'genres': [{'name': 'фантастика'}, {'name': 'триллер'}, {'name': 'драма'}],
#    'countries': [{'name': 'США'}],
#    'typeNumber': 2,
#    'alternativeName': 'V',
#    'backdrop': {'url': None, 'previewUrl': None},
#    'enName': None,
#    'movieLength': None,
#    'names': [{'name': 'Vизитеры'},
#     {'name': 'V'},
#     {'name': 'V - Die Besucher', 'language': 'DE', 'type': None},
#     {'name': 'V (2009)', 'language': 'FR', 'type': None},
#     {'name': 'ビジター', 'language': 'JP', 'type': None},
#     {'name': 'Vизитёры', 'language': 'RU', 'type': None},
#     {'name': 'Визитеры', 'language': 'RU', 'type': None}],
#    'status': 'completed',
#    'ageRating': 16,
#    'ratingMpaa': None,
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'logo': {'url': None},
#    'releaseYears': [{'start': 2009, 'end': 2011}],
#    'top10': None,
#    'top250': None,
#    'isSeries': True,
#    'seriesLength': 43,
#    'totalSeriesLength': 1000},
#   {'status': 'completed',
#    'rating': {'kp': 4.768,
#     'imdb': 4.5,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 7918,
#     'imdb': 18963,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'id': 1282096,
#    'type': 'tv-series',
#    'name': 'Ходячие мертвецы: Мир за пределами',
#    'description': 'Рассказ о\xa0жизни первого поколения, выросшего в\xa0захваченном зомби мире. Айрис и\xa0Хоуп Беннет вместе с\xa0другими подростками отправляются на\xa0поиски своего отца, подавшего сигнал о\xa0помощи.',
#    'year': 2020,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4774061/d599ed5a-8814-4cdf-88ba-1213d8b6ac5d/orig',
# ...
#    'alternativeName': 'The Platoon of Power Squadron',
#    'enName': None,
#    'names': [{'name': 'The Platoon of Power Squadron'}],
#    'movieLength': None,
#    'ratingMpaa': None,
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'ageRating': None,
#    'logo': {'url': None},
#    'releaseYears': [{'start': 2009, 'end': 2017}],
#    'top10': None,
#    'top250': None,
#    'isSeries': True,
#    'seriesLength': None,
#    'totalSeriesLength': 418},
#   {'id': 77217,
#    'type': 'tv-series',
#    'name': 'Десятое королевство',
#    'rating': {'kp': 8.471,
#     'imdb': 8.2,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'description': 'Официантка нью-йоркского кафе Вирджиния однажды спасает пёсика, который оказывается заколдованным принцем Венделом, сбежавшим из Страны Девяти Королевств в наш мир, спасаясь от злой Королевы-Мачехи. Принц приходится внуком Белоснежке и является прямым наследником трона, но у Королевы другой план. Она посылает уродливых и злых троллей убить принца, и они тоже перебираются в наш мир. Так, неожиданно для себя, обычная современная девушка оказывается в самом центре невероятных и фантастических событий.',
#    'votes': {'kp': 112595,
#     'imdb': 20862,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'year': 1999,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1599028/1b956fcb-9146-4528-ad5e-1f3262e59b73/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1599028/1b956fcb-9146-4528-ad5e-1f3262e59b73/x1000'},
#    'genres': [{'name': 'фэнтези'},
#     {'name': 'мелодрама'},
#     {'name': 'комедия'},
#     {'name': 'детектив'},
#     {'name': 'приключения'},
#     {'name': 'семейный'}],
#    'countries': [{'name': 'Великобритания'},
#     {'name': 'Германия'},
#     {'name': 'США'}],
#    'typeNumber': 2,
#    'alternativeName': 'The 10th Kingdom',
#    'enName': None,
#    'names': [{'name': 'Десятое королевство'},
#     {'name': 'The 10th Kingdom'},
#     {'name': 'Տասներորդ թագավորությունը', 'language': 'AM', 'type': None},
#     {'name': 'Десетото кралство', 'language': 'BG', 'type': None},
#     {'name': '魔幻王朝', 'language': 'CN', 'type': None},
#     {'name': 'Desáté království', 'language': 'CZ', 'type': None},
#     {'name': 'Das 10te Königreich', 'language': 'DE', 'type': None},
#     {'name': 'El décimo reino', 'language': 'ES', 'type': None},
#     {'name': 'Le dixième Royaume', 'language': 'FR', 'type': None},
#     {'name': 'A tizedik királyság', 'language': 'HU', 'type': None},
#     {'name': 'Il magico regno delle favole', 'language': 'IT', 'type': None},
#     {'name': 'Dziesiąte królestwo', 'language': 'PL', 'type': None},
#     {'name': 'Десяте королівство', 'language': 'UA', 'type': None},
#     {'name': '10th Kingdom, The', 'language': 'US', 'type': None},
#     {'name': 'Vương quốc thứ Mười', 'language': 'VN', 'type': None}],
#    'movieLength': None,
#    'ratingMpaa': None,
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'ageRating': 6,
#    'backdrop': {'url': None, 'previewUrl': None},
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/8onMvTUNtNk9AO7ULqnSxJSFRRW.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/8onMvTUNtNk9AO7ULqnSxJSFRRW.png'},
#    'releaseYears': [{'start': 1999, 'end': 1999}],
#    'top10': None,
#    'top250': None,
#    'status': 'completed',
#    'isSeries': True,
#    'seriesLength': None,
#    'totalSeriesLength': 417},
#   {'id': 257808,
#    'name': 'Охотник',
#    'alternativeName': None,
#    'names': [],
#    'type': 'tv-series',
#    'typeNumber': 2,
#    'year': 2006,
#    'description': 'Средневековый Охотник\xa0— Владимир, сын Казатула, когда-то казнённый по\xa0ложному обвинению в\xa0убийстве, волей языческих богов заброшен в\xa0современную Москву. Его миссия\xa0— пользуясь охотничьей наблюдательностью и\xa0уникальным умением «читать следы»\xa0— помочь женщине, несправедливо обвинённой в\xa0убийстве собственного мужа…\n\nСподвижником и\xa0проводником Охотника в\xa0современном мире\xa0— поначалу принудительно\xa0— становится продавец кошачьего корма Михаил Ильич Сусел. Но\xa0ни\xa0он, ни\xa0сам Владимир ещё не\xa0знают, что после первого, удачно завершённого дела, Охотник станет едва\xa0ли не\xa0каждое полнолуние материализовываться в\xa0магазинчике «Корма для животных», чтобы помогать тем, кто отчаялся найти в\xa0этом мире справедливость и\xa0кому уже не\xa0на\xa0кого надеяться…',
#    'shortDescription': 'Средневековый охотник помогает отчаявшимся жителям современной Москвы. Фэнтези-сериал с Евгением Цыгановым',
#    'status': 'completed',
#    'rating': {'kp': 7.49,
#     'imdb': 6.7,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 7585,
#     'imdb': 51,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'totalSeriesLength': 416,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1599028/c1bf6666-1fd8-40d6-ade0-e5d89afb9a1f/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1599028/c1bf6666-1fd8-40d6-ade0-e5d89afb9a1f/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/223007/2a00000162a678c7c26efb717f0f5aae8c71/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/223007/2a00000162a678c7c26efb717f0f5aae8c71/x1000'},
#    'genres': [{'name': 'фантастика'},
#     {'name': 'фэнтези'},
#     {'name': 'приключения'}],
#    'countries': [{'name': 'Россия'}],
#    'releaseYears': [{'start': 2006, 'end': 2006}],
#    'top10': None,
#    'top250': None,
#    'isSeries': True,
#    'ticketsOnSale': False,
#    'enName': None,
#    'logo': {'url': None, 'previewUrl': None}},
#   {'id': 993595,
#    'name': 'Лачуга должника',
#    'alternativeName': None,
#    'names': [{'name': 'Лачуга должника',
#      'language': 'RU',
#      'type': 'Russian title on kinopoisk'}],
#    'type': 'tv-series',
#    'typeNumber': 2,
#    'year': 2017,
#    'description': 'В 1940 г. братья Павел и Пётр, семилетние мальчишки, находят в песчаном карьере загадочную капсулу. Присматривающий за ними 12-летний Виктор решает без мелюзги осмотреть находку и отправляет их на речку. Капсула оказывается посланием с планеты, зеркальной Земле — Ялмез. В нём - просьба о помощи, присланная из далёкого 2150 года, в котором цивилизация Ялмеза находится на грани гибели. Также в капсулу вложен препарат, который позволяет человеку жить миллион лет.\n\nВиктор понимает только про долголетие и выпивает препарат. В то же время прибегает запыхавшийся Павел: Петра унесло течением, и маленький Павел не смог ему помочь...',
#    'shortDescription': 'Братья находят капсулу из будущего с волшебным эликсиром и просьбой о помощи. Драма по повести Вадима Шефнера',
#    'status': 'completed',
#    'rating': {'kp': 7.333,
#     'imdb': 5.2,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 33092,
#     'imdb': 85,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'totalSeriesLength': 416,
#    'seriesLength': 52,
#    'ratingMpaa': None,
#    'ageRating': 12,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/6201401/91244759-5e08-46e5-b440-b3be0037ff16/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/6201401/91244759-5e08-46e5-b440-b3be0037ff16/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/1534341/2a0000017e97bfe8ed4dc373e9322bd3c936/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/1534341/2a0000017e97bfe8ed4dc373e9322bd3c936/x1000'},
#    'genres': [{'name': 'драма'}, {'name': 'фантастика'}],
#    'countries': [{'name': 'Россия'}],
#    'releaseYears': [{'start': 2017, 'end': 2017}],
#    'top10': None,
#    'top250': None,
#    'isSeries': True,
#    'ticketsOnSale': False},
#   {'id': 397414,
#    'type': 'tv-series',
#    'name': 'Секунда до...',
#    'rating': {'kp': 7.729,
#     'imdb': 6.9,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'description': 'Преуспевающий бизнесмен Олег узнает, что его бывшая возлюбленная умерла при родах. Теперь он должен признать своего ребенка. Олег не готов сделать этот шаг. Он напивается и попадает в автомобильную аварию...\n \nГерой должен был погибнуть, но в последнюю секунду ему дается шанс: Олег становится одним из «ангелов добра» в команде таких же, как он — однажды принявших неверное решение. Сержанту, игроку, мошеннице, невесте, мальчику-мажору и, наконец, Олегу предоставляется возможность изменить свою судьбу и вернуться назад к живым...',
#    'votes': {'kp': 2914,
#     'imdb': 29,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'year': 2007,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/1599028/9a297319-5053-40ec-8727-acb166802999/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/1599028/9a297319-5053-40ec-8727-acb166802999/x1000'},
#    'genres': [{'name': 'фантастика'},
#     {'name': 'триллер'},
#     {'name': 'приключения'}],
#    'countries': [{'name': 'Россия'}],
#    'typeNumber': 2,
#    'alternativeName': None,
#    'enName': None,
#    'names': [{'name': 'Секунда до...'}],
#    'ageRating': 16,
#    'movieLength': None,
#    'ratingMpaa': None,
#    'shortDescription': None,
#    'ticketsOnSale': False,
#    'backdrop': {'url': None, 'previewUrl': None},
#    'logo': {'url': None},
#    'releaseYears': [{'start': 2007, 'end': 2007}],
#    'top10': None,
#    'top250': None,
#    'status': 'completed',
#    'isSeries': True,
#    'seriesLength': 52,
#    'totalSeriesLength': 416},
#   {'id': 1263485,
#    'type': 'tv-series',
#    'name': 'Дивный новый мир',
#    'rating': {'kp': 7.203,
#     'imdb': 7,
#     'filmCritics': 0,
#     'russianFilmCritics': 47.0588,
#     'await': None},
#    'description': 'XXVI век, идеальный мир\xa0будущего. Здесь всё принадлежат всем, потребление возведено в\xa0культ, люди рождаются в\xa0инкубаторах и\xa0умирают без\xa0болезней и\xa0старости\xa0—\xa0а главное, каждый чувствует себя на\xa0вершине блаженства благодаря специальной таблетке. Синтетическую гармонию нарушает необычный человек извне, и\xa0перед жителями дивного нового мира встает опасный вопрос\xa0—\xa0верный ли\xa0путь к\xa0счастью они\xa0выбрали.',
#    'votes': {'kp': 119274,
#     'imdb': 17846,
#     'filmCritics': 0,
#     'russianFilmCritics': 17,
#     'await': 0},
#    'year': 2020,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/4303601/75a8cc82-e8f6-48a6-ac5f-302175a6ad07/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/4303601/75a8cc82-e8f6-48a6-ac5f-302175a6ad07/x1000'},
#    'genres': [{'name': 'фантастика'}, {'name': 'триллер'}, {'name': 'драма'}],
#    'countries': [{'name': 'США'}],
#    'typeNumber': 2,
#    'alternativeName': 'Brave New World',
#    'enName': 'Brave New World US',
#    'movieLength': None,
#    'names': [{'name': 'Дивный новый мир'},
#     {'name': 'Brave New World'},
#     {'name': 'Brave New World ブレイブ・ニュー・ワールド', 'language': 'JP', 'type': None},
#     {'name': 'Brave New World US', 'language': 'US', 'type': None}],
#    'ratingMpaa': None,
#    'shortDescription': 'В мире будущего поклоняются богу потребления, но не всех устраивает эта утопия. По роману Олдоса Хаксли',
#    'ticketsOnSale': False,
#    'ageRating': 18,
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/224348/2a000001735d80ec9406561421e121697131/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/224348/2a000001735d80ec9406561421e121697131/x1000'},
#    'logo': {'url': 'https://image.openmoviedb.com/tmdb-images/original/k34xau50rR7LVJON53zzmiIBcgp.png',
#     'previewUrl': 'https://image.openmoviedb.com/tmdb-images/w500/k34xau50rR7LVJON53zzmiIBcgp.png'},
#    'releaseYears': [{'start': 2020, 'end': 2020}],
#    'top10': None,
#    'top250': None,
#    'status': 'completed',
#    'isSeries': True,
#    'seriesLength': None,
#    'totalSeriesLength': 415},
#   {'id': 5378717,
#    'name': 'Игра смерти',
#    'alternativeName': 'Ijae, got jukseupnida',
#    'names': [{'name': 'Игра смерти',
#      'language': 'RU',
#      'type': 'Russian title on kinopoisk'},
#     {'name': 'Ijae, got jukseupnida',
#      'language': None,
#      'type': 'Original title on kinopoisk'}],
#    'type': 'tv-series',
#    'typeNumber': 2,
#    'year': 2023,
#    'description': 'Чхве И-джэ вырос в\xa0бедной семье и\xa0не получил в\xa0жизни хороший старт, поэтому, провалив собеседование в\xa0престижную фирму, семь лет\xa0был вынужден перебиваться подработками. Когда парень снова не\xa0проходит собеседование, то\xa0впадает в\xa0отчаяние и, оставив предсмертную записку, что\xa0не боится смерти, прыгает с\xa0крыши. Он\xa0думал, что\xa0на этом его\xa0мучения закончатся, но\xa0не тут-то было. И-джэ оказывается перед вратами ада, где\xa0его встречает сама смерть, и\xa0узнаёт, что\xa0теперь в\xa0качестве наказания будет умирать 12\xa0раз в\xa0разных телах. А\xa0если он\xa0не хочет попасть в\xa0ад, то\xa0должен постараться выжить.',
#    'shortDescription': None,
#    'status': 'completed',
#    'rating': {'kp': 8.4,
#     'imdb': 8.5,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 33605,
#     'imdb': 17187,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': 0},
#    'movieLength': None,
#    'totalSeriesLength': 413,
#    'seriesLength': None,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/10835644/cd676134-ad5e-409a-b6e6-9aaf30758abb/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/10835644/cd676134-ad5e-409a-b6e6-9aaf30758abb/x1000'},
#    'backdrop': {'url': None, 'previewUrl': None},
#    'genres': [{'name': 'фэнтези'},
#     {'name': 'драма'},
#     {'name': 'боевик'},
#     {'name': 'криминал'},
#     {'name': 'мелодрама'},
#     {'name': 'триллер'}],
#    'countries': [{'name': 'Корея Южная'}],
#    'ticketsOnSale': False,
#    'releaseYears': [{'start': 2023, 'end': 2024}],
#    'top10': None,
#    'top250': 50,
#    'isSeries': True},
#   {'id': 4531494,
#    'name': 'Наследие',
#    'alternativeName': None,
#    'names': [{'name': 'Наследие',
#      'language': 'RU',
#      'type': 'Russian title on kinopoisk'}],
#    'type': 'tv-series',
#    'typeNumber': 2,
#    'year': 2021,
#    'description': 'Когда генетическое разнообразие стало минимальным, а\xa0человечество оказалось на\xa0грани вымирания, стартовала программа «Наследие», призванная восполнить популяцию. Ее\xa0возглавили биоинженеры Александр и\xa0Елизавета Гордеевы и\xa0генетик Петр Сергеевич. Группа ученых провела в\xa0криогенном сне\xa0сто лет, чтобы в\xa0будущем разморозить здоровые эмбрионы. Однако ученые и\xa0представить не\xa0могли, каким окажется первое поколение новых людей и\xa0последняя надежда человечества.',
#    'shortDescription': 'Их вырастили, чтобы спасти человечество, но чего хотят они сами? Сай-фай с Алексеем Серебряковым',
#    'status': 'completed',
#    'rating': {'kp': 6.757,
#     'imdb': 6.6,
#     'filmCritics': 0,
#     'russianFilmCritics': 0,
#     'await': None},
#    'votes': {'kp': 28010,
#     'imdb': 208,
#     'filmCritics': 0,
#     'russianFilmCritics': 1,
#     'await': 0},
#    'movieLength': None,
#    'totalSeriesLength': 405,
#    'seriesLength': 45,
#    'ratingMpaa': None,
#    'ageRating': 18,
#    'poster': {'url': 'https://image.openmoviedb.com/kinopoisk-images/6201401/efedbbbc-3937-4788-a241-04cb4e8cb6dd/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-images/6201401/efedbbbc-3937-4788-a241-04cb4e8cb6dd/x1000'},
#    'backdrop': {'url': 'https://image.openmoviedb.com/kinopoisk-ott-images/2419418/2a000001899c9660e9894996affb3d8f4137/orig',
#     'previewUrl': 'https://image.openmoviedb.com/kinopoisk-ott-images/2419418/2a000001899c9660e9894996affb3d8f4137/x1000'},
#    'genres': [{'name': 'фантастика'}],
#    'countries': [{'name': 'Россия'}],
#    'releaseYears': [{'start': 2021, 'end': 2021}],
#    'top10': None,
#    'top250': None,
#    'isSeries': True,
#    'ticketsOnSale': False}],
#  'total': 5986,
#  'limit': 100,
#  'page': 1,
#  'pages': 60}

# %%
films_df = pd.DataFrame(res['docs'])
films_df.head(3)
# Out:
#        id       type                  name  \
# 0  419572  tv-series                Раузан
# 1  891645  tv-series  Министерство времени
# 2  494493  tv-series    Королевство ветров
#
#                                               rating  \
# 0  {'kp': 7.715, 'imdb': 7.4, 'filmCritics': 0, '...
# 1  {'kp': 7.127, 'imdb': 8.2, 'filmCritics': 0, '...
# 2  {'kp': 8.083, 'imdb': 7.5, 'filmCritics': 0, '...
#
#                                          description  \
# 0  Себастьян де Монтоза красив и богат, но страда...
# 1  Министерство времени - секретное правительстве...
# 2  Король Юри, сын первого короля Когурё, великог...
#
#                                                votes  year  \
# 0  {'kp': 431, 'imdb': 44, 'filmCritics': 0, 'rus...  2000
# 1  {'kp': 3372, 'imdb': 5736, 'filmCritics': 0, '...  2015
# 2  {'kp': 1253, 'imdb': 1523, 'filmCritics': 0, '...  2008
#
#                                               poster  \
# 0  {'url': 'https://image.openmoviedb.com/kinopoi...
# 1  {'url': 'https://image.openmoviedb.com/kinopoi...
# 2  {'url': 'https://image.openmoviedb.com/kinopoi...
#
#                                               genres  \
# 0  [{'name': 'фэнтези'}, {'name': 'драма'}, {'nam...
# 1  [{'name': 'фантастика'}, {'name': 'фэнтези'}, ...
# 2  [{'name': 'фэнтези'}, {'name': 'драма'}, {'nam...
#
#                    countries  ...  ticketsOnSale  \
# 0     [{'name': 'Колумбия'}]  ...          False
# 1      [{'name': 'Испания'}]  ...          False
# 2  [{'name': 'Корея Южная'}]  ...          False
#
#                             backdrop  \
# 0  {'url': None, 'previewUrl': None}
# 1  {'url': None, 'previewUrl': None}
# 2  {'url': None, 'previewUrl': None}
#
#                                                 logo  \
# 0                  {'url': None, 'previewUrl': None}
# 1  {'url': 'https://image.openmoviedb.com/tmdb-im...
# 2                  {'url': None, 'previewUrl': None}
#
#                      releaseYears top10 top250     status isSeries  \
# 0  [{'start': 2000, 'end': 2001}]  None    NaN  completed     True
# 1  [{'start': 2015, 'end': 2020}]  None    NaN  completed     True
# 2  [{'start': 2008, 'end': 2008}]  None    NaN  completed     True
#
#    seriesLength totalSeriesLength
# 0          45.0              4500
# 1           NaN              3155
# 2          60.0              2160
#
# [3 rows x 28 columns]

# %%
def clean_series(series):
    series['genre'] = series['genres'].apply(lambda genres: ', '.join([genre['name'] for genre in genres]))
    series['countries'] = series['countries'].apply(lambda countries: ', '.join([country['name'] for country in countries]))

    series['release_start'] = series['releaseYears'].apply(lambda x: x[0]['start'])
    series['release_end'] = series['releaseYears'].apply(lambda x: x[0]['end'])

    series.set_index('id', inplace = True)

    return series[['name', 'year', 'genre', 'countries', 'release_start', 'release_end', 'seriesLength', 'totalSeriesLength']]

# %% [markdown]
# Есть ли в топ-100 самых длинных сериалов сериалы из России?

# %%
cleaned100series = clean_series(films_df)
cleaned100series.head()
# Out:
#                          name  year  \
# id
# 419572                 Раузан  2000
# 891645   Министерство времени  2015
# 494493     Королевство ветров  2008
# 5028856      Сердце спасателя  2022
# 761595    Китайский паладин 3  2009
#
#                                                      genre    countries  \
# id
# 419572                           фэнтези, драма, мелодрама     Колумбия
# 891645   фантастика, фэнтези, боевик, триллер, комедия,...      Испания
# 494493                             фэнтези, драма, история  Корея Южная
# 5028856  ужасы, драма, мелодрама, комедия, фэнтези, дет...      Таиланд
# 761595                            фэнтези, боевик, история        Китай
#
#          release_start  release_end  seriesLength  totalSeriesLength
# id
# 419572          2000.0       2001.0          45.0               4500
# 891645          2015.0       2020.0           NaN               3155
# 494493          2008.0       2008.0          60.0               2160
# 5028856         2022.0       2022.0          39.0               1755
# 761595          2009.0       2009.0          45.0               1665

# %%
cleaned100series[cleaned100series['countries'].str.contains("Россия")]
# Out:
#                                        name  year  \
# id
# 717443                    До смерти красива  2013
# 674374                     Я отменяю смерть  2012
# 622652                Обратная сторона Луны  2012
# 841702                                 Иные  2015
# 533136                                Шахта  2010
# 256766                       Охота на гения  2006
# 428836                               Энигма  2010
# 487349                   Гадание при свечах  2010
# 394028                   Девять неизвестных  2006
# 501965               Пока цветет папоротник  2012
# 405652                               Дурдом  2006
# 768062   Беловодье. Тайна затерянной страны  2016
# 820725                 Колыбель над бездной  2014
# 405692                              Контора  2006
# 153016                     Молодой Волкодав  2006
# 5319850        Последний богатырь. Наследие  2024
# 276285        Бункер, или Ученые под землей  2006
# 257808                              Охотник  2006
# 993595                      Лачуга должника  2017
# 397414                        Секунда до...  2007
# 4531494                            Наследие  2021
#
#                                                   genre        countries  \
# id
# 717443                       фантастика, драма, комедия           Россия
# 674374            детектив, триллер, фэнтези, мелодрама           Россия
# 622652   фантастика, триллер, драма, криминал, детектив           Россия
# 841702                       фантастика, драма, триллер           Россия
# 533136              фантастика, боевик, драма, детектив           Россия
# 256766      фантастика, криминал, детектив, приключения           Россия
# 428836                 фантастика, триллер, приключения           Россия
# 487349                            фантастика, мелодрама           Россия
# 394028                                фэнтези, детектив           Россия
# 501965                    фэнтези, комедия, приключения           Россия
# 405652                      фэнтези, криминал, детектив  Россия, Украина
# 768062                             приключения, фэнтези           Россия
# 820725                                   драма, фэнтези           Россия
# 405692                    фантастика, триллер, детектив           Россия
# 153016                             фэнтези, приключения           Россия
# 5319850         фэнтези, комедия, приключения, семейный           Россия
# 276285                 фантастика, триллер, приключения           Россия
# 257808                 фантастика, фэнтези, приключения           Россия
# 993595                                драма, фантастика           Россия
# 397414                 фантастика, триллер, приключения           Россия
# 4531494                                      фантастика           Россия
#
#          release_start  release_end  seriesLength  totalSeriesLength
# id
# 717443          2013.0       2013.0          46.0               1104
# 674374          2012.0       2012.0          45.0               1080
# 622652          2012.0       2016.0          50.0                800
# 841702          2015.0       2015.0          48.0                768
# 533136          2010.0       2010.0          48.0                768
# 256766          2006.0       2006.0          44.0                704
# 428836          2010.0       2010.0          47.0                686
# 487349          2010.0       2010.0          42.0                680
# 394028          2006.0       2006.0           NaN                624
# 501965          2012.0       2012.0          48.0                619
# 405652          2006.0       2013.0          50.0                600
# 768062          2016.0       2016.0          48.0                576
# 820725          2014.0       2014.0          47.0                564
# 405692          2006.0       2006.0           NaN                551
# 153016          2006.0       2006.0           NaN                528
# 5319850            NaN          NaN          60.0                480
# 276285          2006.0       2006.0          24.0                420
# 257808          2006.0       2006.0           NaN                416
# 993595          2017.0       2017.0          52.0                416
# 397414          2007.0       2007.0          52.0                416
# 4531494         2021.0       2021.0          45.0                405

# %% [markdown]
# ### Творческая часть

# %% [markdown]
# Придумайте какую-нибудь свою интересную и масштабную задачу, которую можно было бы решить в рамках имеющихся у нас данных. В идеале — сразу обосновать, какую пользу или интерес решение такой задачи могло бы нести.

# %% [markdown]
# Давайте вместе реализуем самые интересные и нетривиальные из ваших предложений!
#
#     # your ideas here
